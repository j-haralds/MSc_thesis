# %%
import torch
import numpy as np
import torch.nn as nn
from tqdm import trange
from pathlib import Path
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import importlib
from torchinfo import summary
import time


import sys
sys.path.append('..')
import plot_settings
plot_settings.apply()
import sim_PyBaMM
importlib.reload(sim_PyBaMM);
import exp_pybamm_ver4
importlib.reload(exp_pybamm_ver4);
import SPM_eqs
importlib.reload(SPM_eqs);
import Euler_exp_log
importlib.reload(Euler_exp_log);

# %%
# --- Simulation config ---
T_HORIZON = 3600.0          # [s]  total simulation horizon
T = 1000            # number of time steps
DT = T_HORIZON / (T - 1)   # fixed for all sims
t_fixed = np.linspace(0, T_HORIZON, T)    # fixed 'physical' grid

# %%
# --- Data generation ---

def time_query(sol, t_fixed):
    t_end = sol["Time [s]"].entries[-1]
    valid = t_fixed <= t_end  # boolean, length T # Valid mask: where simulation was still running
    t_query = np.clip(t_fixed, 0, t_end)     # Observe only up to t_end, fill rest with NaN or last value
    return t_query, valid

def observe_states(t_query, sol, model):
    cn = sol.observe(model.variables["X-averaged negative particle concentration [mol.m-3]"])(t_query)[-1, :]
    cp = sol.observe(model.variables["X-averaged positive particle concentration [mol.m-3]"])(t_query)[-1, :]
    I = sol.observe(model.variables["Current [A]"])(t_query)
    V = sol.observe(model.variables["Terminal voltage [V]"])(t_query)
    return cn, cp, I, V

def get_vals_DC(I0):
    sol, model, param = sim_PyBaMM.simulate_DC1(I0, T, T_HORIZON)   # simulate with t_eval = np.linspace(0, t_horizon, T)
    t_query, valid = time_query(sol, t_fixed)
    cn, cp, I, V = observe_states(t_query, sol, model)
    return V, I, cn, cp, valid

def get_vals_pulse():
    sol, model, t_eval, param = exp_pybamm_ver4.generate_data(T_HORIZON, DT, model='DFN', RNG=None)   # simulate with t_eval = np.linspace(0, t_horizon, T)
    t_query, valid = time_query(sol, t_fixed)
    cn, cp, I, V = observe_states(t_query, sol, model)
    return V, I, cn, cp, valid

def get_vals_GRF():
    sol, model, param = sim_PyBaMM.simulate_GRF(T, T_HORIZON)   # simulate with t_eval = np.linspace(0, t_horizon, T)
    t_query, valid = time_query(sol, t_fixed)
    cn, cp, I, V = observe_states(t_query, sol, model)
    return V, I, cn, cp, valid


def gen_data(B, currents='DC', I_low=0.25, I_high=1.0, seed=None):
    ''' Generates B trajectories. Returns arrays of shape (B, T, 1) '''
    rng = np.random.default_rng(seed)

    arrays = {k: np.zeros((B, T, 1)) for k in ['V', 'I', 'dI', 'cn', 'cp', 'cn_dot', 'cp_dot']}
    valid = np.zeros((B, T), dtype=bool)

    for b in trange(B):
        if currents == 'DC':
            V_b, I_b, cn_b, cp_b, valid_b = get_vals_DC(float(rng.uniform(I_low, I_high)))
        elif currents == 'pulse':
            V_b, I_b, cn_b, cp_b, valid_b = get_vals_pulse()
        elif currents == 'GRF':
            V_b, I_b, cn_b, cp_b, valid_b = get_vals_GRF()

        cn_dot_b = np.zeros_like(cn_b)
        cp_dot_b = np.zeros_like(cp_b)
        cn_dot_b[:-1] = np.diff(cn_b) / DT  # Derivative w.r.t. time using backward difference
        cp_dot_b[:-1] = np.diff(cp_b) / DT
        cn_dot_b[-1] = cn_dot_b[-2]         # Pad last entry with second to last value
        cp_dot_b[-1] = cp_dot_b[-2]

        for key, val in zip(['V', 'I', 'cn', 'cp', 'cn_dot', 'cp_dot'], [V_b, I_b, cn_b, cp_b, cn_dot_b, cp_dot_b]):
            arrays[key][b, :, 0] = val

        arrays['dI'][b, 1:, 0] = np.diff(I_b)
        arrays['dI'][b, 0, 0] = 0.0         # dI[0] = 0
        valid[b, :] = valid_b

    return *[arrays[key] for key in ['I', 'dI', 'V', 'cn', 'cn_dot', 'cp', 'cp_dot']] , valid

# %%
# --- Check ---
sol, model_bat, t_eval, param = exp_pybamm_ver4.generate_data(T_HORIZON, DT, model='DFN', RNG=None)   # simulate with t_eval = np.linspace(0, t_horizon, T)
sol, model_bat, param = sim_PyBaMM.simulate_DC1(0.8, T, T_HORIZON)
t_query, valid = time_query(sol, t_fixed)

def observe_states_extra(t_query, sol, model):
    cn = sol.observe(model.variables["X-averaged negative particle concentration [mol.m-3]"])(t_query)[-1, :]
    cp = sol.observe(model.variables["X-averaged positive particle concentration [mol.m-3]"])(t_query)[-1, :]
    I = sol.observe(model.variables["Current [A]"])(t_query)
    V = sol.observe(model.variables["Terminal voltage [V]"])(t_query)
    Ohm_loss = sol.observe(model.variables["Negative electrode ohmic losses [V]"])(t_query)
    return cn, cp, I, V, Ohm_loss

cn, cp, I, V, Ohm_loss = observe_states_extra(t_query, sol, model_bat)
plt.plot(Ohm_loss[0, :]);
print(param['Contact resistance [Ohm]'], param['Current function [A]'])
# Out:
# 0 0.8

# %%
# --- Save data ---
# B = 20
# I, dI, V, cn, cn_dot, cp, cp_dot, valid = gen_data(B, currents='pulse', I_low=0.25, I_high=1.0, seed=42)
# np.savez('data_c_pulse.npz', I=I, dI=dI, V=V, cn=cn, cn_dot=cn_dot, cp=cp, cp_dot=cp_dot, valid=valid)

# %%
# --- Load data ---
def load_data(path):
    d = np.load(path)
    return d['I'], d['dI'], d['V'], d['cn'], d['cn_dot'], d['cp'], d['cp_dot'], d['valid']

# I, dI, V, cn, cn_dot, cp, cp_dot, valid = load_data('Euler_data/data_c_GRFI.npz')
# I, dI, V, cn, cn_dot, cp, cp_dot, valid = load_data('t=5e3_GRF_data_c_dot.npz')
# I, dI, V, cn, cn_dot, cp, cp_dot, valid = load_data('data/data_c_pulse.npz')
I, dI, V, cn, cn_dot, cp, cp_dot, valid = load_data('data/data_c_constI.npz')

B = I.shape[0]

# %%
# --- Normalization ---
stats = {}
def compute_stats():
    for name, arr in zip(['I', 'dI', 'V', 'cn', 'cn_dot', 'cp', 'cp_dot'], 
                         [I, dI, V, cn, cn_dot, cp, cp_dot]):
        stats[name] = (float(arr.mean()), float(max(arr.std(), 1e-8)))  # Avoid zero std
    return stats

def transform(arr, name):
    mean, std = stats[name]
    return (arr - mean) / std

def inverse_transform(arr, name):
    mean, std = stats[name]
    return arr * std + mean
    
stats = compute_stats()

# Normalize
I_n = transform(I, 'I')
dI_n = transform(dI, 'dI')
cn_n = transform(cn, 'cn')
cp_n = transform(cp, 'cp')
cn_dot_n = transform(cn_dot, 'cn_dot')
cp_dot_n = transform(cp_dot, 'cp_dot')
V_n = transform(V, 'V')

# %%
# --- Split data ---
x = torch.tensor(np.concatenate([I_n, cn_n, cp_n], axis=-1), dtype=torch.float32) # (B, T, 4)
y = torch.tensor(np.concatenate([cn_dot_n, cp_dot_n, V_n], axis=-1), dtype=torch.float32)
mask = torch.tensor(valid, dtype=torch.float32)

split = int(0.8 * B)
def _split(arr):
    return arr[:split], arr[split:]

def _split_flat(arr):
    return arr[:split].flatten(0,1), arr[split:].flatten(0,1)   # Same as reshape(B * T, C)    # (B*T, 4)

# Flatten time dimension for training and split
x_train, x_test = _split_flat(x)        
y_train, y_test = _split_flat(y)
mask_train, mask_test = _split_flat(mask)

# Un-normalized for plotting
cn_train,     cn_test     = _split(cn)
cp_train,     cp_test     = _split(cp)
cn_dot_train, cn_dot_test = _split(cn_dot)
cp_dot_train, cp_dot_test = _split(cp_dot)
I_train,      I_test      = _split(I)
dI_train,     dI_test     = _split(dI)
V_train,      V_test      = _split(V)
mask_train_plot, mask_test_plot = _split(valid)

print('Shapes:', x_train.shape, y_train.shape, mask_train.shape, cn_test.shape, cp_test.shape, I_test.shape, V_test.shape)

batch_size_large = int(B*T/4)
train_loader_flat = DataLoader(TensorDataset(x_train, y_train, mask_train), batch_size=batch_size_large, shuffle=True)
# Out:
# Shapes: torch.Size([160000, 3]) torch.Size([160000, 3]) torch.Size([160000]) (40, 1000, 1) (40, 1000, 1) (40, 1000, 1) (40, 1000, 1)

# %%
# --- Model ---
class Net(nn.Module):
    def __init__(self, input_size=3, hidden_size=128):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_size, hidden_size),     # [I_t, cn_t, cp_t]
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 7)               # [G, m1, m2, l1, l2, z1, z2]
        )
    
    def forward(self, x):
        x = self.net(x)
        return x
    
model = Net()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
# summary(model=model, input_size=(batch_size_small*T, 4))

# %%
# --- Training ---
def masked_mse(pred, target, mask):
    err = (pred - target) ** 2    # (B*T, 2)
    m = mask.unsqueeze(-1)        # (B*T, 1)
    return (err * m).sum() / (m.sum() * 2)



def state_evolver(pred, x):
    G, m1, m2, l1, l2, z1, z2 = pred[:, 0], pred[:, 1], pred[:, 2], pred[:, 3], pred[:, 4], pred[:, 5], pred[:, 6]

    v = torch.stack([m1, m2], dim=-1)  # (B*T, 2)
    M = v.unsqueeze(-1) * v.unsqueeze(-2)  # (B*T, 2, 2)
    Z = torch.stack([z1, z2], dim=-1)  # (B*T, 2)

    dG_dxi = torch.autograd.grad(G, x, grad_outputs=torch.ones_like(G), create_graph=True)[0] # (B*T, 3)
    
    dG_dxi_col = dG_dxi[:, 1:3].unsqueeze(-1)  # Slice of dG/dI (B*T, 2) then unsqueeze (B*T, 2, 1)

    term1 = (M @ dG_dxi_col).squeeze(-1)            # (B*T, 2)
    
    I = x[:, 0:1]       # (B*T, 1)
    term2 = I * Z    # (B*T, 2)

    xi_dot = - term1 - term2

    # --- Gibbs free energy rate dG/dt ---
    # Correction factors
    std_xi  = torch.tensor([stats['cn'][1], stats['cp'][1]], dtype=torch.float32)   # (2,)
    std_dot = torch.tensor([stats['cn_dot'][1], stats['cp_dot'][1]], dtype=torch.float32)   # (2,)
    mean_dot = torch.tensor([stats['cn_dot'][0], stats['cp_dot'][0]], dtype=torch.float32)  # (2,)
    std_I = torch.tensor(stats['I'][1], dtype=torch.float32)
    mean_I = torch.tensor(stats['I'][0], dtype=torch.float32)
    std_V = torch.tensor(stats['V'][1], dtype=torch.float32)
    mean_V = torch.tensor(stats['V'][0], dtype=torch.float32)

    I_phys = I * std_I + mean_I  # (B*T, 1)

    dG_dxi_phys  = dG_dxi_col.squeeze(-1) / std_xi                          # (B*T, 2) phys gradient
    xi_dot_phys  = xi_dot * std_dot + mean_dot                          # (B*T, 2) phys rates

    dG_dt = (dG_dxi_phys * xi_dot_phys).sum(dim=-1, keepdim=True)      # (B*T, 1) physical dG/dt

    volt = (dG_dxi_col * Z.unsqueeze(-1)).sum(dim=1)
    V_phys = volt * std_V + mean_V
    print(V_phys, I_phys)
    power = I_phys * V_phys
    # power = (dG_dxi_phys * std_xi * term2).sum(dim=-1, keepdim=True)
    diss = (dG_dxi_phys * (std_dot / std_xi) * term1).sum(dim=-1, keepdim=True)
    return xi_dot, V_phys, dG_dt, Z, diss, power


def loss_xi(xi_dot_pred, target, mask):
    xi_loss = masked_mse(xi_dot_pred, target, mask)
    return xi_loss

def loss_volt(volt_pred, target, mask):
    v_loss = masked_mse(volt_pred, target, mask)
    return v_loss


def training(epochs=30):
    history = {"loss": [], "xi_loss": [], "v_loss": [], "time per ep": []}
    for ep in range(epochs):
        model.train()
        tot_ep_loss = 0.0
        tot_xi_loss = 0.0
        tot_volt_loss = 0.0
        start_t = time.perf_counter()

        for x_b, y_b, mask_b in train_loader_flat:
            x_b = x_b.float().requires_grad_(True)   # ← must be BEFORE model(x_b)
            pred = model(x_b)   # [B*T, 2]
            xi_dot_pred, volt, dG_dt, Z, term1, term2 = state_evolver(pred, x_b)
            xi_loss = loss_xi(xi_dot_pred, y_b[:, :2], mask_b)
            volt_loss = loss_volt(volt, y_b[:, 2:3], mask_b)
            # volt_loss = torch.tensor(0.0)

            ep_loss = xi_loss + volt_loss
            optimizer.zero_grad()
            ep_loss.backward()
            optimizer.step()
            
            tot_ep_loss += ep_loss.item()
            tot_xi_loss += xi_loss.item()
            tot_volt_loss += volt_loss.item()

        avg_loss = tot_ep_loss / len(train_loader_flat)  # Average loss per batch
        avg_xi_loss = tot_xi_loss / len(train_loader_flat)
        avg_volt_loss = tot_volt_loss / len(train_loader_flat)
        end_t = time.perf_counter()

        history["loss"].append(avg_loss)
        history["xi_loss"].append(avg_xi_loss)
        history["v_loss"].append(avg_volt_loss)
        history["time per ep"].append(end_t - start_t)
        print(f"Epoch {ep+1} | loss {avg_loss:.3e} | time {end_t - start_t:.2f}s")

    return history

# %%
history = training(epochs=10)

# %%
# Euler_exp_log.exp_log(model, history, name = 'Data dt=0.1', d_loss_type = 'mse')

# %%
fig, (ax1) = plt.subplots(1, 1, figsize=(4, 3))
ax1.plot(history["loss"], label="Train loss")
ax1.plot(history["xi_loss"], label="Xi loss")
ax1.plot(history["v_loss"], label="Volt loss")
ax1.set_xlabel("epoch")
ax1.set_ylabel("MSE")
ax1.legend();

# %%
# --- Euler rollout ---
def rollout(idx=0, dt_eval=DT, on_train=False):
    if on_train:
        cn_true = cn_train
        cp_true = cp_train
        I_true = I_train
    else:
        cn_true = cn_test
        cp_true = cp_test
        I_true = I_test

    model.eval()

    # Original time grid (training resolution)
    t_train = np.arange(T) * DT

    # Interpolate I onto the new dt grid
    def I_t(t):  
        return float(np.interp(t, t_train, I_true[idx, :, 0]))  # Value at time t

    # Pre-allocate generously
    max_steps = int(T_HORIZON / dt_eval)
    cn_traj = np.zeros(max_steps, dtype=np.float32)
    cp_traj = np.zeros(max_steps, dtype=np.float32)
    cn_dot_traj = np.zeros(max_steps, dtype=np.float32)
    cp_dot_traj = np.zeros(max_steps, dtype=np.float32)
    cn_traj[0] = cn_true[idx, 0, 0]     # Initial un-normalized values for the chosen trajectory
    cp_traj[0] = cp_true[idx, 0, 0]
    
    V_traj = np.zeros(max_steps, dtype=np.float32)
    dG_dt_traj = np.zeros(max_steps, dtype=np.float32)
    Z_traj = np.zeros((max_steps, 2), dtype=np.float32)
    term1_traj = np.zeros((max_steps, 2), dtype=np.float32)
    term2_traj = np.zeros((max_steps, 2), dtype=np.float32)
    power_traj = np.zeros((max_steps), dtype=np.float32)

    steps_run = 1
    step = 0

    # Rollout until depletion
    while cn_traj[steps_run-1] >= cn_true[idx].min() and steps_run < max_steps:
        t_now = step * dt_eval

        x_t = torch.tensor([[
            transform(np.array([[[I_t(t_now)]]]),  "I")[0,0,0],  # True
            transform(np.array([[[cn_traj[step]]]]), "cn")[0,0,0],     # Predicted
            transform(np.array([[[cp_traj[step]]]]), "cp")[0,0,0],]], dtype=torch.float32).requires_grad_(True)      # Predicted                  # (1, 4)

        # Predict on initial state (1, 4)
        pred = model(x_t)              # (1, 2)
        xi_dot_pred, V_pred, dG_dt, Z_pred, term1, power = state_evolver(pred, x_t)  # (1, 2)
        dc_n = inverse_transform(xi_dot_pred[0,0].detach().item(), 'cn_dot')
        dc_p = inverse_transform(xi_dot_pred[0,1].detach().item(), 'cp_dot')

        cn_traj[step+1] = cn_traj[step] + dc_n * dt_eval
        cp_traj[step+1] = cp_traj[step] + dc_p * dt_eval
        cn_dot_traj[step] = dc_n
        cp_dot_traj[step] = dc_p

        # V_pred = inverse_transform(V_pred.detach().item(), 'V')
        V_traj[step] = V_pred
        dG_dt_traj[step] = dG_dt.detach().item()
        Z_traj[step] = Z_pred.detach().numpy()
        term1_traj[step] = term1.detach().numpy()
        power_traj[step] = power.detach().item()

        steps_run += 1
        step += 1

    # TODO: Trim to actual length ?
    return cn_traj, cp_traj, cn_dot_traj, cp_dot_traj, V_traj, dG_dt_traj, Z_traj, term1_traj, power_traj, steps_run

# %%
# --- Plot rollout ---
def plot_rollout(cn_euler, cp_euler, cn_dot_euler, cp_dot_euler, steps_run, 
                 idx=0, dt_eval=DT, on_train=False):
    if on_train:
        cn_true = cn_train
        cp_true = cp_train
        cn_dot_true = cn_dot_train
        I_true = I_train
        dI_true = dI_train
    else:
        cn_true = cn_test
        cp_true = cp_test
        cn_dot_true = cn_dot_test
        I_true = I_test
        dI_true = dI_test


    # Ground truth valid length
    n_gt = int(mask_train_plot[idx].sum())          # number of valid GT steps
    n_nn = steps_run                          # number of NN steps before stopping
    t_gt = np.arange(n_gt) * DT             # physical time axis for GT
    t_nn = np.arange(n_nn) * dt_eval             # physical time axis at new resolution
    

    fig, axes = plt.subplots(1, 5, figsize=(20, 4))

    cn_err = (cn_true[idx, :n_nn, 0] - cn_euler[:n_nn]) / (cn_true[idx, :n_nn, 0])

    # --- cn err ---
    axes[0].bar(t_nn, cn_err, color="tab:blue")
    axes[0].set_xlabel("Time [s]")
    axes[0].set_ylabel("Relative error in $c_n$ [a.u.]")

    # --- cn ---
    axes[1].plot(t_gt, cn_true[idx, :n_gt, 0], color="tab:red", linestyle="dashed", label="True $c_n$")
    axes[1].plot(t_nn, cn_euler[:n_nn], color="tab:blue", label="Predicted $c_n$")
    axes[1].set_xlabel("Time [s]")
    axes[1].set_ylabel(r"Concentration [mol/m$^3$]")
    axes[1].legend()

    # --- cp ---
    axes[2].plot(t_gt, cp_true[idx, :n_gt, 0], color="tab:red", linestyle="dashed", label="True $c_p$")
    axes[2].plot(t_nn, cp_euler[:n_nn], color="tab:blue", label="Predicted $c_p$")
    axes[2].set_xlabel("Time [s]")
    axes[2].set_ylabel(r"Concentration [mol/m$^3$]")
    axes[2].legend()

    # --- cn_dot ---
    axes[3].plot(t_gt, cn_dot_true[idx, :n_gt, 0], color="tab:red", linestyle="dashed", label="True $\\dot{c}_n$")
    axes[3].plot(t_nn, cn_dot_euler[:n_nn], color="tab:blue", label="Predicted $\\dot{c}_n$")
    axes[3].set_xlabel("Time [s]")
    axes[3].set_ylabel(r"Concentration rate [mol/m$^3$/s]")
    axes[3].legend()
    
    # --- current ---
    axes[4].plot(t_gt, I_train[idx, :n_gt, 0], color="black", label="$I$")
    axes[4].set_xlabel("Time [s]")
    axes[4].set_ylabel("Current [A]")
    axes[4].legend(loc='upper right')


    # --- dI ---
    axes3_ = axes[4].twinx()
    axes3_.plot(t_gt, dI_train[idx, :n_gt, 0], color="tab:red", linestyle="dashed", label="$\\dot{I}$")
    axes3_.set_ylabel(r"Current rate [A/s]")
    axes3_.legend(loc='upper left')

    plt.tight_layout()
    # plt.savefig('figs/5.1_predict_ep50_GRF.pdf')
    return t_gt, t_nn, n_gt, n_nn

# %%
idx = 2
dt_eval = 3.7
on_train = False
cn_euler, cp_euler, cn_dot_euler, cp_dot_euler, V_traj, dG_dt_traj, Z_traj, term1_traj, power_traj, steps_run = rollout(idx, dt_eval, on_train)
# Out:
# tensor([[3.7689]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7698]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7693]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7672]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7669]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7666]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7664]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7661]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7604]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7602]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7599]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7597]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7595]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7592]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7590]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7588]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7588]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7585]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7583]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7581]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7578]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7576]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7594]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7592]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7590]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7587]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7585]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7583]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7581]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7579]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7576]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7574]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7572]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7570]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7568]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7565]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7563]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7561]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7559]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7557]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7555]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7552]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7550]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7548]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7546]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7544]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7542]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7540]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7538]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7536]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7534]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7532]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7529]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7527]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7525]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7523]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7521]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7519]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7502]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7500]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7498]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7496]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7494]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7492]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7490]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7488]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7486]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7484]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7482]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7480]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7478]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7476]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7474]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7472]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7470]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7468]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7466]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7464]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7462]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7461]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7459]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7440]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7438]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7437]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7435]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7433]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7431]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7201]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7200]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7146]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7145]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7144]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7143]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7141]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7142]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7108]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7107]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7107]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7106]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7105]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7104]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7103]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7103]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7102]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7101]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7100]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7099]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7099]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7098]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7097]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7096]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7095]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7030]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7030]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7029]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7029]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7028]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.7028]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6989]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6974]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6974]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6973]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6973]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6973]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6972]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6972]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6971]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6971]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6970]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6970]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6969]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6969]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6969]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6968]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6966]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6967]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6966]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6966]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6965]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6965]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6964]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6963]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6963]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6962]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6962]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6961]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6940]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6939]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6939]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6938]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6938]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6937]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6936]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6936]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6935]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6935]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6934]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6934]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6933]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6933]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6932]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6914]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6913]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6913]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6912]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6884]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6884]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6884]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6883]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6883]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6883]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6882]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6882]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6849]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6849]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6849]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6849]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6819]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6819]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6781]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6781]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6744]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6744]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6744]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6744]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6701]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6701]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6701]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6701]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6701]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6701]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6701]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6701]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6701]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6701]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6701]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6699]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6699]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6704]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6704]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6704]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6719]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6719]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6719]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6719]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6720]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6720]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6720]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6720]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6720]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6700]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6700]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6700]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6700]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6685]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6686]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6686]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6686]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6686]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6681]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6825]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6825]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6825]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6810]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6810]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6810]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6777]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6777]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6794]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6794]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6794]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6795]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6770]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6727]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6727]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6727]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6727]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6727]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6728]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6688]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6688]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6688]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6688]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6688]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6688]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6688]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6689]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6689]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6689]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6656]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6656]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6656]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6656]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6656]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6656]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6656]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6656]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6657]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6657]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6657]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6657]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6657]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6657]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6629]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6630]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6630]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6630]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6630]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6630]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6630]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6630]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6630]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6630]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6630]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6630]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6631]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6631]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6631]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6657]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6657]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6658]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6646]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6646]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6646]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6646]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6646]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6646]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6646]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6647]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6647]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6647]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6621]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6621]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6621]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6632]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6632]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6632]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6632]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6632]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6632]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6632]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6632]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6632]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6609]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6609]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6609]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6517]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6517]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6517]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6517]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6517]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6518]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6518]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6518]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6518]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6518]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6518]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6518]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6518]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6518]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6518]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6518]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6519]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6519]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6469]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6469]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6469]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6488]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6488]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6459]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6459]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6458]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6458]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6458]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6436]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6436]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6436]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6436]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6436]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6436]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6436]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6436]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6436]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6436]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6436]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6439]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6403]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6403]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6403]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6403]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6403]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6421]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6421]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6421]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6421]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6421]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6421]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6400]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6359]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6251]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6250]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6250]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6197]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6194]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6194]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6194]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6173]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6173]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6178]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6178]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6178]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6181]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6147]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6122]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6113]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6112]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6112]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6112]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6112]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6122]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6092]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6092]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6091]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6091]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6091]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6095]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6095]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6095]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6094]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6101]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6101]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6100]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6100]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6100]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6100]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6099]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6099]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6099]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6099]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6098]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6098]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6098]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6098]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6097]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6097]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6097]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6097]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6097]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6096]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6096]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6096]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6096]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6095]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6111]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6111]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6110]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6141]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6109]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6109]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6108]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6108]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6079]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6078]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6078]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6078]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6071]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6098]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6090]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6089]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6089]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6089]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6089]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6089]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6100]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6100]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6100]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6100]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6100]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6099]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6099]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6087]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6087]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6087]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6087]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6086]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6086]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6086]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6095]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6095]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6095]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6095]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6094]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6094]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6094]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6094]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6094]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6093]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6093]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6093]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6093]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6092]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6067]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6066]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6066]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6066]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6066]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6065]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6076]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6076]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6076]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6075]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6075]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6075]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6089]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6089]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6088]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6088]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6088]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6088]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6087]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6080]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6080]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6079]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6079]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6079]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6037]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6037]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6037]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.6037]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5985]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5985]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5985]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5984]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5984]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5984]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5983]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5983]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5983]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5982]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5982]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5982]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5981]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5981]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5981]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5980]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5980]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5986]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5986]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5985]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5985]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5985]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5984]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5984]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5984]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5984]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5977]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5976]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5976]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5976]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5975]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5975]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5975]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5974]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5974]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5974]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5952]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5952]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5952]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5951]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5951]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5951]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5950]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5950]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5949]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5949]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5952]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5951]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5951]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5951]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5950]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5950]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5950]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5949]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5949]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5964]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5963]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5963]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5963]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5962]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5962]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5962]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5948]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5948]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5947]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5947]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5947]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5946]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5946]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# ...
# tensor([[3.5642]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5641]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5640]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5640]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5639]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5638]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5563]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5562]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5561]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5560]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5559]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5558]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5557]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5556]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5555]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5554]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5554]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5498]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5497]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5495]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5494]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5491]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5490]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5489]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5488]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5487]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5486]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5485]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5484]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5483]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5482]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5481]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5479]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5478]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5477]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5476]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5475]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5474]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5473]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5472]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5471]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5470]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5453]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5452]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5363]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5361]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5360]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5359]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5358]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5356]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5293]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5291]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5290]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5289]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5287]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5286]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5284]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5283]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5282]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5280]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5279]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5277]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5276]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5275]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5273]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5258]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5256]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5255]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5253]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5252]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5250]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5249]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5247]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5246]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5244]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5243]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5241]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5240]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5238]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5237]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5235]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5234]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5232]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5231]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5229]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5228]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5227]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5225]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5224]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5222]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5221]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5219]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5189]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5187]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5186]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5173]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5172]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5170]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5168]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5167]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5165]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5163]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5161]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5160]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5158]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5156]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5155]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5153]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5151]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5150]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5135]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5133]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5131]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5129]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5127]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5126]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5124]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5122]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5120]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5119]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5117]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5115]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5113]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5111]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5110]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5108]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5106]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5104]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5102]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5101]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5099]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5097]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5095]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5093]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5092]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5090]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5088]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5089]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5087]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5085]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5083]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5082]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5080]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5078]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5076]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5074]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5073]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5071]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5069]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5067]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5101]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5099]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5098]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5096]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5094]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5092]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5095]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5093]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5091]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5089]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5088]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5106]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5104]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5103]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5101]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5099]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5098]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5096]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5094]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5092]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5084]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5083]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5081]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5079]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5078]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5076]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5074]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5073]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5071]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5069]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5067]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5066]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5064]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5062]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5061]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)
# tensor([[3.5059]], grad_fn=<AddBackward0>) tensor([[0.8361]], grad_fn=<AddBackward0>)

# %%
t_gt, t_nn, n_gt, n_nn = plot_rollout(cn_euler, cp_euler, cn_dot_euler, cp_dot_euler, steps_run, idx, dt_eval, on_train)

# %%
# --- Plot from state evolver ---
fig, axes = plt.subplots(1, 5, figsize=(20, 4))
axes[0].plot(t_nn[:n_nn-1], V_traj[:n_nn-1])            # TODO: trim to actual length
axes[0].plot(t_gt[:n_gt], V_test[idx, :n_gt, 0], color="tab:red", linestyle="dashed", label="True $V$")
axes[0].set_xlabel("Time [s]")
axes[0].set_ylabel("Voltage [V]")
axes[1].plot(t_nn[:n_nn-1], dG_dt_traj[:n_nn-1])
axes[1].set_xlabel("Time [s]")
axes[1].set_ylabel("dG/dt [J/s]")
axes[2].plot(t_nn[:n_nn], Z_traj[:n_nn, 0], label="z1")
axes[2].plot(t_nn[:n_nn], Z_traj[:n_nn, 1], label="z2", linestyle='--')
axes[2].set_xlabel("Time [s]")
axes[2].set_ylabel("Z (current coupling)")
axes[3].plot(t_nn[:n_nn], term1_traj[:n_nn, 0], label="Dissipation")
axes[3].plot(t_nn[:n_nn], term1_traj[:n_nn, 1], label="Dissipation", linestyle='--')
axes[3].set_xlabel("Time [s]")
axes[3].set_ylabel("Dissipation")
axes[4].plot(t_nn[:n_nn-1], power_traj[:n_nn-1], label="Power")
axes[4].set_xlabel("Time [s]")
axes[4].set_ylabel("Power")
fig.tight_layout()

# %%
# --- Reconstruct voltage ---
# Interpolate rollout concentrations onto the GT time grid
cn_euler_gt = np.interp(t_gt, t_nn, cn_euler[:n_nn])
cp_euler_gt = np.interp(t_gt, t_nn, cp_euler[:n_nn])

V_spm = SPM_eqs.V_terminal(I_test[idx, :n_gt, 0], cp_euler_gt, cn_euler_gt, param)
V_true = V_test[idx, :n_gt, 0]

# I_nn    = np.interp(t_nn, t_gt, I_test[idx, :n_gt, 0])
# V_true_nn = np.interp(t_nn, t_gt, V_test[idx, :n_gt, 0])

# V_spm = SPM_eqs.V_terminal(I_nn, cp_euler[:n_nn], cn_euler[:n_nn], param)

ocv = SPM_eqs.OCV(cn_test[idx, :n_gt, 0], cp_test[idx, :n_gt, 0])

err = V_spm - V_true
err = err[np.isfinite(err)]

fig , axes = plt.subplots(1, 5, figsize=(20, 3.5))
axes[0].plot(t_gt, V_spm, label='SPM V')
axes[0].set_xlabel("Time [s]")
axes[0].set_ylabel("SPM Voltage [V]")
axes[0].plot(t_gt, V_true, label='True V', linestyle="dashed", color="tab:red")
axes[0].legend()
axes[1].hist(err, bins=100, label='True V')
axes[1].set_xlabel("Voltage error [V]")
axes[1].set_ylabel("Count [a.u.]")
axes[2].bar(t_gt, err / np.max(np.abs(V_true)), label='OCV')
axes[2].set_xlabel("Time [s]")
axes[2].set_ylabel("Relative Voltage Error [V]")
axes[3].plot(V_true - ocv, label='SPM V - OCV')
axes[3].set_xlabel("Time [s]")
axes[3].set_ylabel("Voltage Error [V]")
axes[4].plot(I_test[idx, :n_gt, 0], label='Current')

plt.tight_layout()
# plt.savefig('figs/5.1_SPM_V_ep100.pdf')

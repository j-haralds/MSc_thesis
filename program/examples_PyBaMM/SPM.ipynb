# %% [markdown]
# # Single Particle Model (SPM)

# %% [markdown]
# ## Model Equations

# %% [markdown]
# The SPM consists of two spherically symmetric diffusion equations: one within a representative negative particle ($\text{k}=\text{n}$) and one within a representative positive particle ($\text{k}=\text{p}$). In the centre of the particle the standard no-flux condition is imposed. Since the SPM assumes that all particles in an electrode behave in exactly the same way, the flux on the surface of a particle is simply the current $I$ divided by the thickness of the electrode $L_{\text{k}}$. The concentration of lithium in electrode $\text{k}$ is denoted $c_{\text{k}}$ and the current is denoted by $I$. The model equations for the SPM are then:
# $$
# \frac{\partial c_{\text{s,k}}}{\partial t} = -\frac{1}{r_{\text{k}}^2} \frac{\partial}{\partial r_{\text{k}}} \left(r_{\text{k}}^2 N_{\text{s,k}}\right), \\
# N_{\text{s,k}} = -D_{\text{s,k}}(c_{\text{s,k}}) \frac{\partial c_{\text{s,k}}}{\partial r_{\text{k}}}, \quad \text{k} \in \text{n, p},
# $$
#
# $$
# N_{\text{s,k}}\big|_{r_{\text{k}}=0} = 0, \quad \text{k} \in \text{n, p}, \quad \ \ - N_{\text{s,k}}\big|_{r_{\text{k}}=1} =
# \begin{cases}
# 		  \frac{I}{Fa_{\text{n}}L_{\text{n}}}, \quad &\text{k}=\text{n}, \\
# 		  -\frac{I}{Fa_{\text{p}}L_{\text{p}}}, \quad &\text{k}=\text{p},
# \end{cases} \\
# c_{\text{s,k}}(r_{\text{k}},0) = c_{\text{s,k,0}}, \quad \text{k} \in \text{n, p},$$
# where $D_{\text{s,k}}$ is the diffusion coefficient in the solid, $N_{\text{s,k}}$ denotes the flux of lithium ions in the solid particle within the region $\text{k}$, and $r_{\text{k}} \in[0,1]$ is the radial coordinate of the particle in electrode $\text{k}$.
#
# ### Voltage Expression
# The voltage is obtained from the expression:
# $$
# V = U_{\text{p}}(c_{\text{p}})\big|_{r_{\text{p}}=1} - U_{\text{n}}(c_{\text{n}})\big|_{r_{\text{n}}=1} - \frac{2RT}{F}\sinh^{-1}\left(\frac{I}{2j_{\text{0,p}} a_{\text{p}}L_{\text{p}}}\right) - \frac{2RT}{F}\sinh^{-1}\left(\frac{I}{2j_{\text{0,n}} a_{\text{p}}L_{\text{n}}}\right)
# $$
# with the exchange current densities given by
# $$j_{\text{0,k}} =  (c_{\text{k}})^{1/2}(1-c_{\text{k}})^{1/2}  $$
#
# More details can be found in [[3]](#References).

# %% [markdown]
# ## Example solving SPM using PyBaMM
#
# Below we show how to solve the Single Particle Model, using the default geometry, mesh, parameters, discretisation and solver provided with PyBaMM. In this notebook we explicitly handle all the stages of setting up, processing and solving the model in order to explain them in detail. However, it is often simpler in practice to use the `Simulation` class, which handles many of the stages automatically, as shown [here](../simulations_and_experiments/simulation-class.ipynb).
#
# First we need to import `pybamm`, and then change our working directory to the root of the pybamm folder.

# %%
# %pip install "pybamm[plot,cite]" -q    # install PyBaMM if it is not installed
import os

# from IPython.display import clear_output
# %matplotlib inline

# jonatan = True
# import sys
# if jonatan:
#     sys.path.append("/Users/jonatanharaldsson/Library/CloudStorage/Dropbox/Utbildning/0_Hogskola/Pagaende_kurser/MSc_thesis/program")
#     import plot_settings
#     plot_settings.apply()

# if not jonatan:
#     pass
#     import plot_settings
#     plot_settings.apply()



# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np

import pybamm

os.chdir(pybamm.__path__[0] + "/..")
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We then create an instance of the SPM:

# %%
model = pybamm.lithium_ion.SPM()

# %% [markdown]
# The model object is a subtype of [pybamm.BaseModel](https://docs.pybamm.org/en/stable/source/api/models/base_models/base_model.html), and contains all the equations that define this particular model. For example, the `rhs` dict contained in `model` has a dictionary mapping variables such as $c_n$ to the equation representing its rate of change with time (i.e. $\partial{c_n}/\partial{t}$). We can see this explicitly by visualising this entry in the `rhs` dict:

# %%
variable = list(model.rhs.keys())[1]
equation = list(model.rhs.values())[1]
print("rhs equation for variable '", variable, "' is:")
equation.visualise("spm1.png")
# Out:
# 2026-01-29 12:51:16.498 - [ERROR] symbol.visualise(542): Please install graphviz>=2.42.2 to use dot exporter
# rhs equation for variable ' Throughput capacity [A.h] ' is:

# %% [markdown]
# ![spm1](spm1.png)

# %% [markdown]
# We need a geometry in which to define our model equations. In pybamm this is represented by the [pybamm.Geometry](https://docs.pybamm.org/en/stable/source/api/geometry/index.html) class. In this case we use the default geometry object defined by the model

# %%
geometry = model.default_geometry

# %% [markdown]
# This geometry object defines a number of domains, each with its own name, spatial variables and min/max limits (the latter are represented as equations similar to the rhs equation shown above). For instance, the SPM has the following domains:

# %%
print("SPM domains:")
for i, (k, v) in enumerate(geometry.items()):
    print(str(i + 1) + ".", k, "with variables:")
    for var, rng in v.items():
        if "min" in rng:
            print("  -(", rng["min"], ") <=", var, "<= (", rng["max"], ")")
        else:
            print(var, "=", rng["position"])
# Out:
# SPM domains:
# 1. negative electrode with variables:
#   -( 0 ) <= x_n <= ( Negative electrode thickness [m] )
# 2. separator with variables:
#   -( Negative electrode thickness [m] ) <= x_s <= ( Negative electrode thickness [m] + Separator thickness [m] )
# 3. positive electrode with variables:
#   -( Negative electrode thickness [m] + Separator thickness [m] ) <= x_p <= ( Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] )
# 4. negative particle with variables:
#   -( 0 ) <= r_n <= ( Negative particle radius [m] )
# 5. positive particle with variables:
#   -( 0 ) <= r_p <= ( Positive particle radius [m] )
# 6. current collector with variables:
# z = 1

# %% [markdown]
# Both the model equations and the geometry include parameters, such as $L_p$. We can substitute these symbolic parameters in the model with values by using the [pybamm.ParameterValues](https://docs.pybamm.org/en/stable/source/api/parameters/parameter_values.html) class, which takes either a python dictionary or CSV file with the mapping between parameter names and values. Rather than create our own instance of `pybamm.ParameterValues`, we will use the default parameter set included in the model

# %%
param = model.default_parameter_values

# %% [markdown]
# We can then apply this parameter set to the model and geometry

# %%
param.process_model(model)
param.process_geometry(geometry)

# %% [markdown]
# The next step is to mesh the input geometry. We can do this using the [pybamm.Mesh](https://docs.pybamm.org/en/stable/source/api/meshes/index.html) class. This class takes in the geometry of the problem, and also two dictionaries containing the type of mesh to use within each domain of the geometry (i.e. within the positive or negative electrode domains), and the number of mesh points.
#
# The default mesh types and the default number of points to use in each variable for the SPM are:

# %%
for k, t in model.default_submesh_types.items():
    print(k, "is of type", t.__name__)
for var, npts in model.default_var_pts.items():
    print(var, "has", npts, "mesh points")
# Out:
# negative electrode is of type Uniform1DSubMesh
# separator is of type Uniform1DSubMesh
# positive electrode is of type Uniform1DSubMesh
# negative particle is of type Uniform1DSubMesh
# positive particle is of type Uniform1DSubMesh
# negative primary particle is of type Uniform1DSubMesh
# positive primary particle is of type Uniform1DSubMesh
# negative secondary particle is of type Uniform1DSubMesh
# positive secondary particle is of type Uniform1DSubMesh
# negative particle size is of type Uniform1DSubMesh
# positive particle size is of type Uniform1DSubMesh
# negative primary particle size is of type Uniform1DSubMesh
# positive primary particle size is of type Uniform1DSubMesh
# negative secondary particle size is of type Uniform1DSubMesh
# positive secondary particle size is of type Uniform1DSubMesh
# current collector is of type SubMesh0D
# x_n has 20 mesh points
# x_s has 20 mesh points
# x_p has 20 mesh points
# r_n has 20 mesh points
# r_p has 20 mesh points
# r_n_prim has 20 mesh points
# r_p_prim has 20 mesh points
# r_n_sec has 20 mesh points
# r_p_sec has 20 mesh points
# y has 10 mesh points
# z has 10 mesh points
# R_n has 30 mesh points
# R_p has 30 mesh points
# R_n_prim has 30 mesh points
# R_p_prim has 30 mesh points
# R_n_sec has 30 mesh points
# R_p_sec has 30 mesh points

# %% [markdown]
# With these defaults, we can then create our mesh of the given geometry:

# %%
mesh = pybamm.Mesh(geometry, model.default_submesh_types, model.default_var_pts)

# %% [markdown]
# The next step is to discretise the model equations using this mesh. We do this using the [pybamm.Discretisation](https://docs.pybamm.org/en/stable/source/api/spatial_methods/discretisation.html) class, which takes both the mesh we have already created, and a dictionary of spatial methods to use for each geometry domain. For the case of the SPM, we use the following defaults for the spatial discretisation methods:

# %%
for k, method in model.default_spatial_methods.items():
    print(k, "is discretised using", method.__class__.__name__, "method")
# Out:
# macroscale is discretised using FiniteVolume method
# negative particle is discretised using FiniteVolume method
# positive particle is discretised using FiniteVolume method
# negative primary particle is discretised using FiniteVolume method
# positive primary particle is discretised using FiniteVolume method
# negative secondary particle is discretised using FiniteVolume method
# positive secondary particle is discretised using FiniteVolume method
# negative particle size is discretised using FiniteVolume method
# positive particle size is discretised using FiniteVolume method
# negative primary particle size is discretised using FiniteVolume method
# positive primary particle size is discretised using FiniteVolume method
# negative secondary particle size is discretised using FiniteVolume method
# positive secondary particle size is discretised using FiniteVolume method
# current collector is discretised using ZeroDimensionalSpatialMethod method

# %% [markdown]
# We then create the `pybamm.Discretisation` object, and use this to discretise the model equations

# %%
disc = pybamm.Discretisation(mesh, model.default_spatial_methods)
disc.process_model(model)

# %% [markdown]
# After this stage, all of the variables in `model` have been discretised into `pybamm.StateVector` objects, and spatial operators have been replaced by matrix-vector multiplications, ready to be evaluated within a time-stepping algorithm of a given solver. For example, the rhs expression for $\partial{c_n}/\partial{t}$ that we visualised above is now represented by:

# %%
model.concatenated_rhs.children[1].visualise("spm2.png")
# Out:
# 2026-01-29 12:51:31.946 - [ERROR] symbol.visualise(542): Please install graphviz>=2.42.2 to use dot exporter

# %% [markdown]
# ![spm2](spm2.png)
#
# Now we are ready to run the time-stepping routine to solve the model. Once again we use the default ODE solver.

# %%
# Solve the model at the given time points (in seconds)
solver = model.default_solver
n = 250
t_eval = np.linspace(0, 3600, n)
print("Solving using", type(solver).__name__, "solver...")
solution = solver.solve(model, t_eval)
print("Finished.")
# Out:
# Solving using IDAKLUSolver solver...
# Finished.

# %% [markdown]
# Each model in pybamm has a list of relevant variables defined in the model, for use in visualising the model solution or for comparison with other models. The SPM defines the following variables:

# %%
print("SPM model variables:")
for v,V in zip(model.variables.keys(), model.variables.values()):
    print(f"\t- {v}\t\t{V}")
# Out:
# SPM model variables:
# 	- Time [s]		time
# 	- Time [min]		0.016666666666666666 * time
# 	- Time [h]		0.0002777777777777778 * time
# 	- x [m]		x
# 	- x_n [m]		x_n
# 	- x_s [m]		x_s
# 	- x_p [m]		x_p
# 	- r_n [m]		r_n
# 	- r_p [m]		r_p
# 	- Current variable [A]		Current function [A]
# 	- Total current density [A.m-2]		Current function [A] / (Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell)
# 	- Current [A]		Current function [A]
# 	- C-rate		Current function [A] / Nominal cell capacity [A.h]
# 	- Discharge capacity [A.h]		Discharge capacity [A.h]
# 	- Throughput capacity [A.h]		Throughput capacity [A.h]
# 	- Discharge energy [W.h]		0.0
# 	- Throughput energy [W.h]		0.0
# 	- Porosity		concatenation(Negative electrode porosity, Separator porosity, Positive electrode porosity)
# 	- Negative electrode porosity		Negative electrode porosity
# 	- X-averaged negative electrode porosity		x-average(Negative electrode porosity)
# 	- Separator porosity		Separator porosity
# 	- X-averaged separator porosity		x-average(Separator porosity)
# 	- Positive electrode porosity		Positive electrode porosity
# 	- X-averaged positive electrode porosity		x-average(Positive electrode porosity)
# 	- Porosity change		broadcast(0.0)
# 	- Negative electrode porosity change [s-1]		broadcast(0.0)
# 	- X-averaged negative electrode porosity change [s-1]		broadcast(0.0)
# 	- Separator porosity change [s-1]		broadcast(0.0)
# 	- X-averaged separator porosity change [s-1]		broadcast(0.0)
# 	- Positive electrode porosity change [s-1]		broadcast(0.0)
# 	- X-averaged positive electrode porosity change [s-1]		broadcast(0.0)
# 	- Negative electrode interface utilisation variable		broadcast(1.0)
# 	- X-averaged negative electrode interface utilisation variable		broadcast(1.0)
# 	- Negative electrode interface utilisation		broadcast(1.0)
# 	- X-averaged negative electrode interface utilisation		broadcast(1.0)
# 	- Positive electrode interface utilisation variable		broadcast(1.0)
# 	- X-averaged positive electrode interface utilisation variable		broadcast(1.0)
# 	- Positive electrode interface utilisation		broadcast(1.0)
# 	- X-averaged positive electrode interface utilisation		broadcast(1.0)
# 	- Negative particle crack length [m]		broadcast(0.0)
# 	- X-averaged negative particle crack length [m]		broadcast(0.0)
# 	- Negative particle cracking rate [m.s-1]		broadcast(0.0)
# 	- X-averaged negative particle cracking rate [m.s-1]		broadcast(0.0)
# 	- Positive particle crack length [m]		broadcast(0.0)
# 	- X-averaged positive particle crack length [m]		broadcast(0.0)
# 	- Positive particle cracking rate [m.s-1]		broadcast(0.0)
# 	- X-averaged positive particle cracking rate [m.s-1]		broadcast(0.0)
# 	- Negative electrode active material volume fraction		Negative electrode active material volume fraction
# 	- X-averaged negative electrode active material volume fraction		x-average(Negative electrode active material volume fraction)
# 	- Negative electrode capacity [A.h]		0.0002777777777777778 * yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * Maximum concentration in negative electrode [mol.m-3] * F
# 	- Negative particle radius		Negative particle radius [m] / Negative particle radius [m]
# 	- Negative particle radius [m]		Negative particle radius [m]
# 	- X-averaged negative particle radius [m]		x-average(Negative particle radius [m])
# 	- Negative electrode surface area to volume ratio [m-1]		3.0 * Negative electrode active material volume fraction / Negative particle radius [m]
# 	- X-averaged negative electrode surface area to volume ratio [m-1]		x-average(3.0 * Negative electrode active material volume fraction / Negative particle radius [m])
# 	- Negative electrode active material volume fraction change [s-1]		broadcast(0.0)
# 	- X-averaged negative electrode active material volume fraction change [s-1]		broadcast(0.0)
# 	- Loss of lithium due to loss of active material in negative electrode [mol]		0.0
# 	- Positive electrode active material volume fraction		Positive electrode active material volume fraction
# 	- X-averaged positive electrode active material volume fraction		x-average(Positive electrode active material volume fraction)
# 	- Positive electrode capacity [A.h]		0.0002777777777777778 * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * Maximum concentration in positive electrode [mol.m-3] * F
# 	- Positive particle radius		Positive particle radius [m] / Positive particle radius [m]
# 	- Positive particle radius [m]		Positive particle radius [m]
# 	- X-averaged positive particle radius [m]		x-average(Positive particle radius [m])
# 	- Positive electrode surface area to volume ratio [m-1]		3.0 * Positive electrode active material volume fraction / Positive particle radius [m]
# 	- X-averaged positive electrode surface area to volume ratio [m-1]		x-average(3.0 * Positive electrode active material volume fraction / Positive particle radius [m])
# 	- Positive electrode active material volume fraction change [s-1]		broadcast(0.0)
# 	- X-averaged positive electrode active material volume fraction change [s-1]		broadcast(0.0)
# 	- Loss of lithium due to loss of active material in positive electrode [mol]		0.0
# 	- Separator pressure [Pa]		broadcast(broadcast(0.0))
# 	- X-averaged separator pressure [Pa]		broadcast(0.0)
# 	- negative electrode transverse volume-averaged velocity [m.s-1]		broadcast(broadcast(0.0))
# 	- X-averaged negative electrode transverse volume-averaged velocity [m.s-1]		broadcast(0.0)
# 	- separator transverse volume-averaged velocity [m.s-1]		broadcast(broadcast(0.0))
# 	- X-averaged separator transverse volume-averaged velocity [m.s-1]		broadcast(0.0)
# 	- positive electrode transverse volume-averaged velocity [m.s-1]		broadcast(broadcast(0.0))
# 	- X-averaged positive electrode transverse volume-averaged velocity [m.s-1]		broadcast(0.0)
# 	- Transverse volume-averaged velocity [m.s-1]		broadcast(broadcast(0.0))
# 	- negative electrode transverse volume-averaged acceleration [m.s-2]		broadcast(broadcast(0.0))
# 	- X-averaged negative electrode transverse volume-averaged acceleration [m.s-2]		broadcast(0.0)
# 	- separator transverse volume-averaged acceleration [m.s-2]		broadcast(broadcast(0.0))
# 	- X-averaged separator transverse volume-averaged acceleration [m.s-2]		broadcast(0.0)
# 	- positive electrode transverse volume-averaged acceleration [m.s-2]		broadcast(broadcast(0.0))
# 	- X-averaged positive electrode transverse volume-averaged acceleration [m.s-2]		broadcast(0.0)
# 	- Transverse volume-averaged acceleration [m.s-2]		broadcast(broadcast(0.0))
# 	- Negative electrode volume-averaged velocity [m.s-1]		broadcast(0.0)
# 	- Negative electrode volume-averaged acceleration [m.s-2]		broadcast(0.0)
# 	- X-averaged negative electrode volume-averaged acceleration [m.s-2]		broadcast(0.0)
# 	- Negative electrode pressure [Pa]		broadcast(0.0)
# 	- X-averaged negative electrode pressure [Pa]		broadcast(0.0)
# 	- Positive electrode volume-averaged velocity [m.s-1]		broadcast(0.0)
# 	- Positive electrode volume-averaged acceleration [m.s-2]		broadcast(0.0)
# 	- X-averaged positive electrode volume-averaged acceleration [m.s-2]		broadcast(0.0)
# 	- Positive electrode pressure [Pa]		broadcast(0.0)
# 	- X-averaged positive electrode pressure [Pa]		broadcast(0.0)
# 	- Negative particle concentration [mol.m-3]		broadcast(X-averaged negative particle concentration [mol.m-3])
# 	- X-averaged negative particle concentration [mol.m-3]		X-averaged negative particle concentration [mol.m-3]
# 	- R-averaged negative particle concentration [mol.m-3]		broadcast(r-average(X-averaged negative particle concentration [mol.m-3]))
# 	- Average negative particle concentration [mol.m-3]		r-average(X-averaged negative particle concentration [mol.m-3])
# 	- Negative particle surface concentration [mol.m-3]		broadcast(boundary value(X-averaged negative particle concentration [mol.m-3]))
# 	- X-averaged negative particle surface concentration [mol.m-3]		boundary value(X-averaged negative particle concentration [mol.m-3])
# 	- Minimum negative particle concentration [mol.m-3]		min(broadcast(X-averaged negative particle concentration [mol.m-3]))
# 	- Maximum negative particle concentration [mol.m-3]		max(broadcast(X-averaged negative particle concentration [mol.m-3]))
# 	- Minimum negative particle Minimum negative particle surface concentration [mol.m-3]		min(broadcast(boundary value(X-averaged negative particle concentration [mol.m-3])))
# 	- Maximum negative particle surface concentration [mol.m-3]		max(broadcast(boundary value(X-averaged negative particle concentration [mol.m-3])))
# 	- Negative particle concentration		broadcast(X-averaged negative particle concentration [mol.m-3] / Maximum concentration in negative electrode [mol.m-3])
# 	- X-averaged negative particle concentration		X-averaged negative particle concentration [mol.m-3] / Maximum concentration in negative electrode [mol.m-3]
# 	- R-averaged negative particle concentration		broadcast(r-average(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3])
# 	- Average negative particle concentration		r-average(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3]
# 	- Negative particle surface concentration		broadcast(boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3])
# 	- X-averaged negative particle surface concentration		boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3]
# 	- Minimum negative particle concentration		min(broadcast(X-averaged negative particle concentration [mol.m-3])) / Maximum concentration in negative electrode [mol.m-3]
# 	- Maximum negative particle concentration		max(broadcast(X-averaged negative particle concentration [mol.m-3])) / Maximum concentration in negative electrode [mol.m-3]
# 	- Minimum negative particle surface concentration		min(broadcast(boundary value(X-averaged negative particle concentration [mol.m-3]))) / Maximum concentration in negative electrode [mol.m-3]
# 	- Maximum negative particle surface concentration		max(broadcast(boundary value(X-averaged negative particle concentration [mol.m-3]))) / Maximum concentration in negative electrode [mol.m-3]
# 	- Negative particle stoichiometry		broadcast(X-averaged negative particle concentration [mol.m-3] / Maximum concentration in negative electrode [mol.m-3])
# 	- X-averaged negative particle stoichiometry		X-averaged negative particle concentration [mol.m-3] / Maximum concentration in negative electrode [mol.m-3]
# 	- R-averaged negative particle stoichiometry		broadcast(r-average(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3])
# 	- Average negative particle stoichiometry		r-average(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3]
# 	- Negative particle surface stoichiometry		broadcast(boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3])
# 	- X-averaged negative particle surface stoichiometry		boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3]
# 	- Minimum negative particle stoichiometry		min(broadcast(X-averaged negative particle concentration [mol.m-3])) / Maximum concentration in negative electrode [mol.m-3]
# 	- Maximum negative particle stoichiometry		max(broadcast(X-averaged negative particle concentration [mol.m-3])) / Maximum concentration in negative electrode [mol.m-3]
# 	- Minimum negative particle surface stoichiometry		min(broadcast(boundary value(X-averaged negative particle concentration [mol.m-3]))) / Maximum concentration in negative electrode [mol.m-3]
# 	- Maximum negative particle surface stoichiometry		max(broadcast(boundary value(X-averaged negative particle concentration [mol.m-3]))) / Maximum concentration in negative electrode [mol.m-3]
# 	- Negative electrode extent of lithiation		broadcast(r-average(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3])
# 	- X-averaged negative electrode extent of lithiation		r-average(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3]
# 	- Positive particle concentration [mol.m-3]		broadcast(X-averaged positive particle concentration [mol.m-3])
# 	- X-averaged positive particle concentration [mol.m-3]		X-averaged positive particle concentration [mol.m-3]
# 	- R-averaged positive particle concentration [mol.m-3]		broadcast(r-average(X-averaged positive particle concentration [mol.m-3]))
# 	- Average positive particle concentration [mol.m-3]		r-average(X-averaged positive particle concentration [mol.m-3])
# 	- Positive particle surface concentration [mol.m-3]		broadcast(boundary value(X-averaged positive particle concentration [mol.m-3]))
# 	- X-averaged positive particle surface concentration [mol.m-3]		boundary value(X-averaged positive particle concentration [mol.m-3])
# 	- Minimum positive particle concentration [mol.m-3]		min(broadcast(X-averaged positive particle concentration [mol.m-3]))
# 	- Maximum positive particle concentration [mol.m-3]		max(broadcast(X-averaged positive particle concentration [mol.m-3]))
# 	- Minimum positive particle Minimum positive particle surface concentration [mol.m-3]		min(broadcast(boundary value(X-averaged positive particle concentration [mol.m-3])))
# 	- Maximum positive particle surface concentration [mol.m-3]		max(broadcast(boundary value(X-averaged positive particle concentration [mol.m-3])))
# 	- Positive particle concentration		broadcast(X-averaged positive particle concentration [mol.m-3] / Maximum concentration in positive electrode [mol.m-3])
# 	- X-averaged positive particle concentration		X-averaged positive particle concentration [mol.m-3] / Maximum concentration in positive electrode [mol.m-3]
# 	- R-averaged positive particle concentration		broadcast(r-average(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3])
# 	- Average positive particle concentration		r-average(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3]
# 	- Positive particle surface concentration		broadcast(boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3])
# 	- X-averaged positive particle surface concentration		boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3]
# 	- Minimum positive particle concentration		min(broadcast(X-averaged positive particle concentration [mol.m-3])) / Maximum concentration in positive electrode [mol.m-3]
# 	- Maximum positive particle concentration		max(broadcast(X-averaged positive particle concentration [mol.m-3])) / Maximum concentration in positive electrode [mol.m-3]
# 	- Minimum positive particle surface concentration		min(broadcast(boundary value(X-averaged positive particle concentration [mol.m-3]))) / Maximum concentration in positive electrode [mol.m-3]
# 	- Maximum positive particle surface concentration		max(broadcast(boundary value(X-averaged positive particle concentration [mol.m-3]))) / Maximum concentration in positive electrode [mol.m-3]
# 	- Positive particle stoichiometry		broadcast(X-averaged positive particle concentration [mol.m-3] / Maximum concentration in positive electrode [mol.m-3])
# 	- X-averaged positive particle stoichiometry		X-averaged positive particle concentration [mol.m-3] / Maximum concentration in positive electrode [mol.m-3]
# 	- R-averaged positive particle stoichiometry		broadcast(r-average(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3])
# 	- Average positive particle stoichiometry		r-average(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3]
# 	- Positive particle surface stoichiometry		broadcast(boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3])
# 	- X-averaged positive particle surface stoichiometry		boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3]
# 	- Minimum positive particle stoichiometry		min(broadcast(X-averaged positive particle concentration [mol.m-3])) / Maximum concentration in positive electrode [mol.m-3]
# 	- Maximum positive particle stoichiometry		max(broadcast(X-averaged positive particle concentration [mol.m-3])) / Maximum concentration in positive electrode [mol.m-3]
# 	- Minimum positive particle surface stoichiometry		min(broadcast(boundary value(X-averaged positive particle concentration [mol.m-3]))) / Maximum concentration in positive electrode [mol.m-3]
# 	- Maximum positive particle surface stoichiometry		max(broadcast(boundary value(X-averaged positive particle concentration [mol.m-3]))) / Maximum concentration in positive electrode [mol.m-3]
# 	- Positive electrode extent of lithiation		broadcast(r-average(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3])
# 	- X-averaged positive electrode extent of lithiation		r-average(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3]
# 	- Porosity times concentration [mol.m-3]		concatenation(Negative electrode porosity * Initial concentration in electrolyte [mol.m-3], Separator porosity * Initial concentration in electrolyte [mol.m-3], Positive electrode porosity * Initial concentration in electrolyte [mol.m-3])
# 	- Negative electrode porosity times concentration [mol.m-3]		Negative electrode porosity * Initial concentration in electrolyte [mol.m-3]
# 	- Separator porosity times concentration [mol.m-3]		Separator porosity * Initial concentration in electrolyte [mol.m-3]
# 	- Positive electrode porosity times concentration [mol.m-3]		Positive electrode porosity * Initial concentration in electrolyte [mol.m-3]
# 	- Total lithium in electrolyte [mol]		(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity * Initial concentration in electrolyte [mol.m-3]) + Separator thickness [m] * x-average(Separator porosity * Initial concentration in electrolyte [mol.m-3]) + Positive electrode thickness [m] * x-average(Positive electrode porosity * Initial concentration in electrolyte [mol.m-3])) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]))
# 	- Electrolyte flux [mol.m-2.s-1]		broadcast to edges(0.0)
# 	- Ambient temperature [K]		Ambient temperature [K]
# 	- Volume-averaged ambient temperature [K]		z-average(Ambient temperature [K])
# 	- Cell temperature [K]		broadcast(Ambient temperature [K])
# 	- Negative current collector temperature [K]		Ambient temperature [K]
# 	- Positive current collector temperature [K]		Ambient temperature [K]
# 	- X-averaged cell temperature [K]		Ambient temperature [K]
# 	- Volume-averaged cell temperature [K]		z-average(Ambient temperature [K])
# 	- Negative electrode temperature [K]		broadcast(Ambient temperature [K])
# 	- X-averaged negative electrode temperature [K]		Ambient temperature [K]
# 	- Separator temperature [K]		broadcast(Ambient temperature [K])
# 	- X-averaged separator temperature [K]		Ambient temperature [K]
# 	- Positive electrode temperature [K]		broadcast(Ambient temperature [K])
# 	- X-averaged positive electrode temperature [K]		Ambient temperature [K]
# 	- Ambient temperature [C]		-273.15 + Ambient temperature [K]
# 	- Volume-averaged ambient temperature [C]		-273.15 + z-average(Ambient temperature [K])
# 	- Cell temperature [C]		broadcast(-273.15 + Ambient temperature [K])
# 	- Negative current collector temperature [C]		-273.15 + Ambient temperature [K]
# 	- Positive current collector temperature [C]		-273.15 + Ambient temperature [K]
# 	- X-averaged cell temperature [C]		-273.15 + Ambient temperature [K]
# 	- Volume-averaged cell temperature [C]		-273.15 + z-average(Ambient temperature [K])
# 	- Negative electrode temperature [C]		broadcast(-273.15 + Ambient temperature [K])
# 	- X-averaged negative electrode temperature [C]		-273.15 + Ambient temperature [K]
# 	- Separator temperature [C]		broadcast(-273.15 + Ambient temperature [K])
# 	- X-averaged separator temperature [C]		-273.15 + Ambient temperature [K]
# 	- Positive electrode temperature [C]		broadcast(-273.15 + Ambient temperature [K])
# 	- X-averaged positive electrode temperature [C]		-273.15 + Ambient temperature [K]
# 	- Negative current collector potential [V]		broadcast(0.0)
# 	- Negative SEI concentration [mol.m-3]		broadcast(0.0)
# 	- X-averaged negative SEI concentration [mol.m-3]		broadcast(0.0)
# 	- Volume-averaged negative SEI concentration [mol.m-3]		0.0
# 	- Loss of lithium to negative SEI [mol]		0.0
# 	- Loss of capacity to negative SEI [A.h]		0.0
# 	- Negative electrode SEI interfacial current density [A.m-2]		broadcast(0.0)
# 	- X-averaged negative electrode SEI interfacial current density [A.m-2]		broadcast(0.0)
# 	- Positive SEI concentration [mol.m-3]		broadcast(0.0)
# 	- X-averaged positive SEI concentration [mol.m-3]		broadcast(0.0)
# 	- Volume-averaged positive SEI concentration [mol.m-3]		0.0
# 	- Loss of lithium to positive SEI [mol]		0.0
# 	- Loss of capacity to positive SEI [A.h]		0.0
# 	- Positive electrode SEI interfacial current density [A.m-2]		broadcast(0.0)
# 	- X-averaged positive electrode SEI interfacial current density [A.m-2]		broadcast(0.0)
# 	- Negative SEI on cracks concentration [mol.m-3]		broadcast(0.0)
# 	- X-averaged negative SEI on cracks concentration [mol.m-3]		broadcast(0.0)
# 	- Volume-averaged negative SEI on cracks concentration [mol.m-3]		0.0
# 	- Loss of lithium to negative SEI on cracks [mol]		0.0
# 	- Loss of capacity to negative SEI on cracks [A.h]		0.0
# 	- Negative electrode SEI on cracks interfacial current density [A.m-2]		broadcast(0.0)
# 	- X-averaged negative electrode SEI on cracks interfacial current density [A.m-2]		broadcast(0.0)
# 	- Positive SEI on cracks concentration [mol.m-3]		broadcast(0.0)
# 	- X-averaged positive SEI on cracks concentration [mol.m-3]		broadcast(0.0)
# 	- Volume-averaged positive SEI on cracks concentration [mol.m-3]		0.0
# 	- Loss of lithium to positive SEI on cracks [mol]		0.0
# 	- Loss of capacity to positive SEI on cracks [A.h]		0.0
# 	- Positive electrode SEI on cracks interfacial current density [A.m-2]		broadcast(0.0)
# 	- X-averaged positive electrode SEI on cracks interfacial current density [A.m-2]		broadcast(0.0)
# 	- Negative lithium plating concentration [mol.m-3]		broadcast(0.0)
# 	- X-averaged negative lithium plating concentration [mol.m-3]		broadcast(0.0)
# 	- Volume-averaged negative lithium plating concentration [mol.m-3]		0.0
# 	- Negative dead lithium concentration [mol.m-3]		broadcast(0.0)
# 	- X-averaged negative dead lithium concentration [mol.m-3]		broadcast(0.0)
# 	- Volume-averaged negative dead lithium concentration [mol.m-3]		0.0
# 	- Negative lithium plating thickness [m]		broadcast(0.0)
# 	- X-averaged negative lithium plating thickness [m]		broadcast(0.0)
# 	- Volume-averaged negative lithium plating thickness [m]		0.0
# 	- Negative dead lithium thickness [m]		broadcast(0.0)
# 	- X-averaged negative dead lithium thickness [m]		broadcast(0.0)
# 	- Volume-averaged negative dead lithium thickness [m]		0.0
# 	- Loss of lithium to negative lithium plating [mol]		0.0
# 	- Loss of capacity to negative lithium plating [A.h]		0.0
# 	- Negative electrode lithium plating interfacial current density [A.m-2]		broadcast(0.0)
# 	- X-averaged negative electrode lithium plating interfacial current density [A.m-2]		broadcast(0.0)
# 	- Negative electrode lithium plating reaction overpotential [V]		broadcast(0.0)
# 	- X-averaged negative electrode lithium plating reaction overpotential [V]		broadcast(0.0)
# 	- Positive lithium plating concentration [mol.m-3]		broadcast(0.0)
# 	- X-averaged positive lithium plating concentration [mol.m-3]		broadcast(0.0)
# 	- Volume-averaged positive lithium plating concentration [mol.m-3]		0.0
# 	- Positive dead lithium concentration [mol.m-3]		broadcast(0.0)
# 	- X-averaged positive dead lithium concentration [mol.m-3]		broadcast(0.0)
# 	- Volume-averaged positive dead lithium concentration [mol.m-3]		0.0
# 	- Positive lithium plating thickness [m]		broadcast(0.0)
# 	- X-averaged positive lithium plating thickness [m]		broadcast(0.0)
# 	- Volume-averaged positive lithium plating thickness [m]		0.0
# 	- Positive dead lithium thickness [m]		broadcast(0.0)
# 	- X-averaged positive dead lithium thickness [m]		broadcast(0.0)
# 	- Volume-averaged positive dead lithium thickness [m]		0.0
# 	- Loss of lithium to positive lithium plating [mol]		0.0
# 	- Loss of capacity to positive lithium plating [A.h]		0.0
# 	- Positive electrode lithium plating interfacial current density [A.m-2]		broadcast(0.0)
# 	- X-averaged positive electrode lithium plating interfacial current density [A.m-2]		broadcast(0.0)
# 	- Positive electrode lithium plating reaction overpotential [V]		broadcast(0.0)
# 	- X-averaged positive electrode lithium plating reaction overpotential [V]		broadcast(0.0)
# 	- Negative crack surface to volume ratio [m-1]		broadcast(0.0)
# 	- Negative electrode roughness ratio		broadcast(1.0)
# 	- X-averaged negative electrode roughness ratio		broadcast(1.0)
# 	- Positive crack surface to volume ratio [m-1]		broadcast(0.0)
# 	- Positive electrode roughness ratio		broadcast(1.0)
# 	- X-averaged positive electrode roughness ratio		broadcast(1.0)
# 	- Electrolyte transport efficiency		concatenation(Negative electrode porosity ** Negative electrode Bruggeman coefficient (electrolyte), Separator porosity ** Separator Bruggeman coefficient (electrolyte), Positive electrode porosity ** Positive electrode Bruggeman coefficient (electrolyte))
# 	- Negative electrolyte transport efficiency		Negative electrode porosity ** Negative electrode Bruggeman coefficient (electrolyte)
# 	- X-averaged negative electrolyte transport efficiency		x-average(Negative electrode porosity ** Negative electrode Bruggeman coefficient (electrolyte))
# 	- Separator electrolyte transport efficiency		Separator porosity ** Separator Bruggeman coefficient (electrolyte)
# 	- X-averaged separator electrolyte transport efficiency		x-average(Separator porosity ** Separator Bruggeman coefficient (electrolyte))
# 	- Positive electrolyte transport efficiency		Positive electrode porosity ** Positive electrode Bruggeman coefficient (electrolyte)
# 	- X-averaged positive electrolyte transport efficiency		x-average(Positive electrode porosity ** Positive electrode Bruggeman coefficient (electrolyte))
# 	- Electrode transport efficiency		concatenation((1.0 - Negative electrode porosity) ** Negative electrode Bruggeman coefficient (electrode), broadcast(0.0), (1.0 - Positive electrode porosity) ** Positive electrode Bruggeman coefficient (electrode))
# 	- Negative electrode transport efficiency		(1.0 - Negative electrode porosity) ** Negative electrode Bruggeman coefficient (electrode)
# 	- X-averaged negative electrode transport efficiency		x-average((1.0 - Negative electrode porosity) ** Negative electrode Bruggeman coefficient (electrode))
# 	- Separator electrode transport efficiency		broadcast(0.0)
# 	- X-averaged separator electrode transport efficiency		broadcast(0.0)
# 	- Positive electrode transport efficiency		(1.0 - Positive electrode porosity) ** Positive electrode Bruggeman coefficient (electrode)
# 	- X-averaged positive electrode transport efficiency		x-average((1.0 - Positive electrode porosity) ** Positive electrode Bruggeman coefficient (electrode))
# 	- Separator volume-averaged velocity [m.s-1]		broadcast(0.0)
# 	- Separator volume-averaged acceleration [m.s-2]		broadcast(0.0)
# 	- X-averaged separator volume-averaged acceleration [m.s-2]		broadcast(0.0)
# 	- Volume-averaged velocity [m.s-1]		broadcast(0.0)
# 	- Volume-averaged acceleration [m.s-1]		broadcast(0.0)
# 	- X-averaged volume-averaged acceleration [m.s-1]		broadcast(0.0)
# 	- Pressure [Pa]		concatenation(broadcast(0.0), broadcast(broadcast(0.0)), broadcast(0.0))
# 	- Negative electrode stoichiometry		x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3]))) / x-average(Negative electrode active material volume fraction) / Maximum concentration in negative electrode [mol.m-3]
# 	- Negative electrode volume-averaged concentration		x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3]))) / x-average(Negative electrode active material volume fraction) / Maximum concentration in negative electrode [mol.m-3]
# 	- Negative electrode volume-averaged concentration [mol.m-3]		x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3]))) / x-average(Negative electrode active material volume fraction)
# 	- Total lithium in primary phase in negative electrode [mol]		yz-average(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell
# 	- Positive electrode stoichiometry		x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3]))) / x-average(Positive electrode active material volume fraction) / Maximum concentration in positive electrode [mol.m-3]
# 	- Positive electrode volume-averaged concentration		x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3]))) / x-average(Positive electrode active material volume fraction) / Maximum concentration in positive electrode [mol.m-3]
# 	- Positive electrode volume-averaged concentration [mol.m-3]		x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3]))) / x-average(Positive electrode active material volume fraction)
# 	- Total lithium in primary phase in positive electrode [mol]		yz-average(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3])))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell
# 	- Electrolyte concentration concatenation [mol.m-3]		broadcast(Initial concentration in electrolyte [mol.m-3])
# 	- Negative electrolyte concentration [mol.m-3]		broadcast(Initial concentration in electrolyte [mol.m-3])
# 	- X-averaged negative electrolyte concentration [mol.m-3]		broadcast(Initial concentration in electrolyte [mol.m-3])
# 	- Separator electrolyte concentration [mol.m-3]		broadcast(Initial concentration in electrolyte [mol.m-3])
# 	- X-averaged separator electrolyte concentration [mol.m-3]		broadcast(Initial concentration in electrolyte [mol.m-3])
# 	- Positive electrolyte concentration [mol.m-3]		broadcast(Initial concentration in electrolyte [mol.m-3])
# 	- X-averaged positive electrolyte concentration [mol.m-3]		broadcast(Initial concentration in electrolyte [mol.m-3])
# 	- Negative electrolyte concentration [Molar]		broadcast(0.001 * Initial concentration in electrolyte [mol.m-3])
# 	- X-averaged negative electrolyte concentration [Molar]		broadcast(0.001 * Initial concentration in electrolyte [mol.m-3])
# 	- Separator electrolyte concentration [Molar]		broadcast(0.001 * Initial concentration in electrolyte [mol.m-3])
# 	- X-averaged separator electrolyte concentration [Molar]		broadcast(0.001 * Initial concentration in electrolyte [mol.m-3])
# 	- Positive electrolyte concentration [Molar]		broadcast(0.001 * Initial concentration in electrolyte [mol.m-3])
# 	- X-averaged positive electrolyte concentration [Molar]		broadcast(0.001 * Initial concentration in electrolyte [mol.m-3])
# 	- Electrolyte concentration [mol.m-3]		concatenation(Initial concentration in electrolyte [mol.m-3])
# 	- X-averaged electrolyte concentration [mol.m-3]		broadcast(Initial concentration in electrolyte [mol.m-3])
# 	- Electrolyte concentration [Molar]		broadcast(0.001 * Initial concentration in electrolyte [mol.m-3])
# 	- X-averaged electrolyte concentration [Molar]		broadcast(0.001 * Initial concentration in electrolyte [mol.m-3])
# 	- Ohmic heating [W.m-3]		0.0
# 	- X-averaged Ohmic heating [W.m-3]		0.0
# 	- Volume-averaged Ohmic heating [W.m-3]		0.0
# 	- Ohmic heating per unit electrode-pair area [W.m-2]		0.0
# 	- Ohmic heating [W]		0.0
# 	- Irreversible electrochemical heating [W.m-3]		0.0
# 	- X-averaged irreversible electrochemical heating [W.m-3]		0.0
# 	- Volume-averaged irreversible electrochemical heating [W.m-3]		0.0
# 	- Irreversible electrochemical heating per unit electrode-pair area [W.m-2]		0.0
# 	- Irreversible electrochemical heating [W]		0.0
# 	- Reversible heating [W.m-3]		0.0
# 	- X-averaged reversible heating [W.m-3]		0.0
# 	- Volume-averaged reversible heating [W.m-3]		0.0
# 	- Reversible heating per unit electrode-pair area [W.m-2]		0.0
# 	- Reversible heating [W]		0.0
# 	- Total heating [W.m-3]		0.0
# 	- X-averaged total heating [W.m-3]		0.0
# 	- Volume-averaged total heating [W.m-3]		0.0
# 	- Total heating per unit electrode-pair area [W.m-2]		0.0
# 	- Total heating [W]		0.0
# 	- Negative current collector Ohmic heating [W.m-3]		0.0
# 	- Positive current collector Ohmic heating [W.m-3]		0.0
# 	- Surface total cooling [W.m-3]		0.0
# 	- Surface total cooling [W]		0.0
# 	- Surface temperature [K]		Ambient temperature [K]
# 	- Volume-averaged surface temperature [K]		z-average(Ambient temperature [K])
# 	- Environment total cooling [W]		0.0
# 	- Current collector current density [A.m-2]		broadcast(Current function [A] / (Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell))
# 	- Negative electrode SEI volumetric interfacial current density [A.m-3]		broadcast(0.0)
# 	- X-averaged negative electrode SEI volumetric interfacial current density [A.m-3]		broadcast(0.0)
# 	- X-averaged negative electrode resistance [Ohm.m2]		broadcast(0.0)
# 	- Negative SEI thickness [m]		broadcast(0.0)
# 	- X-averaged negative SEI thickness [m]		broadcast(0.0)
# 	- Volume-averaged negative SEI thickness [m]		0.0
# 	- Positive electrode SEI volumetric interfacial current density [A.m-3]		broadcast(0.0)
# 	- X-averaged positive electrode SEI volumetric interfacial current density [A.m-3]		broadcast(0.0)
# 	- X-averaged positive electrode resistance [Ohm.m2]		broadcast(0.0)
# 	- Positive SEI thickness [m]		broadcast(0.0)
# 	- X-averaged positive SEI thickness [m]		broadcast(0.0)
# 	- Volume-averaged positive SEI thickness [m]		0.0
# 	- Negative electrode SEI on cracks volumetric interfacial current density [A.m-3]		broadcast(0.0)
# 	- X-averaged negative electrode SEI on cracks volumetric interfacial current density [A.m-3]		broadcast(0.0)
# 	- Negative SEI on cracks thickness [m]		broadcast(0.0)
# 	- X-averaged negative SEI on cracks thickness [m]		broadcast(0.0)
# 	- Volume-averaged negative SEI on cracks thickness [m]		0.0
# 	- Positive electrode SEI on cracks volumetric interfacial current density [A.m-3]		broadcast(0.0)
# 	- X-averaged positive electrode SEI on cracks volumetric interfacial current density [A.m-3]		broadcast(0.0)
# 	- Positive SEI on cracks thickness [m]		broadcast(0.0)
# 	- X-averaged positive SEI on cracks thickness [m]		broadcast(0.0)
# 	- Volume-averaged positive SEI on cracks thickness [m]		0.0
# 	- Negative electrode lithium plating volumetric interfacial current density [A.m-3]		broadcast(0.0)
# 	- X-averaged negative electrode lithium plating volumetric interfacial current density [A.m-3]		broadcast(0.0)
# 	- Positive electrode lithium plating volumetric interfacial current density [A.m-3]		broadcast(0.0)
# 	- X-averaged positive electrode lithium plating volumetric interfacial current density [A.m-3]		broadcast(0.0)
# 	- Negative electrode equilibrium open-circuit potential [V]		Negative electrode OCP [V] + (Ambient temperature [K] - Reference temperature [K]) * Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))
# 	- X-averaged negative electrode equilibrium open-circuit potential [V]		Negative electrode OCP [V] + (Ambient temperature [K] - Reference temperature [K]) * Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))
# 	- Negative electrode open-circuit potential [V]		broadcast(Negative electrode OCP [V] + (Ambient temperature [K] - Reference temperature [K]) * Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10))))
# 	- X-averaged negative electrode open-circuit potential [V]		Negative electrode OCP [V] + (Ambient temperature [K] - Reference temperature [K]) * Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))
# 	- Negative electrode bulk open-circuit potential [V]		Negative electrode OCP [V] + (yz-average(Ambient temperature [K]) - Reference temperature [K]) * Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3]))) / x-average(Negative electrode active material volume fraction) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3]))) / x-average(Negative electrode active material volume fraction) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))
# 	- Negative particle concentration overpotential [V]		Negative electrode OCP [V] + (Ambient temperature [K] - Reference temperature [K]) * Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10))) - (Negative electrode OCP [V] + (yz-average(Ambient temperature [K]) - Reference temperature [K]) * Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3]))) / x-average(Negative electrode active material volume fraction) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3]))) / x-average(Negative electrode active material volume fraction) / Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10))))
# 	- Negative electrode entropic change [V.K-1]		Negative electrode OCP entropic change [V.K-1]
# 	- X-averaged negative electrode entropic change [V.K-1]		Negative electrode OCP entropic change [V.K-1]
# 	- Positive electrode equilibrium open-circuit potential [V]		Positive electrode OCP [V] + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)))
# 	- X-averaged positive electrode equilibrium open-circuit potential [V]		Positive electrode OCP [V] + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)))
# 	- Positive electrode open-circuit potential [V]		broadcast(Positive electrode OCP [V] + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))))
# 	- X-averaged positive electrode open-circuit potential [V]		Positive electrode OCP [V] + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)))
# 	- Positive electrode bulk open-circuit potential [V]		Positive electrode OCP [V] + (yz-average(Ambient temperature [K]) - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3]))) / x-average(Positive electrode active material volume fraction) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3]))) / x-average(Positive electrode active material volume fraction) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)))
# 	- Positive particle concentration overpotential [V]		Positive electrode OCP [V] + (Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))) - (Positive electrode OCP [V] + (yz-average(Ambient temperature [K]) - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3]))) / x-average(Positive electrode active material volume fraction) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3]))) / x-average(Positive electrode active material volume fraction) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))))
# 	- Positive electrode entropic change [V.K-1]		Positive electrode OCP entropic change [V.K-1]
# 	- X-averaged positive electrode entropic change [V.K-1]		Positive electrode OCP entropic change [V.K-1]
# 	- X-averaged negative electrode total interfacial current density [A.m-2]		Current function [A] / (Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell) / Negative electrode thickness [m] / x-average(3.0 * Negative electrode active material volume fraction / Negative particle radius [m])
# 	- X-averaged negative electrode total volumetric interfacial current density [A.m-3]		broadcast(Current function [A] / (Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell) / Negative electrode thickness [m])
# 	- Negative electrode SEI film overpotential [V]		broadcast(0.0)
# 	- X-averaged negative electrode SEI film overpotential [V]		0.0
# 	- Negative electrode exchange current density [A.m-2]		broadcast(Negative electrode exchange-current density [A.m-2])
# 	- X-averaged negative electrode exchange current density [A.m-2]		Negative electrode exchange-current density [A.m-2]
# 	- Negative electrode reaction overpotential [V]		broadcast((2.0 * R * Ambient temperature [K] / F) * arcsinh(Current function [A] / (Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell) / Negative electrode thickness [m] / x-average(3.0 * Negative electrode active material volume fraction / Negative particle radius [m]) / (2.0 * Negative electrode exchange-current density [A.m-2])))
# 	- X-averaged negative electrode reaction overpotential [V]		(2.0 * R * Ambient temperature [K] / F) * arcsinh(Current function [A] / (Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell) / Negative electrode thickness [m] / x-average(3.0 * Negative electrode active material volume fraction / Negative particle radius [m]) / (2.0 * Negative electrode exchange-current density [A.m-2]))
# ...
# 	- Total lithium in positive electrode [mol]		yz-average(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3])))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell
# 	- LAM_pe [%]		100.0 - (100.0 * 0.0002777777777777778 * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * Maximum concentration in positive electrode [mol.m-3] * F / (0.0002777777777777778 * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Maximum concentration in positive electrode [mol.m-3] * F * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell))
# 	- Loss of active material in positive electrode [%]		100.0 - (100.0 * 0.0002777777777777778 * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * Maximum concentration in positive electrode [mol.m-3] * F / (0.0002777777777777778 * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Maximum concentration in positive electrode [mol.m-3] * F * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell))
# 	- LLI [%]		100.0 - (100.0 * (yz-average(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3])))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell))
# 	- Loss of lithium inventory [%]		100.0 - (100.0 * (yz-average(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3])))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell))
# 	- Loss of lithium inventory, including electrolyte [%]		100.0 - (100.0 * (yz-average(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3])))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity * Initial concentration in electrolyte [mol.m-3]) + Separator thickness [m] * x-average(Separator porosity * Initial concentration in electrolyte [mol.m-3]) + Positive electrode thickness [m] * x-average(Positive electrode porosity * Initial concentration in electrolyte [mol.m-3])) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]))) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell))
# 	- Total lithium [mol]		yz-average(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3])))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity * Initial concentration in electrolyte [mol.m-3]) + Separator thickness [m] * x-average(Separator porosity * Initial concentration in electrolyte [mol.m-3]) + Positive electrode thickness [m] * x-average(Positive electrode porosity * Initial concentration in electrolyte [mol.m-3])) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]))
# 	- Total lithium in particles [mol]		yz-average(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3])))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell
# 	- Total lithium capacity [A.h]		0.0002777777777777778 * (yz-average(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3])))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity * Initial concentration in electrolyte [mol.m-3]) + Separator thickness [m] * x-average(Separator porosity * Initial concentration in electrolyte [mol.m-3]) + Positive electrode thickness [m] * x-average(Positive electrode porosity * Initial concentration in electrolyte [mol.m-3])) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]))) * F
# 	- Total lithium capacity in particles [A.h]		0.0002777777777777778 * (yz-average(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3])))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell) * F
# 	- Total lithium lost [mol]		yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell - (yz-average(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3])))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity * Initial concentration in electrolyte [mol.m-3]) + Separator thickness [m] * x-average(Separator porosity * Initial concentration in electrolyte [mol.m-3]) + Positive electrode thickness [m] * x-average(Positive electrode porosity * Initial concentration in electrolyte [mol.m-3])) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])))
# 	- Total lithium lost from particles [mol]		yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell - (yz-average(x-average(Negative electrode active material volume fraction * broadcast(r-average(X-averaged negative particle concentration [mol.m-3])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * broadcast(r-average(X-averaged positive particle concentration [mol.m-3])))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell)
# 	- Total lithium lost from electrolyte [mol]		(yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell) - ((Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity * Initial concentration in electrolyte [mol.m-3]) + Separator thickness [m] * x-average(Separator porosity * Initial concentration in electrolyte [mol.m-3]) + Positive electrode thickness [m] * x-average(Positive electrode porosity * Initial concentration in electrolyte [mol.m-3])) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])))
# 	- Total lithium lost to side reactions [mol]		0.0
# 	- Total capacity lost to side reactions [A.h]		0.0

# %% [markdown]
# To help visualise the results, pybamm provides the `pybamm.ProcessedVariable` class, which takes the output of a solver and a variable, and allows the user to evaluate the value of that variable at any given time or $x$ value. These processed variables are automatically created by the solution dictionary.

# %%
voltage = solution["Voltage [V]"]
c_s_n_surf = solution["Negative particle surface concentration"]
c_s_p_surf = solution["Positive particle surface concentration"]

# %% [markdown]
# One we have these variables in hand, we can begin generating plots using a library such as Matplotlib. Below we plot the voltage and surface particle concentrations versus time

# %%
t = solution["Time [s]"].entries
x = solution["x [m]"].entries[:, 0]
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(13, 4))

ax1.plot(t, voltage(t))
ax1.set_xlabel(r"Time [s]")
ax1.set_ylabel("Voltage [V]")

ax2.plot(
    t, c_s_n_surf(t=t, x=x[0])
)  # can evaluate at arbitrary x (single representative particle)
ax2.set_xlabel(r"Time [s]")
ax2.set_ylabel("Negative particle surface concentration")

ax3.plot(
    t, c_s_p_surf(t=t, x=x[-1])
)  # can evaluate at arbitrary x (single representative particle)
ax3.set_xlabel(r"Time [s]")
ax3.set_ylabel("Positive particle surface concentration")

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Some of the output variables are defined over space as well as time. Once option to visualise these variables is to use the `interact` slider widget. Below we plot the negative/positive particle concentration over $r$, using a slider to change the current time point

# %%
c_s_n = solution["Negative particle concentration"]
c_s_p = solution["Positive particle concentration"]
r_n = solution["r_n [m]"].entries[:, 0]
r_p = solution["r_p [m]"].entries[:, 0]

# %%
c_s_n = solution["Negative particle concentration"]
c_s_p = solution["Positive particle concentration"]
r_n = solution["r_n [m]"].entries[:, 0, 0]
r_p = solution["r_p [m]"].entries[:, 0, 0]


def plot_concentrations(t):
    _, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    (_plot_c_n,) = ax1.plot(
        r_n, c_s_n(r=r_n, t=t, x=x[0])
    )  # can evaluate at arbitrary x (single representative particle)
    (_plot_c_p,) = ax2.plot(
        r_p, c_s_p(r=r_p, t=t, x=x[-1])
    )  # can evaluate at arbitrary x (single representative particle)
    ax1.set_ylabel("Negative particle concentration")
    ax2.set_ylabel("Positive particle concentration")
    ax1.set_xlabel(r"$r_n$ [m]")
    ax2.set_xlabel(r"$r_p$ [m]")
    ax1.set_ylim(0, 1)
    ax2.set_ylim(0, 1)
    plt.show()


import ipywidgets as widgets

widgets.interact(
    plot_concentrations, t=widgets.FloatSlider(min=0, max=3600, step=10, value=0)
);

# %% [markdown]
# The QuickPlot class can be used to plot the common set of useful outputs which should give you a good initial overview of the model. The method `Quickplot.dynamic_plot` employs the slider widget.

# %%
# quick_plot = pybamm.QuickPlot(solution)
# quick_plot.dynamic_plot()

# %% [markdown]
# ## References
#
# The relevant papers for this notebook are:

# %%
pybamm.print_citations()
# Out:
# [1] Joel A. E. Andersson, Joris Gillis, Greg Horn, James B. Rawlings, and Moritz Diehl. CasADi – A software framework for nonlinear optimization and optimal control. Mathematical Programming Computation, 11(1):1–36, 2019. doi:10.1007/s12532-018-0139-4.
# [2] Von DAG Bruggeman. Berechnung verschiedener physikalischer konstanten von heterogenen substanzen. i. dielektrizitätskonstanten und leitfähigkeiten der mischkörper aus isotropen substanzen. Annalen der physik, 416(7):636–664, 1935.
# [3] Charles R. Harris, K. Jarrod Millman, Stéfan J. van der Walt, Ralf Gommers, Pauli Virtanen, David Cournapeau, Eric Wieser, Julian Taylor, Sebastian Berg, Nathaniel J. Smith, and others. Array programming with NumPy. Nature, 585(7825):357–362, 2020. doi:10.1038/s41586-020-2649-2.
# [4] Alan C. Hindmarsh. The PVODE and IDA algorithms. Technical Report, Lawrence Livermore National Lab., CA (US), 2000. doi:10.2172/802599.
# [5] Alan C. Hindmarsh, Peter N. Brown, Keith E. Grant, Steven L. Lee, Radu Serban, Dan E. Shumaker, and Carol S. Woodward. SUNDIALS: Suite of nonlinear and differential/algebraic equation solvers. ACM Transactions on Mathematical Software (TOMS), 31(3):363–396, 2005. doi:10.1145/1089014.1089020.
# [6] Scott G. Marquis, Valentin Sulzer, Robert Timms, Colin P. Please, and S. Jon Chapman. An asymptotic derivation of a single particle model with electrolyte. Journal of The Electrochemical Society, 166(15):A3693–A3706, 2019. doi:10.1149/2.0341915jes.
# [7] Valentin Sulzer, Scott G. Marquis, Robert Timms, Martin Robinson, and S. Jon Chapman. Python Battery Mathematical Modelling (PyBaMM). Journal of Open Research Software, 9(1):14, 2021. doi:10.5334/jors.309.

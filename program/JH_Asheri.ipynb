# %%
import numpy as np
import matplotlib.pyplot as plt

# # import  settings
import plot_settings
plot_settings.apply()

# %%
def bulter_volmer(eta,i0, c_p_s, F = 96485, R = 8.314, T = 298.15):
    return i0/F  * (c_p_s * np.exp(F*eta/(2*R*T)) - (1 - c_p_s) * np.exp(-F*eta/(2*R*T)))

def eta_op(phi_p, phi_e, U_eq):
    return phi_p - phi_e - U_eq

def i0_ex_curr(ke,ce_max,ce,F=96485):
    return F * ke * np.sqrt(ce_max-ce) * np.sqrt(ce)

def U(c_p_s):
    c = c_p_s
    return (7.9760- 5.5419 * c+ 5.2824 * c**1.0700- 1.0556e-4 * np.exp(124.7407 * c - 114.2593)- 4.40446 * c**0.0766)

def phi_e(J,F = 96485):
    return - J / F

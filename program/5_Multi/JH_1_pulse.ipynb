# %%
import torch
import numpy as np
import torch.nn as nn
from tqdm import trange
from pathlib import Path
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import importlib
from torchinfo import summary
import time
import sys
import pandas as pd
import scipy
import seaborn as sns
import sklearn.gaussian_process as gp
from scipy import stats
import importlib
import multi_exp_log
sys.path.append('..')
import plot_settings

import GP

colors = plot_settings.colors()

def import_reload():
    plot_settings.apply()
    importlib.reload(multi_exp_log)
    importlib.reload(GP)

import_reload()
GP_FIT = GP.GP_process()

import warnings
warnings.filterwarnings("ignore", message=".*__array_wrap__.*")
# Out:
# /Users/jonatanharaldsson/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/5_Multi/GP.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(

# %% [markdown]
# # Importing data

# %%
DT = 1
Q0 = 17921.57581 
#(data['I'][data['trajectory'] == 10].values)[0]  * 3600 / (data['C'][data['trajectory'] == 10].values)[0]  
#print(f'Q0: {Q0:.5f} As')

# %%
def read_raw_data(file_name):
    df = pd.read_csv(
        f"Multi_data/{file_name}.txt",
        delim_whitespace=True,
        comment="%",
        header=None
    )
    df.columns = ['u_par','C','t','E_cell (V)','I_cell (A)','Rx_cell (N)','u_cell (m)','E_ocv_cell (V)','soc_cell (1)', 'I_1C*wv1(t)*A_cell']
    return df

def read_data(file_name):
    df = pd.read_csv(
        f"Multi_data/{file_name}.txt",
        sep=';',
        comment="%"
    )
    # cols = u_par,C,t,V,I,F,u,Ue,eta,trajectory,dV,dF,soc
    #df.columns = ['u_par','C','t','V','I','F','u','Ue','eta','trajectory','dV','dF','soc']
    # Sort by time within each batch
    return df


path_pulse = f'test_data_pulse300_50p_I'

data_pulse = read_raw_data(path_pulse)

# #rename columns
data_pulse.columns = ['u_par','C','t','V','I_dummy','F','u','Ue','soc','I']


data = read_data('2_merged_data')
# data['u'] = data['u'] * 1e5
# data['Rx'] = data['Rx'] * 1e-9
# data['I'] = data['I'] * 1.
# data['eta'] = data['V_t'] - data['ocv']
#data_pulse.describe()
# # remove the trajectories with u_par = 8.4, C = 3.6 and u_par = 25.7, C = 4.4 
# data = data[~((data['u_par'] == 8.4) & (data['C'] == 3.6))]
# data = data[~((data['u_par'] == 25.7) & (data['C'] == 4.4))]

#data.to_csv('Multi_data/4_raw_data.txt', index=False)

display(data_pulse.head())
# Out:
# /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_14008/4213494014.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
#    u_par    C  t         V   I_dummy             F         u        Ue  \
# 0   18.0  1.9  0  4.281674 -9.458609 -1.375462e+09  0.000026  4.324998
# 1   18.0  1.9  1  4.222699 -9.458609 -1.375058e+09  0.000026  4.323401
# 2   18.0  1.9  2  4.207808 -9.458609 -1.374651e+09  0.000026  4.321794
# 3   18.0  1.9  3  4.196094 -9.458609 -1.374244e+09  0.000026  4.320187
# 4   18.0  1.9  4  4.187515 -9.458609 -1.373837e+09  0.000026  4.318580
#
#         soc         I
# 0  0.999999 -4.729305
# 1  0.999475 -9.458609
# 2  0.998947 -9.458609
# 3  0.998419 -9.458609
# 4  0.997892 -9.458609

# %% [markdown]
# To deal with more reasonable values, $F$ is measured in GN, while $\Delta u$ is measured in $10^{-5}$ m

# %%
def group_trajectories(df):
    """
    Group trajectories by unique combinations of 'C' and 'u_par'.

    Parameters
    ----------
    df : pd.DataFrame
        Input dataframe with columns 'C' and 'u_par'.

    Returns
    -------
    pd.DataFrame
        DataFrame with an added 'trajectory' column indicating group membership.
    """
    df['trajectory'] = df.groupby(['C', 'u_par'], sort=False).ngroup()
    return df

def merge_runs(n_runs, base_dir="Multi_data", add_run_id=False):
    """
    Merge multiple run files into one dataframe.

    Parameters
    ----------
    run_names : list[str]
        Run names without extension, e.g. ['1_run', '2_run'].
    base_dir : str
        Folder containing the .txt run files.
    add_run_id : bool
        If True, adds a 'run_id' column.

    Returns
    -------
    pd.DataFrame
        Merged and preprocessed dataframe.
    """
    run_names = []
    for n in range(1, n_runs+1):
        run_names.append(f"{n}_run")

    print(f"Merging runs: {run_names}")

    if not run_names:
        raise ValueError("run_names must contain at least one run name.")

    frames = []
    for run in run_names:
        df = pd.read_csv(
            f"{base_dir}/{run}_raw.txt",
            delim_whitespace=True,
            comment="%",
            header=None)
        df.columns = ['u_par', 'C', 't', 'V', 'I', 'F', 'u', 'Ue']

        # same preprocessing as in your notebook
        df['u'] = df['u'] * 1e5
        df['F'] = df['F'] * 1e-9
        df['I'] = df['I'] * 1.0
        df['eta'] = df['V'] - df['Ue']
        if add_run_id:
            df['run_id'] = run

        frames.append(df)

    merged = pd.concat(frames, ignore_index=True)
    # remove duplicates in C and u_par if they exist
    merged = merged.drop_duplicates(subset=['C', 'u_par', 't'])

    # optional global trajectory labeling across merged runs
    merged['trajectory'] = merged.groupby(['C', 'u_par'], sort=False).ngroup()

    return merged


# Example:
grouped_data_pulse = group_trajectories(data_pulse)
data_pulse = grouped_data_pulse.copy()

data_pulse['eta'] = -data_pulse['V'] + data_pulse['Ue']
data_pulse['I'] = -data_pulse['I'] * 1.0
data_pulse['u'] = -data_pulse['u'] * 1e5
data_pulse['F'] = -data_pulse['F'] * 1e-9
data_pulse.head()
# Out:
#    u_par    C  t         V   I_dummy         F         u        Ue       soc  \
# 0   18.0  1.9  0  4.281674 -9.458609  1.375462 -2.587185  4.324998  0.999999
# 1   18.0  1.9  1  4.222699 -9.458609  1.375058 -2.587185  4.323401  0.999475
# 2   18.0  1.9  2  4.207808 -9.458609  1.374651 -2.587185  4.321794  0.998947
# 3   18.0  1.9  3  4.196094 -9.458609  1.374244 -2.587185  4.320187  0.998419
# 4   18.0  1.9  4  4.187515 -9.458609  1.373837 -2.587185  4.318580  0.997892
#
#           I  trajectory       eta
# 0  4.729305           0  0.043324
# 1  9.458609           0  0.100702
# 2  9.458609           0  0.113987
# 3  9.458609           0  0.124093
# 4  9.458609           0  0.131065

# %%
print(len(data['trajectory'].unique()))
for tr in data['trajectory'].unique():
    print(f'Trajectory {tr}\t length: {(data['trajectory'] == tr).sum()}')
# Out:
# 248
# Trajectory 0	 length: 1476
# Trajectory 1	 length: 758
# Trajectory 2	 length: 5847
# Trajectory 3	 length: 3846
# Trajectory 4	 length: 758
# Trajectory 5	 length: 3117
# Trajectory 6	 length: 635
# Trajectory 7	 length: 1840
# Trajectory 8	 length: 1169
# Trajectory 9	 length: 997
# Trajectory 10	 length: 963
# Trajectory 11	 length: 784
# Trajectory 12	 length: 1172
# Trajectory 13	 length: 4347
# Trajectory 14	 length: 5847
# Trajectory 15	 length: 1732
# Trajectory 16	 length: 1038
# Trajectory 17	 length: 673
# Trajectory 18	 length: 1279
# Trajectory 19	 length: 1402
# Trajectory 20	 length: 586
# Trajectory 21	 length: 1079
# Trajectory 22	 length: 2089
# Trajectory 23	 length: 3441
# Trajectory 24	 length: 837
# Trajectory 25	 length: 4987
# Trajectory 26	 length: 713
# Trajectory 27	 length: 570
# Trajectory 28	 length: 865
# Trajectory 29	 length: 1125
# Trajectory 30	 length: 1552
# Trajectory 31	 length: 2614
# Trajectory 32	 length: 929
# Trajectory 33	 length: 1955
# Trajectory 34	 length: 810
# Trajectory 35	 length: 1279
# Trajectory 36	 length: 653
# Trajectory 37	 length: 586
# Trajectory 38	 length: 897
# Trajectory 39	 length: 1640
# Trajectory 40	 length: 2409
# Trajectory 41	 length: 603
# Trajectory 42	 length: 2241
# Trajectory 43	 length: 737
# Trajectory 44	 length: 2839
# Trajectory 45	 length: 1038
# Trajectory 46	 length: 1402
# Trajectory 47	 length: 694
# Trajectory 48	 length: 2088
# Trajectory 49	 length: 619
# Trajectory 50	 length: 3846
# Trajectory 51	 length: 835
# Trajectory 52	 length: 4991
# Trajectory 53	 length: 2839
# Trajectory 54	 length: 673
# Trajectory 55	 length: 1404
# Trajectory 56	 length: 620
# Trajectory 57	 length: 809
# Trajectory 58	 length: 5847
# Trajectory 59	 length: 3442
# Trajectory 60	 length: 1279
# Trajectory 61	 length: 714
# Trajectory 62	 length: 1476
# Trajectory 63	 length: 1552
# Trajectory 64	 length: 758
# Trajectory 65	 length: 3118
# Trajectory 66	 length: 714
# Trajectory 67	 length: 673
# Trajectory 68	 length: 586
# Trajectory 69	 length: 3846
# Trajectory 70	 length: 963
# Trajectory 71	 length: 1732
# Trajectory 72	 length: 2089
# Trajectory 73	 length: 835
# Trajectory 74	 length: 1079
# Trajectory 75	 length: 736
# Trajectory 76	 length: 997
# Trajectory 77	 length: 586
# Trajectory 78	 length: 1336
# Trajectory 79	 length: 654
# Trajectory 80	 length: 4989
# Trajectory 81	 length: 636
# Trajectory 82	 length: 926
# Trajectory 83	 length: 1956
# Trajectory 84	 length: 1222
# Trajectory 85	 length: 556
# Trajectory 86	 length: 1038
# Trajectory 87	 length: 783
# Trajectory 88	 length: 864
# Trajectory 89	 length: 1839
# Trajectory 90	 length: 1125
# Trajectory 91	 length: 2414
# Trajectory 92	 length: 1402
# Trajectory 93	 length: 2613
# Trajectory 94	 length: 2614
# Trajectory 95	 length: 997
# Trajectory 96	 length: 619
# Trajectory 97	 length: 1172
# Trajectory 98	 length: 1640
# Trajectory 99	 length: 2241
# Trajectory 100	 length: 2839
# Trajectory 101	 length: 736
# Trajectory 102	 length: 2238
# Trajectory 103	 length: 897
# Trajectory 104	 length: 1038
# Trajectory 105	 length: 693
# Trajectory 106	 length: 618
# Trajectory 107	 length: 1080
# Trajectory 108	 length: 4988
# Trajectory 109	 length: 1172
# Trajectory 110	 length: 2241
# Trajectory 111	 length: 810
# Trajectory 112	 length: 714
# Trajectory 113	 length: 1279
# Trajectory 114	 length: 601
# Trajectory 115	 length: 1125
# Trajectory 116	 length: 864
# Trajectory 117	 length: 3842
# Trajectory 118	 length: 2839
# Trajectory 119	 length: 1637
# Trajectory 120	 length: 555
# Trajectory 121	 length: 1640
# Trajectory 122	 length: 1554
# Trajectory 123	 length: 1336
# Trajectory 124	 length: 737
# Trajectory 125	 length: 2089
# Trajectory 126	 length: 1080
# Trajectory 127	 length: 1222
# Trajectory 128	 length: 587
# Trajectory 129	 length: 928
# Trajectory 130	 length: 3442
# Trajectory 131	 length: 1732
# Trajectory 132	 length: 635
# Trajectory 133	 length: 783
# Trajectory 134	 length: 586
# Trajectory 135	 length: 1476
# Trajectory 136	 length: 7049
# Trajectory 137	 length: 3118
# Trajectory 138	 length: 1955
# Trajectory 139	 length: 653
# Trajectory 140	 length: 963
# Trajectory 141	 length: 1839
# Trajectory 142	 length: 783
# Trajectory 143	 length: 653
# Trajectory 144	 length: 837
# Trajectory 145	 length: 1336
# Trajectory 146	 length: 2409
# Trajectory 147	 length: 4989
# Trajectory 148	 length: 3846
# Trajectory 149	 length: 963
# Trajectory 150	 length: 1402
# Trajectory 151	 length: 4990
# Trajectory 152	 length: 2839
# Trajectory 153	 length: 810
# Trajectory 154	 length: 1221
# Trajectory 155	 length: 1640
# Trajectory 156	 length: 1554
# Trajectory 157	 length: 1279
# Trajectory 158	 length: 2409
# Trajectory 159	 length: 1172
# Trajectory 160	 length: 1955
# Trajectory 161	 length: 672
# Trajectory 162	 length: 619
# Trajectory 163	 length: 587
# Trajectory 164	 length: 692
# Trajectory 165	 length: 3441
# Trajectory 166	 length: 636
# Trajectory 167	 length: 1279
# Trajectory 168	 length: 1476
# Trajectory 169	 length: 927
# Trajectory 170	 length: 864
# Trajectory 171	 length: 571
# Trajectory 172	 length: 997
# Trajectory 173	 length: 2241
# Trajectory 174	 length: 1402
# Trajectory 175	 length: 673
# Trajectory 176	 length: 928
# Trajectory 177	 length: 1732
# Trajectory 178	 length: 2241
# Trajectory 179	 length: 603
# Trajectory 180	 length: 783
# Trajectory 181	 length: 1955
# Trajectory 182	 length: 760
# Trajectory 183	 length: 1122
# Trajectory 184	 length: 5847
# Trajectory 185	 length: 1079
# Trajectory 186	 length: 3846
# Trajectory 187	 length: 1079
# Trajectory 188	 length: 2613
# Trajectory 189	 length: 997
# Trajectory 190	 length: 864
# Trajectory 191	 length: 1839
# Trajectory 192	 length: 5847
# Trajectory 193	 length: 3117
# Trajectory 194	 length: 551
# Trajectory 195	 length: 760
# Trajectory 196	 length: 3846
# Trajectory 197	 length: 736
# Trajectory 198	 length: 2839
# Trajectory 199	 length: 5847
# Trajectory 200	 length: 960
# Trajectory 201	 length: 1336
# Trajectory 202	 length: 926
# Trajectory 203	 length: 1640
# Trajectory 204	 length: 5847
# Trajectory 205	 length: 867
# Trajectory 206	 length: 896
# Trajectory 207	 length: 1339
# Trajectory 208	 length: 1080
# Trajectory 209	 length: 585
# Trajectory 210	 length: 672
# Trajectory 211	 length: 1956
# Trajectory 212	 length: 3442
# Trajectory 213	 length: 1222
# Trajectory 214	 length: 602
# Trajectory 215	 length: 2089
# Trajectory 216	 length: 570
# Trajectory 217	 length: 2088
# Trajectory 218	 length: 619
# Trajectory 219	 length: 1172
# Trajectory 220	 length: 782
# Trajectory 221	 length: 2614
# Trajectory 222	 length: 692
# Trajectory 223	 length: 571
# Trajectory 224	 length: 2614
# Trajectory 225	 length: 1732
# Trajectory 226	 length: 653
# Trajectory 227	 length: 1839
# Trajectory 228	 length: 714
# Trajectory 229	 length: 714
# Trajectory 230	 length: 998
# Trajectory 231	 length: 1554
# Trajectory 232	 length: 758
# Trajectory 233	 length: 636
# Trajectory 234	 length: 1404
# Trajectory 235	 length: 1224
# Trajectory 236	 length: 4344
# Trajectory 237	 length: 837
# Trajectory 238	 length: 3118
# Trajectory 239	 length: 4988
# Trajectory 240	 length: 3846
# Trajectory 241	 length: 759
# Trajectory 242	 length: 962
# Trajectory 243	 length: 1125
# Trajectory 244	 length: 810
# Trajectory 245	 length: 1039
# Trajectory 246	 length: 1476
# Trajectory 247	 length: 2409

# %%
u_C_pairs = data.loc[data['t'] == 0, ['u_par', 'C']]
plt.plot(u_C_pairs['C'], u_C_pairs['u_par'], 'o')

# %%
def find_duplicate_u_C_pairs(df):
    """
    Find duplicate (u_par, C) pairs in the dataframe.

    Parameters
    ----------
    df : pd.DataFrame
        Dataframe containing 'u_par' and 'C' columns.

    Returns
    -------
    pd.DataFrame
        Dataframe of duplicate (u_par, C) pairs and their counts.
    """
    duplicates = df.groupby(['u_par', 'C']).size().reset_index(name='count')
    duplicates = duplicates[duplicates['count'] > 1]
    return duplicates

duplicates = find_duplicate_u_C_pairs(u_C_pairs)
print("Duplicate (u_par, C) pairs:")
print(duplicates)

# # remove the duplicates
# for _, row in duplicates.iterrows():
#     u_par = row['u_par']
#     C = row['C']
#     # Find all trajectories with this (u_par, C) pair
#     trajectories_to_remove = data[(data['u_par'] == u_par) & (data['C'] == C)]['trajectory'].unique()
#     # Remove these trajectories from the dataframe
#     data = data[~data['trajectory'].isin(trajectories_to_remove)]

# print("After removing duplicates:")
# duplicates_after = find_duplicate_u_C_pairs(data.loc[data['t'] == 0, ['u_par', 'C']])
# print(duplicates_after)
# Out:
# Duplicate (u_par, C) pairs:
# Empty DataFrame
# Columns: [u_par, C, count]
# Index: []

# %%
# Add finite-difference columns with the same length as `data`
dV = np.diff(data['V'].to_numpy())[:-1] / DT
dRx = np.diff(data['F'].to_numpy())[:-1] / DT

if len(dV) > 0:
    for i in range(2):
        dV = np.append(dV, dV[-1])
        dRx = np.append(dRx, dRx[-1])
else:
    dV = np.array([0.0])
    dRx = np.array([0.0])

data['dV'] = dV
data['dF'] = dRx

data.head()
# Out:
#    u_par    C    t         V          I         F         u        Ue  \
# 0    0.4  2.2  0.0  4.239833  10.952074  0.030566 -0.057493  4.324996
# 1    0.4  2.2  1.0  4.211952  10.952074  0.030096 -0.057493  4.323139
# 2    0.4  2.2  2.0  4.195213  10.952074  0.029624 -0.057493  4.321278
# 3    0.4  2.2  3.0  4.183479  10.952074  0.029153 -0.057493  4.319417
# 4    0.4  2.2  4.0  4.176773  10.952074  0.028682 -0.057493  4.317557
#
#         eta  trajectory        dV        dF       soc
# 0 -0.085164           0 -0.027881 -0.000470  0.999389
# 1 -0.111187           0 -0.016738 -0.000471  0.998778
# 2 -0.126065           0 -0.011734 -0.000471  0.998167
# 3 -0.135938           0 -0.006706 -0.000471  0.997556
# 4 -0.140783           0 -0.005763 -0.000471  0.996944

# %%
def get_traj_data(trajectory, col,df = data):
    """
    Extract data for a specific trajectory.

    Parameters
    ----------
    df : pd.DataFrame
        Input dataframe containing a 'trajectory' column.
    trajectory : int
        The trajectory number to extract.

    Returns
    -------
    pd.DataFrame
        Dataframe containing only the data for the specified trajectory.
    """
    return df[col][df['trajectory'] == trajectory].reset_index(drop=True)

# %%
plt.plot(-np.concat(([0.5 * np.min(np.diff(get_traj_data(2, 'soc',df=data_pulse))) * Q0],np.diff(get_traj_data(2, 'soc',df=data_pulse)) * Q0)))

# %%
# remove columns that are not needed for the model I_dummy
#data_pulse.drop(columns=['I_dummy'], inplace=True)

data_pulse_mod = data_pulse[data_pulse['V']>2.5]
for tr in data_pulse_mod['trajectory'].unique():
    plt.plot(get_traj_data(tr,'t',df = data_pulse_mod), get_traj_data(tr,'V',df = data_pulse_mod))
data_pulse_mod.to_csv('Multi_data/data_pulse1.txt', index=False)

# %%
tr_max = 40
f,ax = plt.subplots(1, 2, figsize=(12, 5),sharey=True)
#plt.plot(get_traj_data(data, tr_max, 'soc'))
ax[0].plot(get_traj_data(tr_max,'t',df = data_pulse),GP.soc_to_Ue(get_traj_data(tr_max, 'soc',df = data_pulse),GP_FIT))
ax[0].plot(get_traj_data(tr_max,'t',df = data_pulse),get_traj_data(tr_max, 'V',df = data_pulse))
ax[1].plot(get_traj_data(tr_max,'soc',df = data_pulse),GP.soc_to_Ue(get_traj_data(tr_max, 'soc',df = data_pulse),GP_FIT))
ax[1].plot(get_traj_data(tr_max,'soc',df = data_pulse),get_traj_data(tr_max, 'V',df = data_pulse))
ax[1].invert_xaxis()
ax[0].set_ylim(3.0, 4.5)

print(get_traj_data(tr_max,'I',df = data_pulse).max())
tr_max = 15
ax[0].plot(get_traj_data(tr_max,'t'),GP.soc_to_Ue(get_traj_data(tr_max, 'soc'),GP_FIT))
ax[0].plot(get_traj_data(tr_max,'t'),get_traj_data(tr_max, 'V'))
ax[1].plot(get_traj_data(tr_max,'soc'),GP.soc_to_Ue(get_traj_data(tr_max, 'soc'),GP_FIT))
ax[1].plot(get_traj_data(tr_max,'soc'),get_traj_data(tr_max, 'V'))

print(get_traj_data(tr_max,'I').max())
plt.tight_layout()
# Out:
# 10.45425255584412
# 9.45860945418826

# %%
start = time.perf_counter()
ocv_sample = GP.soc_to_Ue(data['soc'][data['trajectory'] == tr_max].values,GP_FIT)
end = time.perf_counter()
print(f"GP sampling took {end - start:.4f} seconds for {len(data['soc'][data['trajectory'] == tr_max].values)} points => {len(data['soc'][data['trajectory'] == tr_max].values)**(-1) *1000* (end - start):.3f} ms/point")
plt.plot((data['soc'][data['trajectory'] == tr_max].values), ocv_sample, color = colors[0], label = 'GP regression')
plt.plot(data['soc'][data['trajectory'] == tr_max].values, data['Ue'][data['trajectory'] == tr_max].values, lw = 2, color = 'black', label = 'Data',ls = '--', alpha = 0.5)
plt.xlabel('State of Charge')
plt.gca().invert_xaxis()
plt.ylabel('OCV [V]')
plt.legend()
print(f'MSE: {np.mean((ocv_sample - data["Ue"][data["trajectory"] == tr_max].values)**2):.6e}')
# Out:
# GP sampling took 0.0570 seconds for 1732 points => 0.033 ms/point
# MSE: 9.608565e-07

# %% [markdown]
# # Plotting data

# %%
f, ax = plt.subplots(2, 3, figsize=(10, 5),sharex=True)
for plot_idx in range(data['trajectory'].nunique()):
    ax[0,0].plot(data['soc'][data['trajectory'] == plot_idx],data['V'][data['trajectory'] == plot_idx], '-', color = colors[0], lw = 2,alpha = 0.1)
    ax[0,0].set_xlabel('Time step')
    ax[0,0].set_ylabel('$V_{cell}$')
    ax[0,1].plot(data['soc'][data['trajectory'] == plot_idx],data['Ue'][data['trajectory'] == plot_idx], '-', color = colors[1], lw = 2,alpha = 0.1)
    ax[0,1].set_xlabel('Time step')
    ax[0,1].set_ylabel('Ue')
    ax[0,2].plot(data['soc'][data['trajectory'] == plot_idx],data['eta'][data['trajectory'] == plot_idx], '-', color = colors[2], lw = 2,alpha = 0.1)
    ax[0,2].set_xlabel('Time step')
    ax[0,2].set_ylabel(r'$\eta$')
    ax[1,0].plot(data['soc'][data['trajectory'] == plot_idx],data['F'][data['trajectory'] == plot_idx], lw = 2,color = colors[3],alpha = 0.1)
    ax[1,0].set_xlabel('Time step')
    ax[1,0].set_ylabel(r'$F$')
    ax[1,1].plot(data['soc'][data['trajectory'] == plot_idx],data['I'][data['trajectory'] == plot_idx], lw = 2,color = colors[4],alpha = 0.1)
    ax[1,1].set_xlabel('Time step')
    ax[1,1].set_ylabel(r'$I$')
    ax[1,2].plot(data['soc'][data['trajectory'] == plot_idx],data['u'][data['trajectory'] == plot_idx], lw = 2,color = colors[5],alpha = 0.1)
    ax[1,2].set_xlabel('Time step')
    ax[1,2].set_ylabel(r'$\Delta u$')

plt.tight_layout()

# %%
plot_idx = data_pulse['trajectory'] == 3
f, ax = plt.subplots(2, 3, figsize=(10, 5))
ax[0,0].plot(data_pulse['V'][plot_idx], '-', color = colors[0], lw = 2)
ax[0,0].set_xlabel('Time step')
ax[0,0].set_ylabel('$V_{cell}$')
ax[0,1].plot(data_pulse['Ue'][plot_idx], '-', color = colors[1], lw = 2)
ax[0,1].set_xlabel('Time step')
ax[0,1].set_ylabel('Ue')
ax[0,2].plot(data_pulse['eta'][plot_idx], '-', color = colors[2], lw = 2)
ax[0,2].set_xlabel('Time step')
ax[0,2].set_ylabel(r'$\eta$')
ax[1,0].plot(data_pulse['F'][plot_idx], lw = 2,color = colors[3])
ax[1,0].set_xlabel('Time step')
ax[1,0].set_ylabel(r'$F$')
ax[1,1].plot(data_pulse['I'][plot_idx], lw = 2,color = colors[4])
ax[1,1].set_xlabel('Time step')
ax[1,1].set_ylabel(r'$I$')
ax[1,2].plot(data_pulse['u'][plot_idx], lw = 2,color = colors[5])
ax[1,2].set_xlabel('Time step')
ax[1,2].set_ylabel(r'$\Delta u$')

plt.tight_layout()
plt.show()

# %%
# Correlation matrix for current signals in this batch

X = data[['V','I','F','u_par','Ue','dF','dV','eta']].values
feature_names = ['$V$','$I$','$R_x$',r'$\Delta u$','$E_{Ue}$',r'$\Delta R_x$',r'$\Delta V$',r'$\eta$']
with np.errstate(invalid="ignore", divide="ignore"):
    corr = np.corrcoef(X, rowvar=False)


fig, ax_corr = plt.subplots(figsize=(7, 5))
im = ax_corr.imshow(corr, cmap="coolwarm", vmin=-1, vmax=1)

ax_corr.set_xticks(np.arange(len(feature_names)))
ax_corr.set_yticks(np.arange(len(feature_names)))
ax_corr.set_xticklabels(feature_names, rotation=45, ha="right")
ax_corr.set_yticklabels(feature_names)
ax_corr.set_title("Correlation matrix")

for i in range(corr.shape[0]):
    for j in range(corr.shape[1]):
        ax_corr.text(j, i, f"{corr[i, j]:.2f}", ha="center", va="center", color="black")

fig.colorbar(im, ax=ax_corr, label="Correlation")
plt.tight_layout()
plt.show()

# %%
traj = 0
#plt.plot(data['u'][data['trajectory'] == traj], data['F'][data['trajectory'] == traj], lw = 2, color = colors[0])
groups = data.groupby('u')['F']


first_F = data.groupby('u')['F'].first()
k = abs(first_F / (data.groupby('u')['u'].first()))
plt.plot(data.groupby('u')['u'].first(), first_F, 'o-', color = colors[0], label = r'$F(\Delta u)$')
plt.plot(data.groupby('u')['u'].first(), -k * data.groupby('u')['u'].first(), '--', color = colors[1], label = r'$-k\Delta u$')
plt.xlabel(r'$\Delta u$ [µm]')
plt.ylabel(r'$F$ [GN]')
plt.legend()
print(f'{100 * k.values[0]:.3f} GN/mm')
print(k.values[0])
# Out:
# 53.164 GN/mm
# 0.5316441632537718

# %%
traj = 1

ds = data['F'][data['trajectory'] == traj] / k.values[0] + data['u'][data['trajectory'] == traj] 

plt.plot(ds,data['F'][data['trajectory'] == traj], lw = 2, color = colors[1])
plt.xlabel(r'Swelling $\Delta s$ [µm]')
plt.ylabel(r'$F$ [MN]')
# Out:
# Text(0, 0.5, '$F$ [MN]')

# %% [markdown]
# # Normalizing data
#
# ### Characteristics that should be preserved after normalization?
#
#
# - $\Delta u$: It should primarily be compression, so have a negative sign.
#     - $\Delta u / L$ gives a fractional compression
# - $I$: The sign of it should reflect if we have charge/discharge
#     - Maybe just a `standard` normalization on this?
# - $V$: It should always be positive
#     - Maybe just a `min-max` normalization on this?
# - $F$: The sign of it should in some way reflect the sign of $\Delta u$. Especially in the cases with low swelling.
#     - Maybe just a `standard` normalization on this?

# %%
N_trajs = len(data['trajectory'].unique())


X = data[['I','u','soc','Ue','trajectory']].values
y = data[['V','F','trajectory']].values

# %%
N_trajs = len(data['trajectory'].unique())

x_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32)

split = (data['trajectory']<=int(N_trajs *0.8)).sum()

def _split_flat(arr, split = split):
    return arr[:split], arr[split:]   # Same as reshape(B * T, C)    # (B*T, 4)

x_train, x_test = _split_flat(x_tensor); y_train, y_test = _split_flat(y_tensor)

print(f'Number of trajectories in train: {int(N_trajs * 0.8)} out of {N_trajs}')

print(f'X shape {x_tensor.shape}\ty shape {y_tensor.shape}\nX-train shape: {x_train.shape}\ty-train shape: {y_train.shape}\nX-test shape: {x_test.shape}\ty-test shape: {y_test.shape}')
# Out:
# Number of trajectories in train: 198 out of 248
# X shape torch.Size([415557, 5])	y shape torch.Size([415557, 3])
# X-train shape: torch.Size([334590, 5])	y-train shape: torch.Size([334590, 3])
# X-test shape: torch.Size([80967, 5])	y-test shape: torch.Size([80967, 3])

# %%
def _split_flat(arr, split = split):
    return arr[:split], arr[split:]   # Same as reshape(B * T, C)    # (B*T, 4)

def get_train_test(case,df_DC = data,df_pulse = data_pulse):
    if case == 'R1':
        df = df_DC
    elif case == 'C1':
        df = df_pulse
    N_trajs = len(df['trajectory'].unique())
    x_tensor = torch.tensor(df[['I','u','soc','Ue','trajectory']].values, dtype=torch.float32)
    y_tensor = torch.tensor(df[['V','F','trajectory']].values, dtype=torch.float32)
    split = (df['trajectory']<=int(N_trajs *0.8)).sum()
    x_train, x_test = _split_flat(x_tensor, split); y_train, y_test = _split_flat(y_tensor, split)
    print(f'Number of trajectories in train: {int(N_trajs * 0.8)} out of {N_trajs}')
    print(f'X shape {x_tensor.shape}\ty shape {y_tensor.shape}\nX-train shape: {x_train.shape}\ty-train shape: {y_train.shape}\nX-test shape: {x_test.shape}\ty-test shape: {y_test.shape}')
    return x_train, y_train, x_test, y_test, N_trajs

# %%
x_train, y_train, x_test, y_test,_ = get_train_test(case = 'R1')
x_train_pulse, y_train_pulse, x_test_pulse, y_test_pulse,_= get_train_test('C1')
# Out:
# Number of trajectories in train: 198 out of 248
# X shape torch.Size([415557, 5])	y shape torch.Size([415557, 3])
# X-train shape: torch.Size([334590, 5])	y-train shape: torch.Size([334590, 3])
# X-test shape: torch.Size([80967, 5])	y-test shape: torch.Size([80967, 3])
# Number of trajectories in train: 40 out of 50
# X shape torch.Size([126623, 5])	y shape torch.Size([126623, 3])
# X-train shape: torch.Size([99530, 5])	y-train shape: torch.Size([99530, 3])
# X-test shape: torch.Size([27093, 5])	y-test shape: torch.Size([27093, 3])

# %%
import torch.nn.functional as TF

''' R1 '''

def ECM_model(Ue, I, R0, U1):
    #Ue = soc_to_Ue(soc,return_torch=True    )
    return Ue - I * R0 - U1

def Mech_model(u,Fs , k = k.values[0]):
    return -k * u + Fs

def soc_force_func(soc, variable = 'F'):
    
    if variable == 'F': 
        forcing_const = 0.9975
    elif variable == 'U':
        forcing_const = 0.995
    return 1 - np.exp((soc-1) / (1 - forcing_const));

def R0_func(I,u):
    x0 = u
    x1 = I
    return x0*(-0.0001887521) - 7.049519e-5*x1 + 0.00844669;



class R1Net(nn.Module):
    def __init__(self, input_size=3, hidden_size=64): 
        super(R1Net, self).__init__()
        self.Snet = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 2)   # output size is 2 for (V_cell, F)
        )

    def forward(self, x):
        
        if False:
            Fs_raw = self.net(x)[:,0] #* force_func(soc)  # (T,)
            U1_raw = self.net(x)[:,1] 
            soc = x[:,2]
            Fs = soc_force_func(soc, variable='F') * Fs_raw;
            U1 = soc_force_func(soc, variable = 'U') * TF.softplus(U1_raw);
            
            return Fs, U1
        else:
            Fs_raw, R1_raw = self.Snet(x)[:,0], self.Snet(x)[:,1]
            soc = x[:,2]
            Fs = soc_force_func(soc) * Fs_raw
            R1 = TF.softplus(R1_raw) / 100  # Ensure R1 is non-negative

            return Fs, R1

modelR1 = R1Net()
optimizerR1 = optim.Adam(modelR1.parameters(), lr=1e-3)

# %%
class C1Net(nn.Module):
    def __init__(self, input_size=2, hidden_size=32): 
        super(C1Net, self).__init__()
        self.Cnet = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 1)   # output size is 2 for (V_cell, F)
        )

    def forward(self, x):
        
        if False:
            Fs_raw = self.net(x)[:,0] #* force_func(soc)  # (T,)
            U1_raw = self.net(x)[:,1] 
            soc = x[:,2]
            Fs = soc_force_func(soc, variable='F') * Fs_raw;
            U1 = soc_force_func(soc, variable = 'U') * TF.softplus(U1_raw);
            
            return Fs, U1
        else:

            C_min = 100
            C_max = 2e4
            C1_raw = self.Cnet(x)[:,0]

            C1 = C_min + TF.sigmoid(C1_raw) * (C_max - C_min) # Ensure R1 is non-negative and bounded between C_min and C_max

            return C1
        
modelC1 = C1Net()
optimizerC1 = optim.Adam(modelC1.parameters(), lr=1e-3)

# %%
def model(I,u,soc,Ue,case, modelR = modelR1, modelC = modelC1):
    R0 = R0_func(I,u)
    x = torch.stack((I,u,soc), dim=1)
    if case == 'R1':
        Fs, R1 = modelR(x)
        U1 = R1 * I
        return torch.stack([ECM_model(Ue, I, R0, U1),Mech_model(u, Fs)], dim=1) 
    elif case == 'C1':
        modelR.eval()
        U1_list = [torch.tensor(0.0)]  # Initialize U1 list with the first value as 0
        with torch.no_grad():
            R1 = modelR(x)[1].squeeze()
        
        for t in range(1, len(I)):
            x_t = torch.stack((u[t], soc[t]), dim=0).unsqueeze(0)  # (1, 3)
            C1 = modelC(x_t).squeeze()  # (1,) -> scalar
            #print(f't: {t}, C1: {C1.item():.2f} F, R1: {R1[t].item():.4f} Ω')
            #if t % 500 == 0:
                #print(f't: {t}, C1: {C1.item():.2f} F, R1: {1000*R1[t].item():.1f} mΩ')
            U1_next = U1_list[-1] * (1 - 1 / (R1[t] * C1 + 1e-8)) + I[t] / (C1 + 1e-8)
            U1_list.append(U1_next)
        U1 = torch.stack(U1_list)

        V = ECM_model(Ue, I, R0, U1)  # (T,)

        return V.unsqueeze(1)  # (T,1)

# %%
def get_NN_opt(case, optimizerR1=optimizerR1, optimizerC1=optimizerC1):
    if case == 'R1':
        return optimizerR1
    elif case == 'C1':
        return optimizerC1
    else:
        raise ValueError(f"Unknown case: {case}. Valid cases are 'R1' and 'C1'.")

# %%
try: 
    print(summary(modelR1, input_data=x_train[:2]))
except Exception as e:
    print(f"Error in model summary: {e}")
# Out:
# Error in model summary: Failed to run torchinfo. See above stack traces for more details. Executed layers up to: []

# %%
def training(epochs=30, case='R1', modelR1=modelR1, modelC1=modelC1, optimizerR1=optimizerR1, optimizerC1=optimizerC1):
    history = {"loss": [], "V_loss": [], "F_loss": [], "time per ep": []}

    x_train, y_train, x_test, y_test, N_trajs = get_train_test(case = case)
    optimizer = get_NN_opt(case)
    tot_time = 0.
    MAX_TIME_min = 1.5
    for ep in range(epochs):
        start_t = time.perf_counter()    
        ep_loss = 0.0

        for traj in range(int(N_trajs * 0.8)):

            x_traj = x_train[x_train[:, -1] == traj]
            y_traj = y_train[y_train[:, -1] == traj]

            # Inputs
            model_input = x_traj[:, :-1]      # (T, 3)
            model_target = y_traj[:,:-1]     # (T, 2)

            I   = model_input[:, 0]
            u   = model_input[:, 1]
            soc = model_input[:, 2]
            Ue  = model_input[:, 3]
            
            #Ue = soc_to_Ue(soc, return_torch=True)  # (T,)      

            # Forward
            if case == 'R1':
                y_pred = model(I,u,soc,Ue, case = case)                # (T, 2)
                V_loss = nn.MSELoss()(y_pred[:,0], model_target[:,0])
                F_loss = nn.MSELoss()(y_pred[:,1], model_target[:,1])
            #U_1_curve_loss = ((U1[2:] - 2*U1[1:-1] + U1[:-2])**2).mean()
                loss = V_loss + F_loss #+ 1e-2 * U_1_curve_loss
            elif case == 'C1':
                y_pred = model(I,u,soc,Ue, case = case, modelR=modelR1,modelC=modelC1)                # (T, 2)
                #print(y_pred.shape, model_target.shape)
                V_loss = nn.MSELoss()(y_pred.squeeze(), model_target[:,0])
                loss = V_loss 
                #print(f'Traj {traj} | loss {loss.item():.2e} | V_loss {V_loss.item():.2e}')
            # Backprop
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            ep_loss += loss.item()
        #print(f"Epoch {ep+1}/{epochs} | loss {ep_loss:.2e} | V_loss {V_loss.item():.2e} | F_loss {F_loss.item():.2e} | time {(time.perf_counter() - start_t):.2f}s")
        ep_loss /= N_trajs

        history["loss"].append(ep_loss)
        history["V_loss"].append(V_loss.item() / N_trajs)
        if case == 'R1':
            history["F_loss"].append(F_loss.item() / N_trajs)
        elif case == 'C1':
            history["F_loss"].append(0.0)
        end_t = time.perf_counter()
        history["time per ep"].append(end_t - start_t)   
        
        tot_time += end_t - start_t
       
        if ep == 0:
            print(f'ETA: {(end_t - start_t) * epochs / 60:.2f} min')

        # if tot_time > MAX_TIME_min*60:
        #     print(f"Early stopping: Total training time exceeded {MAX_TIME_min} minutes.")
        #     break
        print(f'Epoch {ep+1}/{epochs} | loss {ep_loss:.2e} | V_loss {history['V_loss'][-1]:.2e} | F_loss {history['F_loss'][-1]:.2e} | time {end_t - start_t:.2f}s | total time {tot_time%60}:{(tot_time/60):.2f} min')
        #print(f"Epoch {ep+1} | loss {ep_loss:.2e} | V_loss {V_loss.item():.2e} | F_loss {F_loss.item():.2e} | time {end_t - start_t:.2f}s")

    return history

# %%
historyR1 = training(epochs=100, case='R1')
# Out:
# Number of trajectories in train: 198 out of 248
# X shape torch.Size([415557, 5])	y shape torch.Size([415557, 3])
# X-train shape: torch.Size([334590, 5])	y-train shape: torch.Size([334590, 3])
# X-test shape: torch.Size([80967, 5])	y-test shape: torch.Size([80967, 3])
# ETA: 1.36 min
# Epoch 1/100 | loss 4.45e-02 | V_loss 4.06e-05 | F_loss 7.37e-05 | time 0.81s | total time 0.8141218749951804:0.01 min
# Epoch 2/100 | loss 1.90e-02 | V_loss 3.64e-05 | F_loss 3.18e-05 | time 0.64s | total time 1.4491594169958262:0.02 min
# Epoch 3/100 | loss 7.93e-03 | V_loss 3.30e-05 | F_loss 1.99e-06 | time 0.64s | total time 2.0893751670009806:0.03 min
# Epoch 4/100 | loss 7.62e-03 | V_loss 3.11e-05 | F_loss 3.09e-06 | time 0.63s | total time 2.722812833999342:0.05 min
# Epoch 5/100 | loss 9.23e-03 | V_loss 2.99e-05 | F_loss 9.99e-05 | time 0.64s | total time 3.3646088339955895:0.06 min
# Epoch 6/100 | loss 7.94e-03 | V_loss 2.52e-05 | F_loss 3.53e-05 | time 0.64s | total time 4.002174791996367:0.07 min
# Epoch 7/100 | loss 4.80e-03 | V_loss 2.57e-05 | F_loss 2.71e-07 | time 0.63s | total time 4.636403041993617:0.08 min
# Epoch 8/100 | loss 5.48e-03 | V_loss 3.17e-05 | F_loss 1.11e-05 | time 0.63s | total time 5.269513541992637:0.09 min
# Epoch 9/100 | loss 6.28e-03 | V_loss 2.40e-05 | F_loss 3.52e-06 | time 0.63s | total time 5.901964999990014:0.10 min
# Epoch 10/100 | loss 5.08e-03 | V_loss 2.17e-05 | F_loss 1.43e-08 | time 0.64s | total time 6.543740208995587:0.11 min
# Epoch 11/100 | loss 5.51e-03 | V_loss 1.86e-05 | F_loss 1.23e-05 | time 0.63s | total time 7.173606499993184:0.12 min
# Epoch 12/100 | loss 4.28e-03 | V_loss 2.32e-05 | F_loss 5.19e-07 | time 0.63s | total time 7.803860457992414:0.13 min
# Epoch 13/100 | loss 4.07e-03 | V_loss 3.01e-05 | F_loss 1.80e-06 | time 0.63s | total time 8.437859957994078:0.14 min
# Epoch 14/100 | loss 4.53e-03 | V_loss 2.22e-05 | F_loss 5.31e-06 | time 0.63s | total time 9.069827832994633:0.15 min
# Epoch 15/100 | loss 3.17e-03 | V_loss 2.88e-05 | F_loss 2.37e-06 | time 0.63s | total time 9.700233374991512:0.16 min
# Epoch 16/100 | loss 4.61e-03 | V_loss 1.04e-05 | F_loss 1.45e-05 | time 0.71s | total time 10.410506999993231:0.17 min
# Epoch 17/100 | loss 3.40e-03 | V_loss 2.17e-05 | F_loss 2.31e-06 | time 0.63s | total time 11.037692291989515:0.18 min
# Epoch 18/100 | loss 2.79e-03 | V_loss 1.68e-05 | F_loss 7.19e-07 | time 0.63s | total time 11.66768254199269:0.19 min
# Epoch 19/100 | loss 3.23e-03 | V_loss 1.44e-05 | F_loss 1.19e-06 | time 0.63s | total time 12.293408582991106:0.20 min
# Epoch 20/100 | loss 2.49e-03 | V_loss 1.65e-05 | F_loss 9.06e-07 | time 0.63s | total time 12.920224707988382:0.22 min
# Epoch 21/100 | loss 3.45e-03 | V_loss 9.64e-06 | F_loss 1.06e-05 | time 0.62s | total time 13.540369915986957:0.23 min
# Epoch 22/100 | loss 3.85e-03 | V_loss 1.24e-05 | F_loss 1.77e-05 | time 0.62s | total time 14.159761207985866:0.24 min
# Epoch 23/100 | loss 2.32e-03 | V_loss 8.21e-06 | F_loss 4.78e-06 | time 0.63s | total time 14.793244165986835:0.25 min
# Epoch 24/100 | loss 1.55e-03 | V_loss 9.48e-06 | F_loss 1.81e-07 | time 0.87s | total time 15.666007790983713:0.26 min
# Epoch 25/100 | loss 2.34e-03 | V_loss 2.38e-05 | F_loss 1.21e-05 | time 0.68s | total time 16.34225529099058:0.27 min
# Epoch 26/100 | loss 3.32e-03 | V_loss 5.03e-06 | F_loss 5.42e-06 | time 0.64s | total time 16.98329216599086:0.28 min
# Epoch 27/100 | loss 1.51e-03 | V_loss 9.67e-06 | F_loss 2.93e-06 | time 0.63s | total time 17.611922790994868:0.29 min
# Epoch 28/100 | loss 1.30e-03 | V_loss 1.09e-05 | F_loss 7.85e-08 | time 0.63s | total time 18.238711998994404:0.30 min
# Epoch 29/100 | loss 1.37e-03 | V_loss 1.27e-05 | F_loss 5.25e-06 | time 0.63s | total time 18.868553040992992:0.31 min
# Epoch 30/100 | loss 2.62e-03 | V_loss 1.47e-05 | F_loss 1.04e-06 | time 0.64s | total time 19.50718691599468:0.33 min
# Epoch 31/100 | loss 2.11e-03 | V_loss 1.19e-05 | F_loss 6.04e-05 | time 0.62s | total time 20.13128137399326:0.34 min
# Epoch 32/100 | loss 6.23e-03 | V_loss 9.68e-06 | F_loss 2.51e-07 | time 0.63s | total time 20.76175020699884:0.35 min
# Epoch 33/100 | loss 1.44e-03 | V_loss 9.36e-06 | F_loss 1.80e-06 | time 0.63s | total time 21.39026299899706:0.36 min
# Epoch 34/100 | loss 1.07e-03 | V_loss 1.41e-05 | F_loss 1.60e-07 | time 0.63s | total time 22.02224258199567:0.37 min
# Epoch 35/100 | loss 1.30e-03 | V_loss 1.30e-05 | F_loss 1.33e-06 | time 0.62s | total time 22.645453706994886:0.38 min
# Epoch 36/100 | loss 1.58e-03 | V_loss 6.37e-06 | F_loss 6.45e-06 | time 0.62s | total time 23.26772074899054:0.39 min
# Epoch 37/100 | loss 1.37e-03 | V_loss 1.23e-05 | F_loss 2.64e-06 | time 0.63s | total time 23.896154665984795:0.40 min
# Epoch 38/100 | loss 1.37e-03 | V_loss 1.97e-05 | F_loss 1.79e-08 | time 0.63s | total time 24.52322574898426:0.41 min
# Epoch 39/100 | loss 1.51e-03 | V_loss 1.29e-05 | F_loss 1.10e-06 | time 0.62s | total time 25.145120998982748:0.42 min
# Epoch 40/100 | loss 1.45e-03 | V_loss 1.02e-05 | F_loss 5.79e-06 | time 0.62s | total time 25.76766629098711:0.43 min
# Epoch 41/100 | loss 1.16e-03 | V_loss 1.42e-05 | F_loss 7.16e-07 | time 0.63s | total time 26.39451916598773:0.44 min
# Epoch 42/100 | loss 1.25e-03 | V_loss 1.59e-05 | F_loss 1.14e-07 | time 1.26s | total time 27.65893574898655:0.46 min
# Epoch 43/100 | loss 1.34e-03 | V_loss 7.54e-06 | F_loss 2.09e-06 | time 1.12s | total time 28.78096795798774:0.48 min
# Epoch 44/100 | loss 1.18e-03 | V_loss 4.61e-06 | F_loss 5.52e-06 | time 0.84s | total time 29.617027790991415:0.49 min
# Epoch 45/100 | loss 1.10e-03 | V_loss 6.48e-06 | F_loss 3.14e-06 | time 0.65s | total time 30.26464520698937:0.50 min
# Epoch 46/100 | loss 1.01e-03 | V_loss 1.28e-05 | F_loss 1.11e-07 | time 0.77s | total time 31.038427915991633:0.52 min
# Epoch 47/100 | loss 1.38e-03 | V_loss 3.01e-05 | F_loss 1.58e-07 | time 0.64s | total time 31.678826873991056:0.53 min
# Epoch 48/100 | loss 1.19e-03 | V_loss 2.06e-05 | F_loss 6.42e-07 | time 0.68s | total time 32.36369879098493:0.54 min
# Epoch 49/100 | loss 1.29e-03 | V_loss 6.09e-06 | F_loss 3.19e-06 | time 0.85s | total time 33.2173814989801:0.55 min
# Epoch 50/100 | loss 9.89e-04 | V_loss 1.43e-05 | F_loss 1.11e-06 | time 0.71s | total time 33.931996123974386:0.57 min
# Epoch 51/100 | loss 1.43e-03 | V_loss 1.26e-05 | F_loss 4.18e-07 | time 0.62s | total time 34.54879587396863:0.58 min
# Epoch 52/100 | loss 9.96e-04 | V_loss 1.37e-05 | F_loss 8.52e-08 | time 0.62s | total time 35.16555420796794:0.59 min
# Epoch 53/100 | loss 1.23e-03 | V_loss 8.21e-06 | F_loss 3.24e-06 | time 0.61s | total time 35.780415957968216:0.60 min
# Epoch 54/100 | loss 1.00e-03 | V_loss 1.13e-05 | F_loss 3.33e-07 | time 0.62s | total time 36.39812695796718:0.61 min
# Epoch 55/100 | loss 1.09e-03 | V_loss 5.13e-06 | F_loss 4.82e-07 | time 0.61s | total time 37.01258858296933:0.62 min
# Epoch 56/100 | loss 1.24e-03 | V_loss 6.79e-06 | F_loss 3.81e-07 | time 0.66s | total time 37.66776949997438:0.63 min
# Epoch 57/100 | loss 7.27e-04 | V_loss 1.56e-05 | F_loss 2.61e-07 | time 0.62s | total time 38.284497874978115:0.64 min
# Epoch 58/100 | loss 1.04e-03 | V_loss 9.09e-06 | F_loss 2.31e-08 | time 0.62s | total time 38.90171870897757:0.65 min
# Epoch 59/100 | loss 9.86e-04 | V_loss 4.52e-06 | F_loss 7.30e-07 | time 0.61s | total time 39.51667245897988:0.66 min
# Epoch 60/100 | loss 7.53e-04 | V_loss 2.10e-05 | F_loss 5.94e-08 | time 0.61s | total time 40.1299380839846:0.67 min
# Epoch 61/100 | loss 9.52e-04 | V_loss 1.32e-05 | F_loss 2.88e-08 | time 0.62s | total time 40.74688633398182:0.68 min
# Epoch 62/100 | loss 9.75e-04 | V_loss 5.58e-06 | F_loss 1.14e-06 | time 0.62s | total time 41.363269208981364:0.69 min
# Epoch 63/100 | loss 1.09e-03 | V_loss 1.87e-05 | F_loss 2.08e-07 | time 0.61s | total time 41.97209429198119:0.70 min
# Epoch 64/100 | loss 8.94e-04 | V_loss 2.67e-06 | F_loss 3.88e-06 | time 0.62s | total time 42.590518583980156:0.71 min
# Epoch 65/100 | loss 7.29e-04 | V_loss 7.19e-06 | F_loss 2.45e-07 | time 0.61s | total time 43.19899787497707:0.72 min
# Epoch 66/100 | loss 7.32e-04 | V_loss 9.83e-06 | F_loss 2.14e-08 | time 0.61s | total time 43.8116068749805:0.73 min
# Epoch 67/100 | loss 9.68e-04 | V_loss 6.64e-06 | F_loss 1.83e-07 | time 0.62s | total time 44.430791249986214:0.74 min
# Epoch 68/100 | loss 1.03e-03 | V_loss 8.28e-06 | F_loss 1.01e-06 | time 0.61s | total time 45.042328749987064:0.75 min
# Epoch 69/100 | loss 8.23e-04 | V_loss 6.28e-06 | F_loss 4.61e-07 | time 0.62s | total time 45.66085237498919:0.76 min
# Epoch 70/100 | loss 7.61e-04 | V_loss 7.33e-06 | F_loss 3.63e-07 | time 0.61s | total time 46.27544808298262:0.77 min
# Epoch 71/100 | loss 6.56e-04 | V_loss 1.37e-05 | F_loss 4.38e-08 | time 0.61s | total time 46.88727791597921:0.78 min
# Epoch 72/100 | loss 7.54e-04 | V_loss 6.63e-06 | F_loss 9.78e-07 | time 0.62s | total time 47.50471583297622:0.79 min
# Epoch 73/100 | loss 7.52e-04 | V_loss 7.76e-06 | F_loss 5.49e-07 | time 0.61s | total time 48.11286562497844:0.80 min
# Epoch 74/100 | loss 6.18e-04 | V_loss 1.48e-05 | F_loss 1.27e-07 | time 0.61s | total time 48.72664187497867:0.81 min
# Epoch 75/100 | loss 7.02e-04 | V_loss 1.63e-05 | F_loss 5.61e-08 | time 0.62s | total time 49.347911541983194:0.82 min
# Epoch 76/100 | loss 1.09e-03 | V_loss 1.85e-05 | F_loss 2.31e-07 | time 0.61s | total time 49.96104349998495:0.83 min
# Epoch 77/100 | loss 6.26e-04 | V_loss 1.92e-05 | F_loss 1.87e-07 | time 0.62s | total time 50.580728166984045:0.84 min
# Epoch 78/100 | loss 5.30e-04 | V_loss 1.31e-05 | F_loss 6.95e-08 | time 0.61s | total time 51.193622207982116:0.85 min
# Epoch 79/100 | loss 5.34e-04 | V_loss 1.01e-05 | F_loss 8.82e-08 | time 0.63s | total time 51.81916812398413:0.86 min
# Epoch 80/100 | loss 5.43e-04 | V_loss 4.78e-06 | F_loss 1.48e-07 | time 0.61s | total time 52.4337089159817:0.87 min
# Epoch 81/100 | loss 6.49e-04 | V_loss 8.60e-06 | F_loss 3.35e-07 | time 0.61s | total time 53.042240873983246:0.88 min
# Epoch 82/100 | loss 6.05e-04 | V_loss 7.62e-06 | F_loss 7.30e-08 | time 0.61s | total time 53.65514391598117:0.89 min
# Epoch 83/100 | loss 4.94e-04 | V_loss 6.85e-06 | F_loss 4.23e-08 | time 0.69s | total time 54.34548104098212:0.91 min
# Epoch 84/100 | loss 4.72e-04 | V_loss 3.78e-06 | F_loss 2.38e-07 | time 0.61s | total time 54.95512258198141:0.92 min
# Epoch 85/100 | loss 8.76e-04 | V_loss 5.71e-06 | F_loss 2.71e-07 | time 0.62s | total time 55.57213466598478:0.93 min
# Epoch 86/100 | loss 8.55e-04 | V_loss 7.78e-06 | F_loss 5.44e-07 | time 0.61s | total time 56.1847932079836:0.94 min
# Epoch 87/100 | loss 4.94e-04 | V_loss 5.77e-06 | F_loss 4.21e-07 | time 0.61s | total time 56.793612249988655:0.95 min
# Epoch 88/100 | loss 5.53e-04 | V_loss 1.09e-05 | F_loss 1.87e-07 | time 0.61s | total time 57.40665104198706:0.96 min
# Epoch 89/100 | loss 4.11e-04 | V_loss 4.59e-06 | F_loss 3.57e-08 | time 0.62s | total time 58.03078470798937:0.97 min
# Epoch 90/100 | loss 4.28e-04 | V_loss 3.69e-06 | F_loss 1.30e-07 | time 0.65s | total time 58.67983191598614:0.98 min
# Epoch 91/100 | loss 3.30e-04 | V_loss 8.66e-06 | F_loss 1.09e-07 | time 0.61s | total time 59.291699540983245:0.99 min
# Epoch 92/100 | loss 4.35e-04 | V_loss 6.16e-06 | F_loss 2.36e-08 | time 0.61s | total time 59.90397758298059:1.00 min
# Epoch 93/100 | loss 4.08e-04 | V_loss 4.35e-06 | F_loss 3.15e-08 | time 0.62s | total time 0.5220303329770104:1.01 min
# Epoch 94/100 | loss 5.12e-04 | V_loss 2.35e-06 | F_loss 3.27e-08 | time 0.62s | total time 1.144221791983:1.02 min
# Epoch 95/100 | loss 3.61e-04 | V_loss 8.91e-06 | F_loss 5.26e-07 | time 0.61s | total time 1.7573675839812495:1.03 min
# Epoch 96/100 | loss 3.88e-04 | V_loss 9.92e-06 | F_loss 5.42e-07 | time 0.62s | total time 2.3727289179805666:1.04 min
# Epoch 97/100 | loss 4.76e-04 | V_loss 4.05e-06 | F_loss 8.36e-07 | time 0.63s | total time 3.0043954179782304:1.05 min
# Epoch 98/100 | loss 4.68e-04 | V_loss 1.11e-05 | F_loss 4.56e-08 | time 0.62s | total time 3.6197807509815902:1.06 min
# Epoch 99/100 | loss 4.17e-04 | V_loss 1.09e-05 | F_loss 1.05e-07 | time 0.63s | total time 4.24528587597888:1.07 min
# Epoch 100/100 | loss 6.42e-04 | V_loss 4.52e-06 | F_loss 5.50e-07 | time 0.61s | total time 4.856797917978838:1.08 min

# %%
print(np.mean(historyR1['loss'][-5:]))

fig, ax = plt.subplot_mosaic(
    [
        ["loss", "combined"],
        ["V_loss", "combined"],
        ["F_loss", "combined"]
    ],
    figsize=(12, 5),
    sharex=True
)

# Individual plots
ax["loss"].semilogy(historyR1["loss"], label="Train loss", color=colors[0])
ax["V_loss"].semilogy(historyR1["V_loss"], label=r"Train $R$ loss", color=colors[1])
ax["F_loss"].semilogy(historyR1["F_loss"], label=r"Train $F$ loss", color=colors[2])

# Combined plot (all together)
ax["combined"].semilogy(historyR1["loss"], label="Loss", color=colors[0])
ax["combined"].semilogy(historyR1["V_loss"], label=r"$R$ loss", color=colors[1])
ax["combined"].semilogy(historyR1["F_loss"], label=r"$F$ loss", color=colors[2])

# Labels and styling
ax["F_loss"].set_xlabel("epoch")
ax["combined"].set_xlabel("epoch")

for key in ["loss", "V_loss", "F_loss", "combined"]:
    ax[key].set_ylabel("MSE")
    ax[key].legend()
    ax[key].grid(True, which="both", ls="--", lw=0.5)

plt.tight_layout()
plt.show()
# Out:
# 0.0004779961930609951

# %%
historyC1 = training(epochs=30, case='C1')
# Out:
# Number of trajectories in train: 40 out of 50
# X shape torch.Size([126623, 5])	y shape torch.Size([126623, 3])
# X-train shape: torch.Size([99530, 5])	y-train shape: torch.Size([99530, 3])
# X-test shape: torch.Size([27093, 5])	y-test shape: torch.Size([27093, 3])
# ETA: 13.00 min
# Epoch 1/30 | loss 2.92e-02 | V_loss 8.98e-04 | F_loss 0.00e+00 | time 26.00s | total time 25.998100208002143:0.43 min
# Epoch 2/30 | loss 2.11e-02 | V_loss 6.15e-04 | F_loss 0.00e+00 | time 26.11s | total time 52.104381832999934:0.87 min
# Epoch 3/30 | loss 1.54e-02 | V_loss 4.66e-04 | F_loss 0.00e+00 | time 25.90s | total time 18.000187666002603:1.30 min
# Epoch 4/30 | loss 1.45e-02 | V_loss 4.23e-04 | F_loss 0.00e+00 | time 25.98s | total time 43.98368320699956:1.73 min
# Epoch 5/30 | loss 1.43e-02 | V_loss 4.04e-04 | F_loss 0.00e+00 | time 25.46s | total time 9.44424433200038:2.16 min
# Epoch 6/30 | loss 1.41e-02 | V_loss 3.93e-04 | F_loss 0.00e+00 | time 25.92s | total time 35.367475499006105:2.59 min
# Epoch 7/30 | loss 1.40e-02 | V_loss 3.88e-04 | F_loss 0.00e+00 | time 26.00s | total time 1.3670331660032389:3.02 min
# Epoch 8/30 | loss 1.40e-02 | V_loss 3.86e-04 | F_loss 0.00e+00 | time 27.88s | total time 29.24960558200837:3.49 min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 historyC1 = training(epochs=30, case='C1')
#
# Cell In[30], line 36, in training(epochs, case, modelR1, modelC1, optimizerR1, optimizerC1)
#      34     loss = V_loss + F_loss #+ 1e-2 * U_1_curve_loss
#      35 elif case == 'C1':
# ---> 36     y_pred = model(I,u,soc,Ue, case = case, modelR=modelR1,modelC=modelC1)                # (T, 2)
#      37     #print(y_pred.shape, model_target.shape)
#      38     V_loss = nn.MSELoss()(y_pred.squeeze(), model_target[:,0])
#
# Cell In[27], line 16, in model(I, u, soc, Ue, case, modelR, modelC)
#      14 for t in range(1, len(I)):
#      15     x_t = torch.stack((u[t], soc[t]), dim=0).unsqueeze(0)  # (1, 3)
# ---> 16     C1 = modelC(x_t).squeeze()  # (1,) -> scalar
#      17     #print(f't: {t}, C1: {C1.item():.2f} F, R1: {R1[t].item():.4f} Ω')
#      18     #if t % 500 == 0:
#      19         #print(f't: {t}, C1: {C1.item():.2f} F, R1: {1000*R1[t].item():.1f} mΩ')
#      20     U1_next = U1_list[-1] * (1 - 1 / (R1[t] * C1 + 1e-8)) + I[t] / (C1 + 1e-8)
#
# File ~/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# Cell In[26], line 26, in C1Net.forward(self, x)
#      24 C_min = 100
#      25 C_max = 2e4
# ---> 26 C1_raw = self.Cnet(x)[:,0]
#      28 C1 = C_min + TF.sigmoid(C1_raw) * (C_max - C_min) # Ensure R1 is non-negative and bounded between C_min and C_max
#      30 return C1
#
# File ~/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/torch/nn/modules/container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File ~/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplot_mosaic(
    [
        ["loss", "combined"],
        ["V_loss", "combined"],
        ["F_loss", "combined"]
    ],
    figsize=(12, 5),
    sharex=True
)

ax["loss"].semilogy(historyC1["loss"], label="Train loss", color=colors[0])
ax["V_loss"].semilogy(historyC1["V_loss"], label=r"Train $R$ loss", color=colors[1])
ax["F_loss"].semilogy(historyC1["F_loss"], label=r"Train $F$ loss", color=colors[2])    
ax["combined"].semilogy(historyC1["loss"], label="Loss", color=colors[0])
ax["combined"].semilogy(historyC1["V_loss"], label=r"$R$ loss", color=colors[1])
ax["combined"].semilogy(historyC1["F_loss"], label=r"$F$ loss", color=colors[2])    
ax["F_loss"].set_xlabel("epoch")
ax["combined"].set_xlabel("epoch")
for key in ["loss", "V_loss", "F_loss", "combined"]:
    ax[key].set_ylabel("MSE")
    ax[key].legend()
    ax[key].grid(True, which="both", ls="--", lw=0.5)
plt.tight_layout()
# Out:
# /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_36360/3659393962.py:14: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax["combined"].semilogy(historyC1["loss"], label="Loss", color=colors[0])

# %%
def evaluate(model, x_test, y_test):
    model.eval()
    with torch.no_grad():
        I = x_test[:,0]
        u = x_test[:,1]
        Ue = x_test[:,2]

        R0_pred, F_pred = model(x_test)
        y_pred = torch.stack([ECM_box(Ue,I,R0_pred), Mech_box(u,F_pred)],dim=1)

        #test_loss = nn.MSELoss()(y_pred, y_test).item()
    #print(f"Test MSE: {test_loss:.3e}")
    return y_pred.detach().numpy(), R0_pred.detach().numpy(), F_pred.detach().numpy()   


traj_eval = 0
y_pred, R0, F = evaluate(model, x_train[x_train[:,-1] == traj_eval][:,:-1], y_train[y_train[:,2] == traj_eval][:,:-1])


f, ax = plt.subplots(2, 2, figsize=(10, 8))
#plt.plot(x_test[:,0].numpy()* R0.detach().numpy(), label='Predicted $R_0$')
ax[0,0].plot(data['soc'][data['trajectory'] == traj_eval].values, R0, label=r'Predicted $IR_0$',color = colors[0])
ax[0,0].plot(data['soc'][data['trajectory'] == traj_eval].values,-data['eta'][data['trajectory'] == traj_eval].values / x_train[x_train[:,-1] == traj_eval][:,0].numpy(), label=r'True $\eta$',color = colors[1],ls = '--')

ax[0,1].plot(data['soc'][data['trajectory'] == traj_eval].values,data['V_t'][data['trajectory'] == traj_eval].values, label=r'True $V_t$', color = colors[1],ls = '--')
ax[0,1].plot(data['soc'][data['trajectory'] == traj_eval].values,y_pred[:,0], label=r'Predicted $V_t$', color = colors[0])

ax[1,0].plot(data['soc'][data['trajectory'] == traj_eval].values,data['Rx'][data['trajectory'] == traj_eval].values, label=r'True $F$', color = colors[1],ls = '--')
ax[1,0].plot(data['soc'][data['trajectory'] == traj_eval].values,y_pred[:,1], label=r'Predicted $F$', color = colors[0])    

ax[1,1].plot(data['soc'][data['trajectory'] == traj_eval].values,data['Rx'][data['trajectory'] == traj_eval].values + k.values[0] * x_train[x_train[:,-1] == traj_eval][:,1].numpy(), label=r'True $F_s$', color = colors[1], ls = '--')
ax[1,1].plot(data['soc'][data['trajectory'] == traj_eval].values,F, label=r'Pred $F_s$', color = colors[0])

for a in ax.flat:
    a.set_xlabel('State of Charge')
    a.legend()
    a.invert_xaxis()
ax[0,0].set_ylabel(r'$\eta$ and $IR_0$')
ax[0,1].set_ylabel(r'$V_t$ [V]')
ax[1,0].set_ylabel(r'$F$ [GN]')
ax[1,1].set_ylabel(r'$-k\Delta u$ [GN]')
plt.tight_layout()
# Out:
# /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_29960/3197020153.py:21: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   return 1 - np.exp(250*(soc - 1))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'soc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[130], line 22
#      20 f, ax = plt.subplots(2, 2, figsize=(10, 8))
#      21 #plt.plot(x_test[:,0].numpy()* R0.detach().numpy(), label='Predicted $R_0$')
# ---> 22 ax[0,0].plot(data['soc'][data['trajectory'] == traj_eval].values, R0, label=r'Predicted $IR_0$',color = colors[0])
#      23 ax[0,0].plot(data['soc'][data['trajectory'] == traj_eval].values,-data['eta'][data['trajectory'] == traj_eval].values / x_train[x_train[:,-1] == traj_eval][:,0].numpy(), label=r'True $\eta$',color = colors[1],ls = '--')
#      25 ax[0,1].plot(data['soc'][data['trajectory'] == traj_eval].values,data['V_t'][data['trajectory'] == traj_eval].values, label=r'True $V_t$', color = colors[1],ls = '--')
#
# File ~/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'soc'

# %%
def metrics(y_true, y_pred):
    mse = np.mean((y_true - y_pred) ** 2)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(y_true - y_pred))
    r2 = 1 - np.sum((y_true - y_pred) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2)
    return mse, rmse, mae, r2


def evaluate_metrics(model, x, y):
    model.eval()
    mse = np.zeros((torch.unique(x[:, -1]).numel(),2))
    rmse = np.zeros_like(mse)
    mae = np.zeros_like(mse)
    r2 = np.zeros_like(mse)
    j = 0
    for traj in x[:,-1].unique():
        x_traj = x[x[:,-1] == traj][:,:-1]
        y_traj = y[y[:,-1] == traj][:,:-1]
        with torch.no_grad():
            I = x_traj[:,0]
            u = x_traj[:,1]
            Ue = x_traj[:,2]

            R0_pred, F_pred = model(x_traj)
            y_pred = torch.stack([ECM_box(Ue,I,R0_pred), Mech_box(u,F_pred)],dim=1)

        y_true = y_traj.numpy()
        y_pred_np = y_pred.numpy()

        mse[j,0], rmse[j,0], mae[j,0], r2[j,0] = metrics(y_true[:,0], y_pred_np[:,0])
        mse[j,1], rmse[j,1], mae[j,1], r2[j,1] = metrics(y_true[:,1], y_pred_np[:,1])
        print(f"Test MSE: [{mse[j,0]:.3e},{mse[j,1]:.3e}], RMSE: [{rmse[j,0]:.3e},{rmse[j,1]:.3e}], MAE: [{mae[j,0]:.3e},{mae[j,1]:.3e}], R2: [{r2[j,0]:.3f},{r2[j,1]:.3f}]")
        j += 1
    return mse, rmse, mae, r2

mse, rmse, mae, r2 = evaluate_metrics(model, x_test, y_test)

f, ax = plt.subplots(4, 2, figsize=(7, 10),sharex=True)

ax[0,0].plot(mse[:,0], 'o-', color = colors[0])
ax[0,1].plot(mse[:,1], 'o-', color = colors[1])
ax[1,0].plot(rmse[:,0], 'o-', color = colors[2])
ax[1,1].plot(rmse[:,1], 'o-', color = colors[3])
ax[2,0].plot(mae[:,0], 'o-', color = colors[4])
ax[2,1].plot(mae[:,1], 'o-', color = colors[5])
ax[3,0].plot(r2[:,0], 'o-', color = colors[6])
ax[3,1].plot(r2[:,1], 'o-', color = colors[7])

ax[0,0].set_title('MSE for $V_t$')
ax[0,1].set_title('MSE for $F$')    
ax[1,0].set_title('RMSE for $V_t$')
ax[1,1].set_title('RMSE for $F$')
ax[2,0].set_title('MAE for $V_t$')
ax[2,1].set_title('MAE for $F$')
ax[3,0].set_title('R² for $V_t$')
ax[3,1].set_title('R² for $F$')
ax[3,0].set_xlabel('Trajectory')
ax[3,1].set_xlabel('Trajectory')
for a in ax.flat:
    a.set_ylabel('Error')
    a.grid(True, ls='--', lw=0.5)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_29960/3197020153.py:21: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   return 1 - np.exp(250*(soc - 1))
# Test MSE: [2.997e-03,1.742e-04], RMSE: [5.475e-02,1.320e-02], MAE: [3.560e-02,1.260e-02], R2: [0.961,0.996]
# Test MSE: [3.128e-03,1.720e-04], RMSE: [5.593e-02,1.311e-02], MAE: [3.581e-02,1.244e-02], R2: [0.959,0.996]
# Test MSE: [2.460e-03,2.242e-04], RMSE: [4.959e-02,1.497e-02], MAE: [3.237e-02,1.449e-02], R2: [0.966,0.994]
# Test MSE: [7.247e-03,3.670e-04], RMSE: [8.513e-02,1.916e-02], MAE: [4.569e-02,1.882e-02], R2: [0.902,0.989]
# Test MSE: [1.632e-03,1.284e-04], RMSE: [4.040e-02,1.133e-02], MAE: [2.134e-02,1.109e-02], R2: [0.979,0.997]
# Test MSE: [4.544e-03,2.556e-04], RMSE: [6.741e-02,1.599e-02], MAE: [4.501e-02,1.576e-02], R2: [0.939,0.993]
# Test MSE: [2.344e-03,1.088e-04], RMSE: [4.841e-02,1.043e-02], MAE: [2.983e-02,1.005e-02], R2: [0.968,0.997]
# Test MSE: [9.064e-03,6.240e-04], RMSE: [9.521e-02,2.498e-02], MAE: [6.498e-02,2.488e-02], R2: [0.882,0.979]
# Test MSE: [4.637e-03,2.223e-04], RMSE: [6.810e-02,1.491e-02], MAE: [3.972e-02,1.466e-02], R2: [0.936,0.994]
# Test MSE: [1.680e-03,5.945e-05], RMSE: [4.099e-02,7.710e-03], MAE: [1.811e-02,5.517e-03], R2: [0.980,0.999]
# Test MSE: [2.188e-03,2.105e-04], RMSE: [4.678e-02,1.451e-02], MAE: [2.934e-02,1.418e-02], R2: [0.971,0.995]
# Test MSE: [7.730e-03,5.734e-04], RMSE: [8.792e-02,2.395e-02], MAE: [4.840e-02,2.362e-02], R2: [0.892,0.982]
# Test MSE: [5.393e-03,5.306e-04], RMSE: [7.344e-02,2.304e-02], MAE: [4.976e-02,2.293e-02], R2: [0.924,0.984]
# Test MSE: [1.213e-02,6.025e-04], RMSE: [1.101e-01,2.455e-02], MAE: [8.956e-02,2.437e-02], R2: [0.843,0.980]
# Test MSE: [2.643e-03,1.740e-04], RMSE: [5.141e-02,1.319e-02], MAE: [2.962e-02,1.279e-02], R2: [0.965,0.996]
# Test MSE: [1.536e-03,4.168e-03], RMSE: [3.920e-02,6.456e-02], MAE: [2.091e-02,6.259e-02], R2: [0.983,0.912]
# Test MSE: [2.188e-03,1.008e-04], RMSE: [4.678e-02,1.004e-02], MAE: [2.046e-02,8.781e-03], R2: [0.974,0.998]
# Test MSE: [1.818e-03,1.400e-04], RMSE: [4.264e-02,1.183e-02], MAE: [2.567e-02,1.150e-02], R2: [0.976,0.997]
# Test MSE: [8.369e-03,6.604e-04], RMSE: [9.148e-02,2.570e-02], MAE: [7.125e-02,2.558e-02], R2: [0.883,0.979]
# Test MSE: [4.243e-03,2.278e-04], RMSE: [6.514e-02,1.509e-02], MAE: [3.901e-02,1.472e-02], R2: [0.943,0.994]
# Test MSE: [2.299e-03,1.600e-04], RMSE: [4.794e-02,1.265e-02], MAE: [3.018e-02,1.233e-02], R2: [0.970,0.996]
# Test MSE: [6.049e-03,3.766e-04], RMSE: [7.777e-02,1.941e-02], MAE: [4.457e-02,1.920e-02], R2: [0.915,0.989]
# Test MSE: [7.839e-03,6.296e-04], RMSE: [8.854e-02,2.509e-02], MAE: [6.730e-02,2.498e-02], R2: [0.890,0.980]
# Test MSE: [5.349e-03,2.966e-04], RMSE: [7.314e-02,1.722e-02], MAE: [4.305e-02,1.702e-02], R2: [0.927,0.991]
# Test MSE: [2.600e-03,2.220e-04], RMSE: [5.099e-02,1.490e-02], MAE: [3.356e-02,1.440e-02], R2: [0.964,0.994]
# Test MSE: [1.497e-03,1.036e-04], RMSE: [3.870e-02,1.018e-02], MAE: [2.211e-02,9.537e-03], R2: [0.981,0.998]
# Test MSE: [1.742e-03,1.108e-04], RMSE: [4.173e-02,1.052e-02], MAE: [1.541e-02,7.751e-03], R2: [0.980,0.998]
# Test MSE: [2.121e-03,1.565e-04], RMSE: [4.606e-02,1.251e-02], MAE: [1.890e-02,1.068e-02], R2: [0.975,0.997]
# Test MSE: [4.409e-03,3.130e-04], RMSE: [6.640e-02,1.769e-02], MAE: [4.061e-02,1.729e-02], R2: [0.941,0.991]

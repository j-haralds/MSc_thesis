# %%
import torch
import numpy as np
import torch.nn as nn
from tqdm import trange
from pathlib import Path
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import importlib
from torchinfo import summary
import time
import sys
import pandas as pd
import scipy
import seaborn as sns
import sklearn.gaussian_process as gp
from scipy import stats
import importlib
import multi_exp_log
sys.path.append('..')
import plot_settings

import GP

colors = plot_settings.colors()

def import_reload():
    plot_settings.apply()
    importlib.reload(multi_exp_log)
    importlib.reload(GP)

import_reload()
GP_FIT = GP.GP_process()

import warnings
warnings.filterwarnings("ignore", message=".*__array_wrap__.*")
# Out:
# /Users/jonatanharaldsson/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/5_Multi/GP.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(

# %% [markdown]
# # Importing data

# %%
DT = 1
Q0 = 17921.57581 
#(data['I'][data['trajectory'] == 10].values)[0]  * 3600 / (data['C'][data['trajectory'] == 10].values)[0]  
#print(f'Q0: {Q0:.5f} As')

# %%
def read_raw_data(file_name):
    df = pd.read_csv(
        f"Multi_data/{file_name}.txt",
        delim_whitespace=True,
        comment="%",
        header=None
    )
    df.columns = ['u_par','C','t','E_cell (V)','I_cell (A)','Rx_cell (N)','u_cell (m)','E_ocv_cell (V)','soc_cell (1)']
    return df

def read_data(file_name):
    df = pd.read_csv(
        f"Multi_data/{file_name}.txt",
        sep=';',
        comment="%"
    )
    # cols = u_par,C,t,V,I,F,u,Ue,eta,trajectory,dV,dF,soc
    #df.columns = ['u_par','C','t','V','I','F','u','Ue','eta','trajectory','dV','dF','soc']
    # Sort by time within each batch
    return df


path_pulse = f'test_data_pulse300_50p'

data_pulse = read_raw_data(path_pulse)

# #rename columns
data_pulse.columns = ['u_par','C','t','V','I','F','u','Ue','soc']


data = read_data('2_merged_data')
# data['u'] = data['u'] * 1e5
# data['Rx'] = data['Rx'] * 1e-9
# data['I'] = data['I'] * 1.
# data['eta'] = data['V_t'] - data['ocv']
#data_pulse.describe()
# # remove the trajectories with u_par = 8.4, C = 3.6 and u_par = 25.7, C = 4.4 
# data = data[~((data['u_par'] == 8.4) & (data['C'] == 3.6))]
# data = data[~((data['u_par'] == 25.7) & (data['C'] == 4.4))]

#data.to_csv('Multi_data/4_raw_data.txt', index=False)
# Out:
# /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_7195/2732270845.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(

# %% [markdown]
# To deal with more reasonable values, $F$ is measured in GN, while $\Delta u$ is measured in $10^{-5}$ m

# %%
def group_trajectories(df):
    """
    Group trajectories by unique combinations of 'C' and 'u_par'.

    Parameters
    ----------
    df : pd.DataFrame
        Input dataframe with columns 'C' and 'u_par'.

    Returns
    -------
    pd.DataFrame
        DataFrame with an added 'trajectory' column indicating group membership.
    """
    df['trajectory'] = df.groupby(['C', 'u_par'], sort=False).ngroup()
    return df

def merge_runs(n_runs, base_dir="Multi_data", add_run_id=False):
    """
    Merge multiple run files into one dataframe.

    Parameters
    ----------
    run_names : list[str]
        Run names without extension, e.g. ['1_run', '2_run'].
    base_dir : str
        Folder containing the .txt run files.
    add_run_id : bool
        If True, adds a 'run_id' column.

    Returns
    -------
    pd.DataFrame
        Merged and preprocessed dataframe.
    """
    run_names = []
    for n in range(1, n_runs+1):
        run_names.append(f"{n}_run")

    print(f"Merging runs: {run_names}")

    if not run_names:
        raise ValueError("run_names must contain at least one run name.")

    frames = []
    for run in run_names:
        df = pd.read_csv(
            f"{base_dir}/{run}_raw.txt",
            delim_whitespace=True,
            comment="%",
            header=None)
        df.columns = ['u_par', 'C', 't', 'V', 'I', 'F', 'u', 'Ue']

        # same preprocessing as in your notebook
        df['u'] = df['u'] * 1e5
        df['F'] = df['F'] * 1e-9
        df['I'] = df['I'] * 1.0
        df['eta'] = df['V'] - df['Ue']
        if add_run_id:
            df['run_id'] = run

        frames.append(df)

    merged = pd.concat(frames, ignore_index=True)
    # remove duplicates in C and u_par if they exist
    merged = merged.drop_duplicates(subset=['C', 'u_par', 't'])

    # optional global trajectory labeling across merged runs
    merged['trajectory'] = merged.groupby(['C', 'u_par'], sort=False).ngroup()

    return merged


# Example:
grouped_data_pulse = group_trajectories(data_pulse)
data_pulse = grouped_data_pulse.copy()

data_pulse['eta'] = data_pulse['V'] - data_pulse['Ue']
data_pulse['I'] = -data_pulse['I'] * 1.0
data_pulse['u'] = data_pulse['u'] * 1e5
data_pulse['F'] = -data_pulse['F'] * 1e-9
data_pulse.head()
# Out:
#    u_par    C  t         V         I         F        u        Ue       soc  \
# 0   12.0  2.6  0  4.267586  12.94336  0.916975  1.72479  4.324998  0.999999
# 1   12.0  2.6  1  4.191414  12.94336  0.916422  1.72479  4.322812  0.999282
# 2   12.0  2.6  2  4.172004  12.94336  0.915865  1.72479  4.320613  0.998559
# 3   12.0  2.6  3  4.162097  12.94336  0.915308  1.72479  4.318414  0.997837
# 4   12.0  2.6  4  4.154179  12.94336  0.914751  1.72479  4.316215  0.997115
#
#    trajectory       eta
# 0           0 -0.057412
# 1           0 -0.131398
# 2           0 -0.148609
# 3           0 -0.156317
# 4           0 -0.162036

# %%
print(len(data['trajectory'].unique()))
for tr in data['trajectory'].unique():
    print(f'Trajectory {tr}\t length: {(data['trajectory'] == tr).sum()}')
# Out:
# 248
# Trajectory 0	 length: 1476
# Trajectory 1	 length: 758
# Trajectory 2	 length: 5847
# Trajectory 3	 length: 3846
# Trajectory 4	 length: 758
# Trajectory 5	 length: 3117
# Trajectory 6	 length: 635
# Trajectory 7	 length: 1840
# Trajectory 8	 length: 1169
# Trajectory 9	 length: 997
# Trajectory 10	 length: 963
# Trajectory 11	 length: 784
# Trajectory 12	 length: 1172
# Trajectory 13	 length: 4347
# Trajectory 14	 length: 5847
# Trajectory 15	 length: 1732
# Trajectory 16	 length: 1038
# Trajectory 17	 length: 673
# Trajectory 18	 length: 1279
# Trajectory 19	 length: 1402
# Trajectory 20	 length: 586
# Trajectory 21	 length: 1079
# Trajectory 22	 length: 2089
# Trajectory 23	 length: 3441
# Trajectory 24	 length: 837
# Trajectory 25	 length: 4987
# Trajectory 26	 length: 713
# Trajectory 27	 length: 570
# Trajectory 28	 length: 865
# Trajectory 29	 length: 1125
# Trajectory 30	 length: 1552
# Trajectory 31	 length: 2614
# Trajectory 32	 length: 929
# Trajectory 33	 length: 1955
# Trajectory 34	 length: 810
# Trajectory 35	 length: 1279
# Trajectory 36	 length: 653
# Trajectory 37	 length: 586
# Trajectory 38	 length: 897
# Trajectory 39	 length: 1640
# Trajectory 40	 length: 2409
# Trajectory 41	 length: 603
# Trajectory 42	 length: 2241
# Trajectory 43	 length: 737
# Trajectory 44	 length: 2839
# Trajectory 45	 length: 1038
# Trajectory 46	 length: 1402
# Trajectory 47	 length: 694
# Trajectory 48	 length: 2088
# Trajectory 49	 length: 619
# Trajectory 50	 length: 3846
# Trajectory 51	 length: 835
# Trajectory 52	 length: 4991
# Trajectory 53	 length: 2839
# Trajectory 54	 length: 673
# Trajectory 55	 length: 1404
# Trajectory 56	 length: 620
# Trajectory 57	 length: 809
# Trajectory 58	 length: 5847
# Trajectory 59	 length: 3442
# Trajectory 60	 length: 1279
# Trajectory 61	 length: 714
# Trajectory 62	 length: 1476
# Trajectory 63	 length: 1552
# Trajectory 64	 length: 758
# Trajectory 65	 length: 3118
# Trajectory 66	 length: 714
# Trajectory 67	 length: 673
# Trajectory 68	 length: 586
# Trajectory 69	 length: 3846
# Trajectory 70	 length: 963
# Trajectory 71	 length: 1732
# Trajectory 72	 length: 2089
# Trajectory 73	 length: 835
# Trajectory 74	 length: 1079
# Trajectory 75	 length: 736
# Trajectory 76	 length: 997
# Trajectory 77	 length: 586
# Trajectory 78	 length: 1336
# Trajectory 79	 length: 654
# Trajectory 80	 length: 4989
# Trajectory 81	 length: 636
# Trajectory 82	 length: 926
# Trajectory 83	 length: 1956
# Trajectory 84	 length: 1222
# Trajectory 85	 length: 556
# Trajectory 86	 length: 1038
# Trajectory 87	 length: 783
# Trajectory 88	 length: 864
# Trajectory 89	 length: 1839
# Trajectory 90	 length: 1125
# Trajectory 91	 length: 2414
# Trajectory 92	 length: 1402
# Trajectory 93	 length: 2613
# Trajectory 94	 length: 2614
# Trajectory 95	 length: 997
# Trajectory 96	 length: 619
# Trajectory 97	 length: 1172
# Trajectory 98	 length: 1640
# Trajectory 99	 length: 2241
# Trajectory 100	 length: 2839
# Trajectory 101	 length: 736
# Trajectory 102	 length: 2238
# Trajectory 103	 length: 897
# Trajectory 104	 length: 1038
# Trajectory 105	 length: 693
# Trajectory 106	 length: 618
# Trajectory 107	 length: 1080
# Trajectory 108	 length: 4988
# Trajectory 109	 length: 1172
# Trajectory 110	 length: 2241
# Trajectory 111	 length: 810
# Trajectory 112	 length: 714
# Trajectory 113	 length: 1279
# Trajectory 114	 length: 601
# Trajectory 115	 length: 1125
# Trajectory 116	 length: 864
# Trajectory 117	 length: 3842
# Trajectory 118	 length: 2839
# Trajectory 119	 length: 1637
# Trajectory 120	 length: 555
# Trajectory 121	 length: 1640
# Trajectory 122	 length: 1554
# Trajectory 123	 length: 1336
# Trajectory 124	 length: 737
# Trajectory 125	 length: 2089
# Trajectory 126	 length: 1080
# Trajectory 127	 length: 1222
# Trajectory 128	 length: 587
# Trajectory 129	 length: 928
# Trajectory 130	 length: 3442
# Trajectory 131	 length: 1732
# Trajectory 132	 length: 635
# Trajectory 133	 length: 783
# Trajectory 134	 length: 586
# Trajectory 135	 length: 1476
# Trajectory 136	 length: 7049
# Trajectory 137	 length: 3118
# Trajectory 138	 length: 1955
# Trajectory 139	 length: 653
# Trajectory 140	 length: 963
# Trajectory 141	 length: 1839
# Trajectory 142	 length: 783
# Trajectory 143	 length: 653
# Trajectory 144	 length: 837
# Trajectory 145	 length: 1336
# Trajectory 146	 length: 2409
# Trajectory 147	 length: 4989
# Trajectory 148	 length: 3846
# Trajectory 149	 length: 963
# Trajectory 150	 length: 1402
# Trajectory 151	 length: 4990
# Trajectory 152	 length: 2839
# Trajectory 153	 length: 810
# Trajectory 154	 length: 1221
# Trajectory 155	 length: 1640
# Trajectory 156	 length: 1554
# Trajectory 157	 length: 1279
# Trajectory 158	 length: 2409
# Trajectory 159	 length: 1172
# Trajectory 160	 length: 1955
# Trajectory 161	 length: 672
# Trajectory 162	 length: 619
# Trajectory 163	 length: 587
# Trajectory 164	 length: 692
# Trajectory 165	 length: 3441
# Trajectory 166	 length: 636
# Trajectory 167	 length: 1279
# Trajectory 168	 length: 1476
# Trajectory 169	 length: 927
# Trajectory 170	 length: 864
# Trajectory 171	 length: 571
# Trajectory 172	 length: 997
# Trajectory 173	 length: 2241
# Trajectory 174	 length: 1402
# Trajectory 175	 length: 673
# Trajectory 176	 length: 928
# Trajectory 177	 length: 1732
# Trajectory 178	 length: 2241
# Trajectory 179	 length: 603
# Trajectory 180	 length: 783
# Trajectory 181	 length: 1955
# Trajectory 182	 length: 760
# Trajectory 183	 length: 1122
# Trajectory 184	 length: 5847
# Trajectory 185	 length: 1079
# Trajectory 186	 length: 3846
# Trajectory 187	 length: 1079
# Trajectory 188	 length: 2613
# Trajectory 189	 length: 997
# Trajectory 190	 length: 864
# Trajectory 191	 length: 1839
# Trajectory 192	 length: 5847
# Trajectory 193	 length: 3117
# Trajectory 194	 length: 551
# Trajectory 195	 length: 760
# Trajectory 196	 length: 3846
# Trajectory 197	 length: 736
# Trajectory 198	 length: 2839
# Trajectory 199	 length: 5847
# Trajectory 200	 length: 960
# Trajectory 201	 length: 1336
# Trajectory 202	 length: 926
# Trajectory 203	 length: 1640
# Trajectory 204	 length: 5847
# Trajectory 205	 length: 867
# Trajectory 206	 length: 896
# Trajectory 207	 length: 1339
# Trajectory 208	 length: 1080
# Trajectory 209	 length: 585
# Trajectory 210	 length: 672
# Trajectory 211	 length: 1956
# Trajectory 212	 length: 3442
# Trajectory 213	 length: 1222
# Trajectory 214	 length: 602
# Trajectory 215	 length: 2089
# Trajectory 216	 length: 570
# Trajectory 217	 length: 2088
# Trajectory 218	 length: 619
# Trajectory 219	 length: 1172
# Trajectory 220	 length: 782
# Trajectory 221	 length: 2614
# Trajectory 222	 length: 692
# Trajectory 223	 length: 571
# Trajectory 224	 length: 2614
# Trajectory 225	 length: 1732
# Trajectory 226	 length: 653
# Trajectory 227	 length: 1839
# Trajectory 228	 length: 714
# Trajectory 229	 length: 714
# Trajectory 230	 length: 998
# Trajectory 231	 length: 1554
# Trajectory 232	 length: 758
# Trajectory 233	 length: 636
# Trajectory 234	 length: 1404
# Trajectory 235	 length: 1224
# Trajectory 236	 length: 4344
# Trajectory 237	 length: 837
# Trajectory 238	 length: 3118
# Trajectory 239	 length: 4988
# Trajectory 240	 length: 3846
# Trajectory 241	 length: 759
# Trajectory 242	 length: 962
# Trajectory 243	 length: 1125
# Trajectory 244	 length: 810
# Trajectory 245	 length: 1039
# Trajectory 246	 length: 1476
# Trajectory 247	 length: 2409

# %%
u_C_pairs = data.loc[data['t'] == 0, ['u_par', 'C']]
plt.plot(u_C_pairs['C'], u_C_pairs['u_par'], 'o')

# %%
def find_duplicate_u_C_pairs(df):
    """
    Find duplicate (u_par, C) pairs in the dataframe.

    Parameters
    ----------
    df : pd.DataFrame
        Dataframe containing 'u_par' and 'C' columns.

    Returns
    -------
    pd.DataFrame
        Dataframe of duplicate (u_par, C) pairs and their counts.
    """
    duplicates = df.groupby(['u_par', 'C']).size().reset_index(name='count')
    duplicates = duplicates[duplicates['count'] > 1]
    return duplicates

duplicates = find_duplicate_u_C_pairs(u_C_pairs)
print("Duplicate (u_par, C) pairs:")
print(duplicates)

# # remove the duplicates
# for _, row in duplicates.iterrows():
#     u_par = row['u_par']
#     C = row['C']
#     # Find all trajectories with this (u_par, C) pair
#     trajectories_to_remove = data[(data['u_par'] == u_par) & (data['C'] == C)]['trajectory'].unique()
#     # Remove these trajectories from the dataframe
#     data = data[~data['trajectory'].isin(trajectories_to_remove)]

# print("After removing duplicates:")
# duplicates_after = find_duplicate_u_C_pairs(data.loc[data['t'] == 0, ['u_par', 'C']])
# print(duplicates_after)
# Out:
# Duplicate (u_par, C) pairs:
# Empty DataFrame
# Columns: [u_par, C, count]
# Index: []

# %%
# Add finite-difference columns with the same length as `data`
dV = np.diff(data['V'].to_numpy())[:-1] / DT
dRx = np.diff(data['F'].to_numpy())[:-1] / DT

if len(dV) > 0:
    for i in range(2):
        dV = np.append(dV, dV[-1])
        dRx = np.append(dRx, dRx[-1])
else:
    dV = np.array([0.0])
    dRx = np.array([0.0])

data['dV'] = dV
data['dF'] = dRx

data.head()
# Out:
#    u_par    C    t         V          I         F         u        Ue  \
# 0    0.4  2.2  0.0  4.239833  10.952074  0.030566 -0.057493  4.324996
# 1    0.4  2.2  1.0  4.211952  10.952074  0.030096 -0.057493  4.323139
# 2    0.4  2.2  2.0  4.195213  10.952074  0.029624 -0.057493  4.321278
# 3    0.4  2.2  3.0  4.183479  10.952074  0.029153 -0.057493  4.319417
# 4    0.4  2.2  4.0  4.176773  10.952074  0.028682 -0.057493  4.317557
#
#         eta  trajectory        dV        dF       soc
# 0 -0.085164           0 -0.027881 -0.000470  0.999389
# 1 -0.111187           0 -0.016738 -0.000471  0.998778
# 2 -0.126065           0 -0.011734 -0.000471  0.998167
# 3 -0.135938           0 -0.006706 -0.000471  0.997556
# 4 -0.140783           0 -0.005763 -0.000471  0.996944

# %%
def get_traj_data(trajectory, col,df = data):
    """
    Extract data for a specific trajectory.

    Parameters
    ----------
    df : pd.DataFrame
        Input dataframe containing a 'trajectory' column.
    trajectory : int
        The trajectory number to extract.

    Returns
    -------
    pd.DataFrame
        Dataframe containing only the data for the specified trajectory.
    """
    return df[col][df['trajectory'] == trajectory].reset_index(drop=True)

# %%
plt.plot(-np.concat(([0.5 * np.min(np.diff(get_traj_data(2, 'soc',df=data_pulse))) * Q0],np.diff(get_traj_data(2, 'soc',df=data_pulse)) * Q0)))

# %%
tr_max = 40
f,ax = plt.subplots(1, 2, figsize=(12, 5),sharey=True)
#plt.plot(get_traj_data(data, tr_max, 'soc'))
ax[0].plot(get_traj_data(tr_max,'t',df = data_pulse),GP.soc_to_Ue(get_traj_data(tr_max, 'soc',df = data_pulse),GP_FIT))
ax[0].plot(get_traj_data(tr_max,'t',df = data_pulse),get_traj_data(tr_max, 'V',df = data_pulse))
ax[1].plot(get_traj_data(tr_max,'soc',df = data_pulse),GP.soc_to_Ue(get_traj_data(tr_max, 'soc',df = data_pulse),GP_FIT))
ax[1].plot(get_traj_data(tr_max,'soc',df = data_pulse),get_traj_data(tr_max, 'V',df = data_pulse))
ax[1].invert_xaxis()
ax[0].set_ylim(3.0, 4.5)

print(get_traj_data(tr_max,'I',df = data_pulse).max())
tr_max = 15
ax[0].plot(get_traj_data(tr_max,'t'),GP.soc_to_Ue(get_traj_data(tr_max, 'soc'),GP_FIT))
ax[0].plot(get_traj_data(tr_max,'t'),get_traj_data(tr_max, 'V'))
ax[1].plot(get_traj_data(tr_max,'soc'),GP.soc_to_Ue(get_traj_data(tr_max, 'soc'),GP_FIT))
ax[1].plot(get_traj_data(tr_max,'soc'),get_traj_data(tr_max, 'V'))

print(get_traj_data(tr_max,'I').max())
plt.tight_layout()
# Out:
# 10.45425255462913
# 9.45860945418826

# %%
start = time.perf_counter()
ocv_sample = GP.soc_to_Ue(data['soc'][data['trajectory'] == tr_max].values,GP_FIT)
end = time.perf_counter()
print(f"GP sampling took {end - start:.4f} seconds for {len(data['soc'][data['trajectory'] == tr_max].values)} points => {len(data['soc'][data['trajectory'] == tr_max].values)**(-1) *1000* (end - start):.3f} ms/point")
plt.plot((data['soc'][data['trajectory'] == tr_max].values), ocv_sample, color = colors[0], label = 'GP regression')
plt.plot(data['soc'][data['trajectory'] == tr_max].values, data['Ue'][data['trajectory'] == tr_max].values, lw = 2, color = 'black', label = 'Data',ls = '--', alpha = 0.5)
plt.xlabel('State of Charge')
plt.gca().invert_xaxis()
plt.ylabel('OCV [V]')
plt.legend()
print(f'MSE: {np.mean((ocv_sample - data["Ue"][data["trajectory"] == tr_max].values)**2):.6e}')
# Out:
# GP sampling took 0.0983 seconds for 3122 points => 0.031 ms/point
# MSE: 9.185406e-07

# %% [markdown]
# # Plotting data

# %%
plot_idx = data['trajectory'] == 3
f, ax = plt.subplots(2, 3, figsize=(10, 5))
ax[0,0].plot(data['V'][plot_idx], '-', color = colors[0], lw = 2)
ax[0,0].set_xlabel('Time step')
ax[0,0].set_ylabel('$V_{cell}$')
ax[0,1].plot(data['Ue'][plot_idx], '-', color = colors[1], lw = 2)
ax[0,1].set_xlabel('Time step')
ax[0,1].set_ylabel('Ue')
ax[0,2].plot(data['eta'][plot_idx], '-', color = colors[2], lw = 2)
ax[0,2].set_xlabel('Time step')
ax[0,2].set_ylabel(r'$\eta$')
ax[1,0].plot(data['F'][plot_idx], lw = 2,color = colors[3])
ax[1,0].set_xlabel('Time step')
ax[1,0].set_ylabel(r'$F$')
ax[1,1].plot(data['I'][plot_idx], lw = 2,color = colors[4])
ax[1,1].set_xlabel('Time step')
ax[1,1].set_ylabel(r'$I$')
ax[1,2].plot(data['u'][plot_idx], lw = 2,color = colors[5])
ax[1,2].set_xlabel('Time step')
ax[1,2].set_ylabel(r'$\Delta u$')

plt.tight_layout()
plt.show()

# %%
plot_idx = data_pulse['trajectory'] == 3
f, ax = plt.subplots(2, 3, figsize=(10, 5))
ax[0,0].plot(data_pulse['V'][plot_idx], '-', color = colors[0], lw = 2)
ax[0,0].set_xlabel('Time step')
ax[0,0].set_ylabel('$V_{cell}$')
ax[0,1].plot(data_pulse['Ue'][plot_idx], '-', color = colors[1], lw = 2)
ax[0,1].set_xlabel('Time step')
ax[0,1].set_ylabel('Ue')
ax[0,2].plot(data_pulse['eta'][plot_idx], '-', color = colors[2], lw = 2)
ax[0,2].set_xlabel('Time step')
ax[0,2].set_ylabel(r'$\eta$')
ax[1,0].plot(data_pulse['F'][plot_idx], lw = 2,color = colors[3])
ax[1,0].set_xlabel('Time step')
ax[1,0].set_ylabel(r'$F$')
ax[1,1].plot(data_pulse['I'][plot_idx], lw = 2,color = colors[4])
ax[1,1].set_xlabel('Time step')
ax[1,1].set_ylabel(r'$I$')
ax[1,2].plot(data_pulse['u'][plot_idx], lw = 2,color = colors[5])
ax[1,2].set_xlabel('Time step')
ax[1,2].set_ylabel(r'$\Delta u$')

plt.tight_layout()
plt.show()

# %%
# Correlation matrix for current signals in this batch

X = data[['V_t','I','Rx','u_par','ocv','dRx','dV_t','eta']].values
feature_names = ['$V_t$','$I$','$R_x$',r'$\Delta u$','$E_{ocv}$',r'$\Delta R_x$',r'$\Delta V_t$',r'$\eta$']
with np.errstate(invalid="ignore", divide="ignore"):
    corr = np.corrcoef(X, rowvar=False)


fig, ax_corr = plt.subplots(figsize=(7, 5))
im = ax_corr.imshow(corr, cmap="coolwarm", vmin=-1, vmax=1)

ax_corr.set_xticks(np.arange(len(feature_names)))
ax_corr.set_yticks(np.arange(len(feature_names)))
ax_corr.set_xticklabels(feature_names, rotation=45, ha="right")
ax_corr.set_yticklabels(feature_names)
ax_corr.set_title("Correlation matrix")

for i in range(corr.shape[0]):
    for j in range(corr.shape[1]):
        ax_corr.text(j, i, f"{corr[i, j]:.2f}", ha="center", va="center", color="black")

fig.colorbar(im, ax=ax_corr, label="Correlation")
plt.tight_layout()
plt.show()

# %%
traj = 0
#plt.plot(data['u'][data['trajectory'] == traj], data['Rx'][data['trajectory'] == traj], lw = 2, color = colors[0])
groups = data.groupby('u')['Rx']


first_rx = data.groupby('u')['Rx'].first()
k = abs(first_rx / (data.groupby('u')['u'].first()))
plt.plot(10 * data.groupby('u')['u'].first(), first_rx, 'o-', color = colors[0], label = r'$F(\Delta u)$')
plt.plot(10 * data.groupby('u')['u'].first(), -k * data.groupby('u')['u'].first(), '--', color = colors[1], label = r'$-k\Delta u$')
plt.xlabel(r'$\Delta u$ [µm]')
plt.ylabel(r'$F$ [GN]')
plt.legend()
print(f'{ k.values[0]:.3f} GN/µm')
# Out:
# 0.532 GN/µm

# %%
traj = 1

ds = data['Rx'][data['trajectory'] == traj] / k.values[0] + data['u'][data['trajectory'] == traj] 

plt.plot(10 * ds,data['Rx'][data['trajectory'] == traj], lw = 2, color = colors[1])
plt.xlabel(r'Swelling $\Delta s$ [µm]')
plt.ylabel(r'$F$ [MN]')
# Out:
# Text(0, 0.5, '$F$ [MN]')

# %% [markdown]
# # Normalizing data
#
# ### Characteristics that should be preserved after normalization?
#
#
# - $\Delta u$: It should primarily be compression, so have a negative sign.
#     - $\Delta u / L$ gives a fractional compression
# - $I$: The sign of it should reflect if we have charge/discharge
#     - Maybe just a `standard` normalization on this?
# - $V$: It should always be positive
#     - Maybe just a `min-max` normalization on this?
# - $F$: The sign of it should in some way reflect the sign of $\Delta u$. Especially in the cases with low swelling.
#     - Maybe just a `standard` normalization on this?

# %%
f, ax = plt.subplots(3,2,figsize=(6, 7))
ax[0,0].hist(np.unique(data['I']), bins=50, color=colors[0], alpha=0.5,edgecolor='black',density=True)
ax[0,1].hist(np.unique(data['u']) , bins=500, color=colors[1], alpha=0.5,edgecolor='black',density=True)
ax[1,0].hist(data['V_t'], bins=50, color=colors[2], alpha=0.5,edgecolor='black',density=True)
ax[1,1].hist(np.unique(data['Rx']), bins=50, color=colors[3], alpha=0.5,edgecolor='black',density=True)
ax[2,1].hist(data['ocv'], bins=50, color=colors[4], alpha=0.5,edgecolor='black',density=True)
ax[2,0].hist((data['eta']), bins=50, color=colors[5], alpha=0.5,edgecolor='black',density=True)
ax[0,0].set_xlabel('$I$')
ax[0,1].set_xlabel(r'$\Delta u$')
ax[1,0].set_xlabel('$V_t$')
ax[1,1].set_xlabel('$F$')
ax[2,1].set_xlabel('$E_{ocv}$')
ax[2,0].set_xlabel(r'$\eta$')
#ax[2,0].set_xlabel('$E_{ocv}$')
#ax[2,1].set_xlabel('$d$')
for a in ax.flat:
    a.set_yticklabels([])
plt.tight_layout()
plt.show()

# %%
N_trajs = len(data['trajectory'].unique())


# test_inds = data['trajectory'] >= int(N_trajs * 0.8)

# print(test_inds.sum(), 'test samples')

# X = np.zeros((len(data) +1, 3))
# y = np.zeros((len(data) + 1,2))
# print(len(data[['V_t']].values))
# traj_len0 = 0

# for traj_ids in range(0, N_trajs):
#     traj_len1 = traj_len0 + len(data[data['trajectory'] == traj_ids]) - 1
#     X[traj_len0:traj_len1,...] = data[['I','u', 'ocv']][data['trajectory'] == traj_ids].values[:]
#     y[traj_len0:traj_len1,...] = data[['V_t','Rx']][data['trajectory'] == traj_ids].values[:]

#     traj_len0 = traj_len1



X = data[['I','u','soc','trajectory']].values
y = data[['V_t','Rx','trajectory']].values

# %%
x_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32)

split = (data['trajectory']<=int(N_trajs *0.8)).sum()

def _split_flat(arr, split = split):
    return arr[:split], arr[split:]   # Same as reshape(B * T, C)    # (B*T, 4)

x_train, x_test = _split_flat(x_tensor); y_train, y_test = _split_flat(y_tensor)

print(f'Number of trajectories in train: {int(N_trajs * 0.8)} out of {N_trajs}')

print(f'X shape {x_tensor.shape}\ty shape {y_tensor.shape}\nX-train shape: {x_train.shape}\ty-train shape: {y_train.shape}\nX-test shape: {x_test.shape}\ty-test shape: {y_test.shape}')

display(x_train[:5], y_train[:5])

#df_train = data[data['trajectory'] <= int(N_trajs * 0.8)]
#df_test = data[data['trajectory'] > int(N_trajs * 0.8)]

#train_loader_flat = DataLoader(TensorDataset(x_train, y_train), shuffle=False)
# Out:
# Number of trajectories in train: 120 out of 150
# X shape torch.Size([250258, 5])	y shape torch.Size([250258, 3])
# X-train shape: torch.Size([199038, 5])	y-train shape: torch.Size([199038, 3])
# X-test shape: torch.Size([51220, 5])	y-test shape: torch.Size([51220, 3])
# tensor([[10.9521, -0.0575,  4.3250,  0.9994,  0.0000],
#         [10.9521, -0.0575,  4.3231,  0.9988,  0.0000],
#         [10.9521, -0.0575,  4.3213,  0.9982,  0.0000],
#         [10.9521, -0.0575,  4.3194,  0.9976,  0.0000],
#         [10.9521, -0.0575,  4.3176,  0.9969,  0.0000]])
# tensor([[4.2398, 0.0306, 0.0000],
#         [4.2120, 0.0301, 0.0000],
#         [4.1952, 0.0296, 0.0000],
#         [4.1835, 0.0292, 0.0000],
#         [4.1768, 0.0287, 0.0000]])

# %%
''' Mk 1 '''


# def ECM_box(Ue, I, R0):
#     Ue = denormalize(Ue, 'ocv')
#     I = denormalize(I, 'I')
#     return normalize(Ue - I * R0, 'V_t')

# def Mech_box(u,s , k = k.values[0]):
#     u = denormalize(u, 'u')
#     s = denormalize(s, 'u')
#     return normalize(-k * u + k * s, 'Rx')

def ECM_box(soc, I, R0):
    Ue = soc_to_ocv(soc)
    return Ue - I * R0

def Mech_box(u,Fs , k = k.values[0]):
    return -k * u + Fs

def force_func(soc):
    return 1 - np.exp(250*(soc - 1))

# %%
import torch.nn.functional as TF

class Net(nn.Module):
    def __init__(self, input_size=4, hidden_size=256): 
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 2)   # output size is 2 for (V_cell, F)
        )

    def forward(self, x):
        R0_raw, Fs_raw = self.net(x)[:,0], self.net(x)[:,1]
        R0 = R0_raw #TF.softplus(R0_raw)  # Ensure R0 is non-negative
        soc = x[:,2]
        Fs = force_func(soc) * Fs_raw
        return R0, Fs


model = Net()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
try: 
    print(summary(model, input_data=x_train[:2]))
except Exception as e:
    print(f"Error in model summary: {e}")
# Out:
# Error in model summary: Failed to run torchinfo. See above stack traces for more details. Executed layers up to: []

# %%
# def next_step(x, Ue, I, k, u):
#     R0_dot, F_dot = model(x)
#     R0 = R0_dot * dt + x[:,0]
#     F  = F_dot  * dt + x[:,1] 

#     Vt = ECM_box(Ue,I,R0)
#     FR = Mech_box(u,k,F)

#     return torch.stack([R0, F], dim=1), Vt, FR



def training(epochs=30):
    history = {"loss": [], "V_loss": [], "F_loss": [], "time per ep": []}

    model.train()
    tot_time = 0.
    for ep in range(epochs):
        start_t = time.perf_counter()    
        ep_loss = 0.0

        for traj in range(int(N_trajs * 0.8)):

            x_traj = x_train[x_train[:, -1] == traj]
            y_traj = y_train[y_train[:, -1] == traj]

            # Inputs
            model_input = x_traj[:, :-1]      # (T, 3)
            model_target = y_traj[:,:-1]     # (T, 2)

            I   = model_input[:, 0]
            u   = model_input[:, 1]
            soc  = model_input[:, 2]

            # Forward
            R0, Fs = model(model_input)     # (T,), (T,)

            y_pred = torch.stack([
                ECM_box(soc, I, R0),
                Mech_box(u, Fs)
            ], dim=1)                       # (T, 2)

            V_loss = nn.MSELoss()(y_pred[:,0], model_target[:,0])
            F_loss = nn.MSELoss()(y_pred[:,1], model_target[:,1])
            loss = V_loss + F_loss

            # Backprop
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        ep_loss += loss.item()

        ep_loss /= N_trajs

        history["loss"].append(ep_loss)
        history["V_loss"].append(V_loss.item() / N_trajs)
        history["F_loss"].append(F_loss.item() / N_trajs)
        end_t = time.perf_counter()
        history["time per ep"].append(end_t - start_t)   
        
        tot_time += end_t - start_t
       
        if ep == 0:
            print(f'ETA: {(end_t - start_t) * epochs / 60:.2f} min')

        if tot_time > 5*60:
            print("Early stopping: Total training time exceeded 3 minutes.")
            break
        print(f"Epoch {ep+1} | loss {ep_loss:.2e} | V_loss {V_loss.item():.2e} | F_loss {F_loss.item():.2e} | time {end_t - start_t:.2f}s")

    return history

# %%
history = training(epochs=500)
# Out:
# /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_29960/3197020153.py:21: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   return 1 - np.exp(250*(soc - 1))
# ETA: 7.45 min
# Epoch 1 | loss 1.77e-01 | V_loss 2.66e+01 | F_loss 5.23e-02 | time 0.89s
# Epoch 2 | loss 5.87e-03 | V_loss 8.37e-01 | F_loss 4.33e-02 | time 0.94s
# Epoch 3 | loss 3.28e-04 | V_loss 8.54e-03 | F_loss 4.07e-02 | time 0.97s
# Epoch 4 | loss 3.19e-04 | V_loss 1.12e-02 | F_loss 3.66e-02 | time 0.81s
# Epoch 5 | loss 4.52e-04 | V_loss 3.62e-02 | F_loss 3.15e-02 | time 0.90s
# Epoch 6 | loss 3.46e-04 | V_loss 2.54e-02 | F_loss 2.66e-02 | time 0.83s
# Epoch 7 | loss 3.47e-04 | V_loss 3.16e-02 | F_loss 2.05e-02 | time 0.84s
# Epoch 8 | loss 1.28e-04 | V_loss 5.80e-03 | F_loss 1.34e-02 | time 0.85s
# Epoch 9 | loss 1.93e-03 | V_loss 2.84e-01 | F_loss 5.27e-03 | time 0.76s
# Epoch 10 | loss 8.00e-03 | V_loss 1.19e+00 | F_loss 4.97e-03 | time 0.77s
# Epoch 11 | loss 3.99e-02 | V_loss 5.97e+00 | F_loss 8.59e-03 | time 0.82s
# Epoch 12 | loss 9.91e-04 | V_loss 1.45e-01 | F_loss 3.49e-03 | time 0.99s
# Epoch 13 | loss 2.73e-02 | V_loss 4.09e+00 | F_loss 1.70e-03 | time 0.98s
# Epoch 14 | loss 8.44e-04 | V_loss 1.05e-01 | F_loss 2.21e-02 | time 0.84s
# Epoch 15 | loss 9.31e-05 | V_loss 9.42e-03 | F_loss 4.54e-03 | time 0.79s
# Epoch 16 | loss 4.29e-05 | V_loss 5.43e-03 | F_loss 9.97e-04 | time 0.82s
# Epoch 17 | loss 3.82e-05 | V_loss 5.05e-03 | F_loss 6.77e-04 | time 0.73s
# Epoch 18 | loss 3.54e-05 | V_loss 5.03e-03 | F_loss 2.87e-04 | time 0.73s
# Epoch 19 | loss 3.47e-05 | V_loss 5.07e-03 | F_loss 1.42e-04 | time 0.73s
# Epoch 20 | loss 3.53e-05 | V_loss 5.14e-03 | F_loss 1.49e-04 | time 0.76s
# Epoch 21 | loss 5.07e-05 | V_loss 7.24e-03 | F_loss 3.71e-04 | time 0.76s
# Epoch 22 | loss 3.71e-05 | V_loss 5.39e-03 | F_loss 1.76e-04 | time 0.72s
# Epoch 23 | loss 3.59e-05 | V_loss 5.19e-03 | F_loss 1.91e-04 | time 0.75s
# Epoch 24 | loss 3.59e-05 | V_loss 5.13e-03 | F_loss 2.54e-04 | time 0.76s
# Epoch 25 | loss 3.67e-05 | V_loss 5.13e-03 | F_loss 3.67e-04 | time 0.73s
# Epoch 26 | loss 3.62e-05 | V_loss 5.03e-03 | F_loss 4.03e-04 | time 0.76s
# Epoch 27 | loss 3.58e-05 | V_loss 4.99e-03 | F_loss 3.83e-04 | time 0.75s
# Epoch 28 | loss 3.54e-05 | V_loss 4.92e-03 | F_loss 4.01e-04 | time 0.72s
# Epoch 29 | loss 3.57e-05 | V_loss 4.90e-03 | F_loss 4.63e-04 | time 0.75s
# Epoch 30 | loss 3.85e-05 | V_loss 5.12e-03 | F_loss 6.52e-04 | time 0.72s
# Epoch 31 | loss 5.92e-05 | V_loss 8.24e-03 | F_loss 6.33e-04 | time 0.76s
# Epoch 32 | loss 3.20e-04 | V_loss 4.69e-02 | F_loss 1.14e-03 | time 0.72s
# Epoch 33 | loss 4.62e-04 | V_loss 6.87e-02 | F_loss 6.85e-04 | time 0.75s
# Epoch 34 | loss 2.38e-04 | V_loss 3.54e-02 | F_loss 2.30e-04 | time 0.75s
# Epoch 35 | loss 3.74e-04 | V_loss 5.44e-02 | F_loss 1.74e-03 | time 0.76s
# Epoch 36 | loss 4.52e-04 | V_loss 6.62e-02 | F_loss 1.53e-03 | time 0.74s
# Epoch 37 | loss 6.60e-04 | V_loss 9.87e-02 | F_loss 3.32e-04 | time 0.75s
# Epoch 38 | loss 1.28e-03 | V_loss 1.90e-01 | F_loss 1.17e-03 | time 0.74s
# Epoch 39 | loss 2.14e-04 | V_loss 2.95e-02 | F_loss 2.68e-03 | time 0.75s
# Epoch 40 | loss 3.68e-05 | V_loss 5.13e-03 | F_loss 3.85e-04 | time 0.75s
# Epoch 41 | loss 4.27e-05 | V_loss 5.78e-03 | F_loss 6.23e-04 | time 0.75s
# Epoch 42 | loss 4.36e-05 | V_loss 5.75e-03 | F_loss 7.97e-04 | time 0.74s
# Epoch 43 | loss 4.04e-05 | V_loss 5.90e-03 | F_loss 1.71e-04 | time 0.75s
# Epoch 44 | loss 7.19e-05 | V_loss 1.07e-02 | F_loss 1.09e-04 | time 0.76s
# Epoch 45 | loss 5.15e-04 | V_loss 7.61e-02 | F_loss 1.16e-03 | time 0.75s
# Epoch 46 | loss 1.01e-04 | V_loss 5.22e-03 | F_loss 9.87e-03 | time 0.73s
# Epoch 47 | loss 4.14e-05 | V_loss 5.02e-03 | F_loss 1.19e-03 | time 0.75s
# Epoch 48 | loss 3.44e-05 | V_loss 4.94e-03 | F_loss 2.26e-04 | time 0.75s
# Epoch 49 | loss 3.29e-05 | V_loss 4.75e-03 | F_loss 1.91e-04 | time 0.71s
# Epoch 50 | loss 3.22e-05 | V_loss 4.60e-03 | F_loss 2.22e-04 | time 0.69s
# Epoch 51 | loss 3.08e-05 | V_loss 4.33e-03 | F_loss 2.85e-04 | time 0.80s
# Epoch 52 | loss 2.97e-05 | V_loss 4.28e-03 | F_loss 1.78e-04 | time 0.78s
# Epoch 53 | loss 2.85e-05 | V_loss 4.17e-03 | F_loss 9.84e-05 | time 0.74s
# Epoch 54 | loss 2.66e-05 | V_loss 3.89e-03 | F_loss 9.76e-05 | time 0.77s
# Epoch 55 | loss 2.77e-05 | V_loss 4.05e-03 | F_loss 1.05e-04 | time 0.75s
# Epoch 56 | loss 2.64e-05 | V_loss 3.87e-03 | F_loss 8.72e-05 | time 0.74s
# Epoch 57 | loss 3.01e-05 | V_loss 4.33e-03 | F_loss 1.87e-04 | time 0.74s
# Epoch 58 | loss 4.22e-05 | V_loss 5.87e-03 | F_loss 4.67e-04 | time 0.74s
# Epoch 59 | loss 3.57e-05 | V_loss 4.91e-03 | F_loss 4.50e-04 | time 0.76s
# Epoch 60 | loss 6.83e-05 | V_loss 9.78e-03 | F_loss 4.60e-04 | time 0.77s
# Epoch 61 | loss 3.41e-05 | V_loss 3.33e-03 | F_loss 1.79e-03 | time 0.72s
# Epoch 62 | loss 2.46e-05 | V_loss 3.29e-03 | F_loss 4.05e-04 | time 0.71s
# Epoch 63 | loss 1.71e-05 | V_loss 2.51e-03 | F_loss 6.47e-05 | time 0.75s
# Epoch 64 | loss 3.31e-05 | V_loss 3.39e-03 | F_loss 1.58e-03 | time 0.75s
# Epoch 65 | loss 8.57e-05 | V_loss 1.23e-02 | F_loss 5.05e-04 | time 0.77s
# Epoch 66 | loss 5.95e-05 | V_loss 8.28e-03 | F_loss 6.44e-04 | time 0.75s
# Epoch 67 | loss 3.19e-05 | V_loss 3.00e-03 | F_loss 1.79e-03 | time 0.74s
# Epoch 68 | loss 2.04e-05 | V_loss 2.74e-03 | F_loss 3.18e-04 | time 1.02s
# Epoch 69 | loss 4.00e-05 | V_loss 5.45e-03 | F_loss 5.45e-04 | time 0.79s
# Epoch 70 | loss 1.81e-05 | V_loss 2.62e-03 | F_loss 1.01e-04 | time 0.73s
# Epoch 71 | loss 1.66e-05 | V_loss 2.32e-03 | F_loss 1.72e-04 | time 0.74s
# Epoch 72 | loss 3.07e-05 | V_loss 4.22e-03 | F_loss 3.80e-04 | time 0.77s
# Epoch 73 | loss 1.48e-05 | V_loss 2.09e-03 | F_loss 1.28e-04 | time 0.75s
# Epoch 74 | loss 3.08e-05 | V_loss 4.07e-03 | F_loss 5.53e-04 | time 0.74s
# Epoch 75 | loss 1.19e-05 | V_loss 1.62e-03 | F_loss 1.65e-04 | time 0.73s
# Epoch 76 | loss 8.43e-05 | V_loss 2.70e-03 | F_loss 9.95e-03 | time 0.76s
# Epoch 77 | loss 2.72e-05 | V_loss 2.23e-03 | F_loss 1.85e-03 | time 0.76s
# Epoch 78 | loss 2.05e-05 | V_loss 2.83e-03 | F_loss 2.43e-04 | time 0.71s
# Epoch 79 | loss 6.56e-05 | V_loss 6.69e-03 | F_loss 3.15e-03 | time 0.76s
# Epoch 80 | loss 3.65e-05 | V_loss 5.33e-03 | F_loss 1.49e-04 | time 0.75s
# Epoch 81 | loss 1.05e-05 | V_loss 1.43e-03 | F_loss 1.43e-04 | time 0.74s
# Epoch 82 | loss 9.49e-06 | V_loss 1.37e-03 | F_loss 5.48e-05 | time 0.71s
# Epoch 83 | loss 2.08e-05 | V_loss 2.16e-03 | F_loss 9.64e-04 | time 0.76s
# Epoch 84 | loss 8.30e-06 | V_loss 1.22e-03 | F_loss 2.13e-05 | time 0.76s
# Epoch 85 | loss 1.73e-05 | V_loss 1.28e-03 | F_loss 1.32e-03 | time 0.77s
# Epoch 86 | loss 7.46e-06 | V_loss 1.06e-03 | F_loss 6.02e-05 | time 0.74s
# Epoch 87 | loss 1.13e-05 | V_loss 9.76e-04 | F_loss 7.12e-04 | time 0.75s
# Epoch 88 | loss 3.15e-05 | V_loss 4.36e-03 | F_loss 3.67e-04 | time 0.72s
# Epoch 89 | loss 1.55e-05 | V_loss 2.01e-03 | F_loss 3.19e-04 | time 0.76s
# Epoch 90 | loss 1.34e-05 | V_loss 1.76e-03 | F_loss 2.44e-04 | time 0.70s
# Epoch 91 | loss 1.87e-05 | V_loss 2.55e-03 | F_loss 2.60e-04 | time 0.74s
# Epoch 92 | loss 2.06e-05 | V_loss 2.50e-03 | F_loss 5.96e-04 | time 0.75s
# Epoch 93 | loss 8.38e-05 | V_loss 6.00e-03 | F_loss 6.56e-03 | time 0.72s
# Epoch 94 | loss 2.98e-05 | V_loss 2.91e-03 | F_loss 1.57e-03 | time 0.75s
# Epoch 95 | loss 1.77e-05 | V_loss 1.96e-03 | F_loss 6.94e-04 | time 0.74s
# Epoch 96 | loss 1.28e-05 | V_loss 1.15e-03 | F_loss 7.73e-04 | time 0.75s
# Epoch 97 | loss 1.02e-05 | V_loss 1.27e-03 | F_loss 2.56e-04 | time 0.78s
# Epoch 98 | loss 2.26e-05 | V_loss 2.18e-03 | F_loss 1.21e-03 | time 0.77s
# Epoch 99 | loss 7.45e-06 | V_loss 1.03e-03 | F_loss 8.27e-05 | time 0.76s
# Epoch 100 | loss 2.27e-05 | V_loss 2.49e-03 | F_loss 9.10e-04 | time 0.76s
# Epoch 101 | loss 1.04e-05 | V_loss 1.46e-03 | F_loss 9.19e-05 | time 0.73s
# Epoch 102 | loss 9.36e-06 | V_loss 1.20e-03 | F_loss 2.08e-04 | time 0.75s
# Epoch 103 | loss 3.72e-05 | V_loss 4.87e-03 | F_loss 7.16e-04 | time 0.80s
# Epoch 104 | loss 2.73e-05 | V_loss 3.54e-03 | F_loss 5.64e-04 | time 1.04s
# Epoch 105 | loss 4.10e-05 | V_loss 5.20e-03 | F_loss 9.51e-04 | time 0.76s
# Epoch 106 | loss 1.73e-05 | V_loss 2.45e-03 | F_loss 1.51e-04 | time 0.81s
# Epoch 107 | loss 1.78e-05 | V_loss 2.59e-03 | F_loss 7.72e-05 | time 0.76s
# Epoch 108 | loss 1.28e-05 | V_loss 1.90e-03 | F_loss 2.31e-05 | time 0.76s
# Epoch 109 | loss 1.96e-05 | V_loss 2.80e-03 | F_loss 1.37e-04 | time 0.76s
# Epoch 110 | loss 1.43e-05 | V_loss 2.13e-03 | F_loss 1.88e-05 | time 0.78s
# Epoch 111 | loss 2.27e-05 | V_loss 3.05e-03 | F_loss 3.56e-04 | time 0.77s
# Epoch 112 | loss 2.30e-05 | V_loss 2.10e-03 | F_loss 1.35e-03 | time 0.89s
# Epoch 113 | loss 2.76e-05 | V_loss 3.25e-03 | F_loss 8.89e-04 | time 0.78s
# Epoch 114 | loss 2.28e-05 | V_loss 3.03e-03 | F_loss 3.87e-04 | time 0.83s
# Epoch 115 | loss 4.46e-05 | V_loss 5.93e-03 | F_loss 7.67e-04 | time 0.75s
# Epoch 116 | loss 3.59e-05 | V_loss 4.43e-03 | F_loss 9.58e-04 | time 0.74s
# Epoch 117 | loss 2.96e-05 | V_loss 3.89e-03 | F_loss 5.47e-04 | time 0.77s
# Epoch 118 | loss 6.07e-05 | V_loss 6.10e-03 | F_loss 3.01e-03 | time 0.76s
# Epoch 119 | loss 5.65e-05 | V_loss 5.73e-03 | F_loss 2.74e-03 | time 0.76s
# Epoch 120 | loss 4.63e-05 | V_loss 5.60e-03 | F_loss 1.35e-03 | time 0.73s
# Epoch 121 | loss 5.64e-05 | V_loss 4.98e-03 | F_loss 3.48e-03 | time 0.76s
# Epoch 122 | loss 3.26e-05 | V_loss 4.30e-03 | F_loss 5.88e-04 | time 0.75s
# Epoch 123 | loss 2.53e-05 | V_loss 3.63e-03 | F_loss 1.62e-04 | time 0.82s
# Epoch 124 | loss 4.28e-05 | V_loss 4.36e-03 | F_loss 2.05e-03 | time 0.76s
# Epoch 125 | loss 2.34e-05 | V_loss 3.04e-03 | F_loss 4.60e-04 | time 0.78s
# Epoch 126 | loss 3.92e-05 | V_loss 4.89e-03 | F_loss 9.91e-04 | time 0.75s
# Epoch 127 | loss 4.10e-05 | V_loss 5.91e-03 | F_loss 2.34e-04 | time 0.74s
# Epoch 128 | loss 3.48e-05 | V_loss 4.38e-03 | F_loss 8.43e-04 | time 0.75s
# Epoch 129 | loss 4.79e-05 | V_loss 5.42e-03 | F_loss 1.77e-03 | time 0.76s
# Epoch 130 | loss 5.58e-05 | V_loss 6.90e-03 | F_loss 1.48e-03 | time 0.75s
# Epoch 131 | loss 3.60e-05 | V_loss 4.88e-03 | F_loss 5.28e-04 | time 0.76s
# Epoch 132 | loss 3.51e-05 | V_loss 5.17e-03 | F_loss 9.27e-05 | time 0.76s
# Epoch 133 | loss 3.51e-05 | V_loss 5.15e-03 | F_loss 1.24e-04 | time 0.77s
# Epoch 134 | loss 2.99e-05 | V_loss 4.36e-03 | F_loss 1.22e-04 | time 0.79s
# Epoch 135 | loss 2.70e-05 | V_loss 2.67e-03 | F_loss 1.38e-03 | time 0.74s
# Epoch 136 | loss 3.61e-05 | V_loss 5.11e-03 | F_loss 3.03e-04 | time 0.76s
# Epoch 137 | loss 5.07e-05 | V_loss 6.78e-03 | F_loss 8.22e-04 | time 0.76s
# Epoch 138 | loss 3.71e-05 | V_loss 5.50e-03 | F_loss 6.28e-05 | time 0.76s
# Epoch 139 | loss 2.70e-05 | V_loss 4.03e-03 | F_loss 3.01e-05 | time 0.76s
# Epoch 140 | loss 3.70e-05 | V_loss 5.15e-03 | F_loss 4.09e-04 | time 0.76s
# Epoch 141 | loss 4.60e-05 | V_loss 6.43e-03 | F_loss 4.64e-04 | time 0.76s
# Epoch 142 | loss 5.41e-05 | V_loss 7.85e-03 | F_loss 2.64e-04 | time 0.76s
# Epoch 143 | loss 3.13e-05 | V_loss 4.60e-03 | F_loss 1.05e-04 | time 0.78s
# Epoch 144 | loss 4.14e-05 | V_loss 5.88e-03 | F_loss 3.25e-04 | time 0.74s
# Epoch 145 | loss 3.46e-05 | V_loss 4.96e-03 | F_loss 2.24e-04 | time 0.76s
# Epoch 146 | loss 3.46e-05 | V_loss 5.08e-03 | F_loss 1.03e-04 | time 0.77s
# Epoch 147 | loss 3.45e-05 | V_loss 5.09e-03 | F_loss 8.61e-05 | time 0.73s
# Epoch 148 | loss 3.59e-05 | V_loss 5.10e-03 | F_loss 2.86e-04 | time 0.75s
# Epoch 149 | loss 3.80e-05 | V_loss 5.15e-03 | F_loss 5.51e-04 | time 0.75s
# Epoch 150 | loss 3.59e-05 | V_loss 5.10e-03 | F_loss 2.85e-04 | time 0.76s
# Epoch 151 | loss 3.76e-05 | V_loss 5.24e-03 | F_loss 3.95e-04 | time 0.76s
# Epoch 152 | loss 3.57e-05 | V_loss 5.18e-03 | F_loss 1.66e-04 | time 0.74s
# Epoch 153 | loss 5.56e-05 | V_loss 8.21e-03 | F_loss 1.22e-04 | time 0.73s
# Epoch 154 | loss 4.31e-05 | V_loss 5.33e-03 | F_loss 1.13e-03 | time 0.74s
# Epoch 155 | loss 3.52e-05 | V_loss 5.07e-03 | F_loss 2.19e-04 | time 0.71s
# Epoch 156 | loss 3.54e-05 | V_loss 5.07e-03 | F_loss 2.42e-04 | time 0.76s
# Epoch 157 | loss 3.60e-05 | V_loss 5.10e-03 | F_loss 2.95e-04 | time 0.76s
# Epoch 158 | loss 3.64e-05 | V_loss 5.13e-03 | F_loss 3.30e-04 | time 0.76s
# Epoch 159 | loss 3.69e-05 | V_loss 5.21e-03 | F_loss 3.30e-04 | time 0.76s
# Epoch 160 | loss 3.76e-05 | V_loss 5.37e-03 | F_loss 2.65e-04 | time 0.76s
# Epoch 161 | loss 3.90e-05 | V_loss 5.73e-03 | F_loss 1.28e-04 | time 0.95s
# Epoch 162 | loss 4.28e-05 | V_loss 5.49e-03 | F_loss 9.38e-04 | time 0.75s
# Epoch 163 | loss 3.74e-05 | V_loss 5.11e-03 | F_loss 4.94e-04 | time 0.73s
# Epoch 164 | loss 3.78e-05 | V_loss 5.22e-03 | F_loss 4.45e-04 | time 0.75s
# Epoch 165 | loss 3.82e-05 | V_loss 5.37e-03 | F_loss 3.63e-04 | time 0.74s
# Epoch 166 | loss 3.97e-05 | V_loss 5.82e-03 | F_loss 1.30e-04 | time 0.76s
# Epoch 167 | loss 4.44e-05 | V_loss 5.68e-03 | F_loss 9.78e-04 | time 0.74s
# Epoch 168 | loss 3.63e-05 | V_loss 5.09e-03 | F_loss 3.55e-04 | time 0.72s
# Epoch 169 | loss 3.55e-05 | V_loss 5.07e-03 | F_loss 2.51e-04 | time 0.74s
# Epoch 170 | loss 3.58e-05 | V_loss 5.08e-03 | F_loss 2.93e-04 | time 1.05s
# Epoch 171 | loss 3.63e-05 | V_loss 5.13e-03 | F_loss 3.09e-04 | time 0.93s
# Epoch 172 | loss 3.69e-05 | V_loss 5.25e-03 | F_loss 2.90e-04 | time 0.74s
# Epoch 173 | loss 3.80e-05 | V_loss 5.53e-03 | F_loss 1.66e-04 | time 0.80s
# Epoch 174 | loss 3.86e-05 | V_loss 5.16e-03 | F_loss 6.38e-04 | time 0.80s
# Epoch 175 | loss 3.81e-05 | V_loss 5.29e-03 | F_loss 4.16e-04 | time 0.78s
# Epoch 176 | loss 3.89e-05 | V_loss 5.65e-03 | F_loss 1.95e-04 | time 0.94s
# Epoch 177 | loss 3.90e-05 | V_loss 5.17e-03 | F_loss 6.84e-04 | time 0.85s
# Epoch 178 | loss 3.84e-05 | V_loss 5.22e-03 | F_loss 5.36e-04 | time 0.79s
# Epoch 179 | loss 3.87e-05 | V_loss 5.37e-03 | F_loss 4.31e-04 | time 0.83s
# Epoch 180 | loss 3.95e-05 | V_loss 5.56e-03 | F_loss 3.64e-04 | time 0.80s
# Epoch 181 | loss 3.85e-05 | V_loss 5.44e-03 | F_loss 3.39e-04 | time 0.81s
# Epoch 182 | loss 3.90e-05 | V_loss 5.65e-03 | F_loss 1.93e-04 | time 0.84s
# Epoch 183 | loss 3.88e-05 | V_loss 5.16e-03 | F_loss 6.63e-04 | time 0.81s
# Epoch 184 | loss 3.67e-05 | V_loss 5.08e-03 | F_loss 4.32e-04 | time 0.78s
# Epoch 185 | loss 3.72e-05 | V_loss 5.25e-03 | F_loss 3.32e-04 | time 0.78s
# Epoch 186 | loss 3.82e-05 | V_loss 5.40e-03 | F_loss 3.37e-04 | time 0.76s
# Epoch 187 | loss 3.96e-05 | V_loss 5.10e-03 | F_loss 8.45e-04 | time 0.78s
# Epoch 188 | loss 3.90e-05 | V_loss 5.23e-03 | F_loss 6.21e-04 | time 0.80s
# Epoch 189 | loss 3.92e-05 | V_loss 5.46e-03 | F_loss 4.24e-04 | time 0.78s
# Epoch 190 | loss 4.12e-05 | V_loss 6.06e-03 | F_loss 1.21e-04 | time 0.78s
# Epoch 191 | loss 3.98e-05 | V_loss 5.53e-03 | F_loss 4.50e-04 | time 0.79s
# Epoch 192 | loss 3.53e-05 | V_loss 5.06e-03 | F_loss 2.27e-04 | time 0.77s
# Epoch 193 | loss 3.53e-05 | V_loss 5.06e-03 | F_loss 2.33e-04 | time 0.79s
# Epoch 194 | loss 3.58e-05 | V_loss 5.06e-03 | F_loss 3.10e-04 | time 0.80s
# Epoch 195 | loss 3.67e-05 | V_loss 5.07e-03 | F_loss 4.32e-04 | time 0.79s
# Epoch 196 | loss 8.56e-05 | V_loss 7.86e-03 | F_loss 4.97e-03 | time 0.78s
# Epoch 197 | loss 4.35e-05 | V_loss 5.28e-03 | F_loss 1.24e-03 | time 0.76s
# Epoch 198 | loss 3.51e-05 | V_loss 5.08e-03 | F_loss 1.88e-04 | time 0.77s
# Epoch 199 | loss 3.45e-05 | V_loss 5.04e-03 | F_loss 1.27e-04 | time 0.78s
# Epoch 200 | loss 3.90e-05 | V_loss 5.11e-03 | F_loss 7.52e-04 | time 0.80s
# Epoch 201 | loss 3.49e-05 | V_loss 5.05e-03 | F_loss 1.87e-04 | time 0.80s
# Epoch 202 | loss 3.47e-05 | V_loss 5.02e-03 | F_loss 1.86e-04 | time 0.82s
# Epoch 203 | loss 3.48e-05 | V_loss 5.00e-03 | F_loss 2.15e-04 | time 0.83s
# Epoch 204 | loss 3.47e-05 | V_loss 4.99e-03 | F_loss 2.19e-04 | time 0.84s
# Epoch 205 | loss 3.47e-05 | V_loss 4.98e-03 | F_loss 2.15e-04 | time 0.90s
# Epoch 206 | loss 3.47e-05 | V_loss 4.98e-03 | F_loss 2.19e-04 | time 0.82s
# Epoch 207 | loss 3.47e-05 | V_loss 5.00e-03 | F_loss 2.05e-04 | time 0.80s
# Epoch 208 | loss 3.51e-05 | V_loss 5.04e-03 | F_loss 2.19e-04 | time 0.80s
# Epoch 209 | loss 3.57e-05 | V_loss 5.17e-03 | F_loss 1.94e-04 | time 0.79s
# Epoch 210 | loss 3.72e-05 | V_loss 5.41e-03 | F_loss 1.64e-04 | time 0.76s
# Epoch 211 | loss 3.64e-05 | V_loss 5.04e-03 | F_loss 4.25e-04 | time 0.81s
# Epoch 212 | loss 3.66e-05 | V_loss 5.11e-03 | F_loss 3.83e-04 | time 0.80s
# Epoch 213 | loss 3.75e-05 | V_loss 5.25e-03 | F_loss 3.68e-04 | time 0.80s
# Epoch 214 | loss 3.88e-05 | V_loss 5.59e-03 | F_loss 2.28e-04 | time 0.91s
# Epoch 215 | loss 3.81e-05 | V_loss 5.05e-03 | F_loss 6.65e-04 | time 0.80s
# Epoch 216 | loss 3.61e-05 | V_loss 5.04e-03 | F_loss 3.74e-04 | time 0.77s
# Epoch 217 | loss 3.69e-05 | V_loss 5.08e-03 | F_loss 4.66e-04 | time 0.79s
# Epoch 218 | loss 3.73e-05 | V_loss 5.15e-03 | F_loss 4.50e-04 | time 0.77s
# Epoch 219 | loss 3.82e-05 | V_loss 5.29e-03 | F_loss 4.35e-04 | time 0.79s
# Epoch 220 | loss 3.90e-05 | V_loss 5.50e-03 | F_loss 3.53e-04 | time 0.78s
# Epoch 221 | loss 3.90e-05 | V_loss 5.53e-03 | F_loss 3.27e-04 | time 0.77s
# Epoch 222 | loss 3.86e-05 | V_loss 5.42e-03 | F_loss 3.62e-04 | time 0.76s
# Epoch 223 | loss 3.88e-05 | V_loss 5.46e-03 | F_loss 3.65e-04 | time 0.73s
# Epoch 224 | loss 3.95e-05 | V_loss 5.66e-03 | F_loss 2.69e-04 | time 0.72s
# Epoch 225 | loss 3.77e-05 | V_loss 5.08e-03 | F_loss 5.77e-04 | time 0.73s
# Epoch 226 | loss 3.83e-05 | V_loss 5.16e-03 | F_loss 5.86e-04 | time 0.77s
# Epoch 227 | loss 3.91e-05 | V_loss 5.24e-03 | F_loss 6.26e-04 | time 0.76s
# Epoch 228 | loss 3.96e-05 | V_loss 5.28e-03 | F_loss 6.65e-04 | time 0.77s
# Epoch 229 | loss 4.02e-05 | V_loss 5.26e-03 | F_loss 7.69e-04 | time 0.75s
# Epoch 230 | loss 4.02e-05 | V_loss 5.26e-03 | F_loss 7.65e-04 | time 0.73s
# Epoch 231 | loss 4.01e-05 | V_loss 5.44e-03 | F_loss 5.74e-04 | time 0.73s
# Epoch 232 | loss 4.21e-05 | V_loss 6.10e-03 | F_loss 2.15e-04 | time 0.77s
# Epoch 233 | loss 3.92e-05 | V_loss 5.56e-03 | F_loss 3.17e-04 | time 0.72s
# Epoch 234 | loss 3.45e-05 | V_loss 5.05e-03 | F_loss 1.25e-04 | time 0.77s
# Epoch 235 | loss 3.42e-05 | V_loss 5.01e-03 | F_loss 1.14e-04 | time 0.73s
# Epoch 236 | loss 3.46e-05 | V_loss 5.01e-03 | F_loss 1.71e-04 | time 0.74s
# Epoch 237 | loss 3.52e-05 | V_loss 5.02e-03 | F_loss 2.51e-04 | time 0.72s
# Epoch 238 | loss 3.59e-05 | V_loss 5.05e-03 | F_loss 3.39e-04 | time 0.72s
# Epoch 239 | loss 3.67e-05 | V_loss 5.08e-03 | F_loss 4.28e-04 | time 0.77s
# Epoch 240 | loss 3.76e-05 | V_loss 5.16e-03 | F_loss 4.87e-04 | time 0.72s
# Epoch 241 | loss 3.84e-05 | V_loss 5.27e-03 | F_loss 4.95e-04 | time 0.74s
# Epoch 242 | loss 3.92e-05 | V_loss 5.41e-03 | F_loss 4.68e-04 | time 0.75s
# Epoch 243 | loss 3.98e-05 | V_loss 5.60e-03 | F_loss 3.76e-04 | time 0.75s
# Epoch 244 | loss 3.85e-05 | V_loss 5.36e-03 | F_loss 4.17e-04 | time 0.76s
# Epoch 245 | loss 3.92e-05 | V_loss 5.42e-03 | F_loss 4.58e-04 | time 0.76s
# Epoch 246 | loss 4.02e-05 | V_loss 5.71e-03 | F_loss 3.19e-04 | time 0.77s
# Epoch 247 | loss 3.77e-05 | V_loss 5.13e-03 | F_loss 5.27e-04 | time 0.74s
# Epoch 248 | loss 3.87e-05 | V_loss 5.28e-03 | F_loss 5.19e-04 | time 0.74s
# Epoch 249 | loss 7.87e-05 | V_loss 7.50e-03 | F_loss 4.30e-03 | time 0.89s
# Epoch 250 | loss 3.60e-04 | V_loss 6.10e-03 | F_loss 4.79e-02 | time 0.75s
# Epoch 251 | loss 2.34e-04 | V_loss 6.87e-03 | F_loss 2.83e-02 | time 0.77s
# Epoch 252 | loss 4.46e-05 | V_loss 6.38e-03 | F_loss 3.20e-04 | time 0.76s
# Epoch 253 | loss 5.20e-05 | V_loss 5.61e-03 | F_loss 2.19e-03 | time 0.76s
# Epoch 254 | loss 3.73e-05 | V_loss 4.41e-03 | F_loss 1.18e-03 | time 0.76s
# Epoch 255 | loss 4.54e-05 | V_loss 4.43e-03 | F_loss 2.38e-03 | time 0.75s
# Epoch 256 | loss 3.23e-05 | V_loss 4.12e-03 | F_loss 7.29e-04 | time 0.76s
# Epoch 257 | loss 2.13e-05 | V_loss 3.07e-03 | F_loss 1.22e-04 | time 0.76s
# Epoch 258 | loss 2.08e-05 | V_loss 2.44e-03 | F_loss 6.78e-04 | time 0.76s
# Epoch 259 | loss 2.51e-05 | V_loss 2.54e-03 | F_loss 1.22e-03 | time 0.76s
# Epoch 260 | loss 2.52e-05 | V_loss 2.49e-03 | F_loss 1.29e-03 | time 0.77s
# Epoch 261 | loss 2.58e-05 | V_loss 2.51e-03 | F_loss 1.37e-03 | time 0.77s
# Epoch 262 | loss 2.02e-05 | V_loss 2.09e-03 | F_loss 9.41e-04 | time 0.77s
# Epoch 263 | loss 1.45e-05 | V_loss 1.70e-03 | F_loss 4.80e-04 | time 0.78s
# Epoch 264 | loss 1.31e-05 | V_loss 1.64e-03 | F_loss 3.19e-04 | time 0.71s
# Epoch 265 | loss 1.21e-05 | V_loss 1.56e-03 | F_loss 2.58e-04 | time 0.74s
# Epoch 266 | loss 1.18e-05 | V_loss 1.55e-03 | F_loss 2.25e-04 | time 0.75s
# Epoch 267 | loss 2.75e-05 | V_loss 3.73e-03 | F_loss 3.90e-04 | time 0.76s
# Epoch 268 | loss 1.73e-05 | V_loss 1.86e-03 | F_loss 7.31e-04 | time 0.75s
# Epoch 269 | loss 6.35e-05 | V_loss 7.33e-03 | F_loss 2.20e-03 | time 0.77s
# Epoch 270 | loss 4.30e-05 | V_loss 5.69e-03 | F_loss 7.60e-04 | time 0.78s
# Epoch 271 | loss 3.90e-05 | V_loss 5.49e-03 | F_loss 3.59e-04 | time 0.77s
# Epoch 272 | loss 3.68e-05 | V_loss 5.33e-03 | F_loss 1.93e-04 | time 0.77s
# Epoch 273 | loss 3.57e-05 | V_loss 5.24e-03 | F_loss 1.18e-04 | time 0.79s
# Epoch 274 | loss 3.52e-05 | V_loss 5.21e-03 | F_loss 7.31e-05 | time 0.76s
# Epoch 275 | loss 3.50e-05 | V_loss 5.20e-03 | F_loss 5.61e-05 | time 0.77s
# Epoch 276 | loss 3.55e-05 | V_loss 5.24e-03 | F_loss 8.03e-05 | time 0.77s
# Epoch 277 | loss 3.64e-05 | V_loss 5.31e-03 | F_loss 1.49e-04 | time 0.77s
# Epoch 278 | loss 3.75e-05 | V_loss 5.39e-03 | F_loss 2.36e-04 | time 0.82s
# Epoch 279 | loss 3.84e-05 | V_loss 5.47e-03 | F_loss 2.92e-04 | time 0.74s
# Epoch 280 | loss 3.91e-05 | V_loss 5.56e-03 | F_loss 3.09e-04 | time 0.75s
# Epoch 281 | loss 3.96e-05 | V_loss 5.63e-03 | F_loss 3.03e-04 | time 0.72s
# Epoch 282 | loss 3.96e-05 | V_loss 5.65e-03 | F_loss 2.90e-04 | time 0.75s
# Epoch 283 | loss 3.95e-05 | V_loss 5.63e-03 | F_loss 2.94e-04 | time 0.75s
# Epoch 284 | loss 3.95e-05 | V_loss 5.61e-03 | F_loss 3.11e-04 | time 0.75s
# Epoch 285 | loss 3.98e-05 | V_loss 5.65e-03 | F_loss 3.15e-04 | time 0.75s
# Epoch 286 | loss 3.91e-05 | V_loss 5.55e-03 | F_loss 3.26e-04 | time 0.78s
# Epoch 287 | loss 4.01e-05 | V_loss 5.65e-03 | F_loss 3.60e-04 | time 0.77s
# Epoch 288 | loss 3.89e-05 | V_loss 5.52e-03 | F_loss 3.26e-04 | time 0.79s
# Epoch 289 | loss 4.01e-05 | V_loss 5.62e-03 | F_loss 3.99e-04 | time 0.95s
# Epoch 290 | loss 3.96e-05 | V_loss 5.63e-03 | F_loss 3.18e-04 | time 0.78s
# Epoch 291 | loss 3.91e-05 | V_loss 5.48e-03 | F_loss 3.89e-04 | time 0.79s
# Epoch 292 | loss 4.02e-05 | V_loss 5.58e-03 | F_loss 4.54e-04 | time 0.73s
# Epoch 293 | loss 4.05e-05 | V_loss 5.77e-03 | F_loss 2.96e-04 | time 0.78s
# Epoch 294 | loss 3.71e-05 | V_loss 5.08e-03 | F_loss 4.79e-04 | time 0.81s
# Epoch 295 | loss 3.88e-05 | V_loss 5.21e-03 | F_loss 6.14e-04 | time 0.83s
# Epoch 296 | loss 3.95e-05 | V_loss 5.34e-03 | F_loss 5.82e-04 | time 0.78s
# Epoch 297 | loss 4.02e-05 | V_loss 5.51e-03 | F_loss 5.11e-04 | time 0.79s
# Epoch 298 | loss 4.07e-05 | V_loss 5.79e-03 | F_loss 3.20e-04 | time 0.77s
# Epoch 299 | loss 3.69e-05 | V_loss 5.07e-03 | F_loss 4.66e-04 | time 0.78s
# Epoch 300 | loss 3.81e-05 | V_loss 5.16e-03 | F_loss 5.47e-04 | time 0.79s
# Epoch 301 | loss 3.81e-05 | V_loss 5.13e-03 | F_loss 5.95e-04 | time 0.80s
# Epoch 302 | loss 3.79e-05 | V_loss 5.17e-03 | F_loss 5.23e-04 | time 0.75s
# Epoch 303 | loss 3.83e-05 | V_loss 5.26e-03 | F_loss 4.87e-04 | time 0.76s
# Epoch 304 | loss 3.89e-05 | V_loss 5.37e-03 | F_loss 4.57e-04 | time 0.77s
# Epoch 305 | loss 3.94e-05 | V_loss 5.49e-03 | F_loss 4.11e-04 | time 0.78s
# Epoch 306 | loss 3.92e-05 | V_loss 5.54e-03 | F_loss 3.47e-04 | time 0.86s
# Epoch 307 | loss 3.89e-05 | V_loss 5.46e-03 | F_loss 3.71e-04 | time 0.78s
# Epoch 308 | loss 3.96e-05 | V_loss 5.48e-03 | F_loss 4.58e-04 | time 0.74s
# Epoch 309 | loss 4.03e-05 | V_loss 5.67e-03 | F_loss 3.84e-04 | time 0.77s
# Epoch 310 | loss 3.65e-05 | V_loss 5.10e-03 | F_loss 3.71e-04 | time 0.89s
# Epoch 311 | loss 3.91e-05 | V_loss 5.19e-03 | F_loss 6.80e-04 | time 0.79s
# Epoch 312 | loss 3.84e-05 | V_loss 5.19e-03 | F_loss 5.70e-04 | time 0.77s
# Epoch 313 | loss 3.71e-05 | V_loss 5.24e-03 | F_loss 3.20e-04 | time 0.77s
# Epoch 314 | loss 3.78e-05 | V_loss 5.33e-03 | F_loss 3.38e-04 | time 0.82s
# Epoch 315 | loss 3.78e-05 | V_loss 5.33e-03 | F_loss 3.38e-04 | time 0.74s
# Epoch 316 | loss 3.82e-05 | V_loss 5.36e-03 | F_loss 3.70e-04 | time 0.75s
# Epoch 317 | loss 3.87e-05 | V_loss 5.45e-03 | F_loss 3.54e-04 | time 0.86s
# Epoch 318 | loss 3.83e-05 | V_loss 5.44e-03 | F_loss 3.08e-04 | time 0.95s
# Epoch 319 | loss 3.82e-05 | V_loss 5.37e-03 | F_loss 3.60e-04 | time 0.87s
# Epoch 320 | loss 3.89e-05 | V_loss 5.41e-03 | F_loss 4.29e-04 | time 0.86s
# Epoch 321 | loss 3.96e-05 | V_loss 5.59e-03 | F_loss 3.46e-04 | time 0.88s
# Epoch 322 | loss 3.41e-05 | V_loss 4.93e-03 | F_loss 1.90e-04 | time 0.77s
# Epoch 323 | loss 9.54e-05 | V_loss 1.18e-02 | F_loss 2.50e-03 | time 0.81s
# Epoch 324 | loss 4.12e-05 | V_loss 5.58e-03 | F_loss 5.91e-04 | time 0.76s
# Epoch 325 | loss 4.32e-05 | V_loss 5.61e-03 | F_loss 8.71e-04 | time 0.75s
# Epoch 326 | loss 4.17e-05 | V_loss 5.49e-03 | F_loss 7.77e-04 | time 0.76s
# Epoch 327 | loss 3.88e-05 | V_loss 5.33e-03 | F_loss 4.91e-04 | time 0.76s
# Epoch 328 | loss 3.02e-05 | V_loss 3.79e-03 | F_loss 7.37e-04 | time 0.73s
# Epoch 329 | loss 3.78e-05 | V_loss 5.59e-03 | F_loss 7.92e-05 | time 0.90s
# Epoch 330 | loss 3.94e-05 | V_loss 5.64e-03 | F_loss 2.74e-04 | time 0.79s
# Epoch 331 | loss 3.81e-05 | V_loss 5.47e-03 | F_loss 2.41e-04 | time 0.77s
# Epoch 332 | loss 3.71e-05 | V_loss 5.36e-03 | F_loss 2.04e-04 | time 0.75s
# Epoch 333 | loss 3.65e-05 | V_loss 5.29e-03 | F_loss 1.87e-04 | time 0.75s
# Epoch 334 | loss 3.59e-05 | V_loss 5.22e-03 | F_loss 1.66e-04 | time 0.72s
# Epoch 335 | loss 3.54e-05 | V_loss 5.18e-03 | F_loss 1.27e-04 | time 0.73s
# Epoch 336 | loss 3.49e-05 | V_loss 5.15e-03 | F_loss 9.11e-05 | time 0.74s
# Epoch 337 | loss 3.46e-05 | V_loss 5.11e-03 | F_loss 7.63e-05 | time 0.75s
# Epoch 338 | loss 3.44e-05 | V_loss 5.09e-03 | F_loss 7.36e-05 | time 0.71s
# Epoch 339 | loss 3.44e-05 | V_loss 5.07e-03 | F_loss 7.97e-05 | time 0.75s
# Epoch 340 | loss 3.44e-05 | V_loss 5.07e-03 | F_loss 9.37e-05 | time 0.72s
# Epoch 341 | loss 3.45e-05 | V_loss 5.07e-03 | F_loss 1.17e-04 | time 0.75s
# Epoch 342 | loss 3.48e-05 | V_loss 5.07e-03 | F_loss 1.48e-04 | time 0.76s
# Epoch 343 | loss 3.51e-05 | V_loss 5.07e-03 | F_loss 1.86e-04 | time 0.77s
# Epoch 344 | loss 3.54e-05 | V_loss 5.08e-03 | F_loss 2.25e-04 | time 0.76s
# Epoch 345 | loss 3.56e-05 | V_loss 5.08e-03 | F_loss 2.62e-04 | time 0.73s
# Epoch 346 | loss 3.59e-05 | V_loss 5.09e-03 | F_loss 3.00e-04 | time 0.74s
# Epoch 347 | loss 3.61e-05 | V_loss 5.09e-03 | F_loss 3.27e-04 | time 0.74s
# Epoch 348 | loss 3.63e-05 | V_loss 5.09e-03 | F_loss 3.55e-04 | time 0.75s
# Epoch 349 | loss 3.64e-05 | V_loss 5.10e-03 | F_loss 3.66e-04 | time 0.76s
# Epoch 350 | loss 3.65e-05 | V_loss 5.09e-03 | F_loss 3.89e-04 | time 0.82s
# Epoch 351 | loss 3.66e-05 | V_loss 5.09e-03 | F_loss 3.95e-04 | time 0.98s
# Epoch 352 | loss 3.66e-05 | V_loss 5.09e-03 | F_loss 3.96e-04 | time 1.02s
# Epoch 353 | loss 1.71e-04 | V_loss 2.02e-02 | F_loss 5.42e-03 | time 0.85s
# Epoch 354 | loss 4.10e-05 | V_loss 5.63e-03 | F_loss 5.25e-04 | time 0.80s
# Epoch 355 | loss 3.61e-05 | V_loss 5.27e-03 | F_loss 1.40e-04 | time 0.77s
# Epoch 356 | loss 3.65e-05 | V_loss 5.32e-03 | F_loss 1.58e-04 | time 0.75s
# Epoch 357 | loss 3.86e-05 | V_loss 5.48e-03 | F_loss 2.99e-04 | time 0.74s
# Epoch 358 | loss 4.14e-05 | V_loss 5.67e-03 | F_loss 5.48e-04 | time 0.77s
# Epoch 359 | loss 4.29e-05 | V_loss 5.76e-03 | F_loss 6.68e-04 | time 0.76s
# Epoch 360 | loss 4.30e-05 | V_loss 5.68e-03 | F_loss 7.59e-04 | time 0.73s
# Epoch 361 | loss 4.44e-05 | V_loss 5.86e-03 | F_loss 7.94e-04 | time 0.74s
# Epoch 362 | loss 3.80e-05 | V_loss 5.33e-03 | F_loss 3.67e-04 | time 0.78s
# Epoch 363 | loss 4.05e-05 | V_loss 5.92e-03 | F_loss 1.53e-04 | time 0.75s
# Epoch 364 | loss 6.37e-05 | V_loss 7.51e-03 | F_loss 2.04e-03 | time 0.85s
# Epoch 365 | loss 3.93e-05 | V_loss 5.70e-03 | F_loss 1.97e-04 | time 0.93s
# Epoch 366 | loss 4.16e-05 | V_loss 5.89e-03 | F_loss 3.53e-04 | time 1.32s
# Epoch 367 | loss 4.39e-05 | V_loss 6.05e-03 | F_loss 5.26e-04 | time 0.90s
# Epoch 368 | loss 4.56e-05 | V_loss 6.17e-03 | F_loss 6.66e-04 | time 0.80s
# Epoch 369 | loss 4.53e-05 | V_loss 6.20e-03 | F_loss 6.01e-04 | time 0.79s
# Epoch 370 | loss 1.32e-05 | V_loss 1.81e-03 | F_loss 1.62e-04 | time 0.78s
# Epoch 371 | loss 4.01e-05 | V_loss 4.86e-03 | F_loss 1.15e-03 | time 0.78s
# Epoch 372 | loss 1.75e-05 | V_loss 2.33e-03 | F_loss 2.98e-04 | time 0.76s
# Epoch 373 | loss 3.00e-05 | V_loss 3.34e-03 | F_loss 1.16e-03 | time 0.79s
# Epoch 374 | loss 3.98e-05 | V_loss 5.83e-03 | F_loss 1.43e-04 | time 0.79s
# Epoch 375 | loss 1.40e-05 | V_loss 1.95e-03 | F_loss 1.52e-04 | time 0.84s
# Epoch 376 | loss 3.63e-05 | V_loss 5.20e-03 | F_loss 2.54e-04 | time 0.78s
# Epoch 377 | loss 8.75e-06 | V_loss 1.19e-03 | F_loss 1.28e-04 | time 0.83s
# Epoch 378 | loss 2.78e-05 | V_loss 4.02e-03 | F_loss 1.60e-04 | time 0.80s
# Epoch 379 | loss 1.25e-05 | V_loss 1.82e-03 | F_loss 5.26e-05 | time 0.77s
# Epoch 380 | loss 1.69e-05 | V_loss 2.46e-03 | F_loss 7.76e-05 | time 0.77s
# Epoch 381 | loss 1.02e-05 | V_loss 1.51e-03 | F_loss 1.59e-05 | time 0.86s
# Epoch 382 | loss 1.07e-05 | V_loss 1.58e-03 | F_loss 2.02e-05 | time 0.99s
# Epoch 383 | loss 1.18e-05 | V_loss 1.75e-03 | F_loss 2.68e-05 | time 1.19s
# Epoch 384 | loss 1.81e-05 | V_loss 2.68e-03 | F_loss 2.85e-05 | time 1.07s
# Early stopping: Total training time exceeded 3 minutes.

# %%
print(np.mean(history['loss'][-5:]))

fig, ax = plt.subplot_mosaic(
    [
        ["loss", "combined"],
        ["V_loss", "combined"],
        ["F_loss", "combined"]
    ],
    figsize=(12, 5),
    sharex=True
)

# Individual plots
ax["loss"].semilogy(history["loss"], label="Train loss", color=colors[0])
ax["V_loss"].semilogy(history["V_loss"], label=r"Train $R$ loss", color=colors[1])
ax["F_loss"].semilogy(history["F_loss"], label=r"Train $F$ loss", color=colors[2])

# Combined plot (all together)
ax["combined"].semilogy(history["loss"], label="Loss", color=colors[0])
ax["combined"].semilogy(history["V_loss"], label=r"$R$ loss", color=colors[1])
ax["combined"].semilogy(history["F_loss"], label=r"$F$ loss", color=colors[2])

# Labels and styling
ax["F_loss"].set_xlabel("epoch")
ax["combined"].set_xlabel("epoch")

for key in ["loss", "V_loss", "F_loss", "combined"]:
    ax[key].set_ylabel("MSE")
    ax[key].legend()
    ax[key].grid(True, which="both", ls="--", lw=0.5)

plt.tight_layout()
plt.show()
# Out:
# 1.4191573796172935e-05

# %%
def evaluate(model, x_test, y_test):
    model.eval()
    with torch.no_grad():
        I = x_test[:,0]
        u = x_test[:,1]
        Ue = x_test[:,2]

        R0_pred, F_pred = model(x_test)
        y_pred = torch.stack([ECM_box(Ue,I,R0_pred), Mech_box(u,F_pred)],dim=1)

        #test_loss = nn.MSELoss()(y_pred, y_test).item()
    #print(f"Test MSE: {test_loss:.3e}")
    return y_pred.detach().numpy(), R0_pred.detach().numpy(), F_pred.detach().numpy()   


traj_eval = 0
y_pred, R0, F = evaluate(model, x_train[x_train[:,-1] == traj_eval][:,:-1], y_train[y_train[:,2] == traj_eval][:,:-1])


f, ax = plt.subplots(2, 2, figsize=(10, 8))
#plt.plot(x_test[:,0].numpy()* R0.detach().numpy(), label='Predicted $R_0$')
ax[0,0].plot(data['soc'][data['trajectory'] == traj_eval].values, R0, label=r'Predicted $IR_0$',color = colors[0])
ax[0,0].plot(data['soc'][data['trajectory'] == traj_eval].values,-data['eta'][data['trajectory'] == traj_eval].values / x_train[x_train[:,-1] == traj_eval][:,0].numpy(), label=r'True $\eta$',color = colors[1],ls = '--')

ax[0,1].plot(data['soc'][data['trajectory'] == traj_eval].values,data['V_t'][data['trajectory'] == traj_eval].values, label=r'True $V_t$', color = colors[1],ls = '--')
ax[0,1].plot(data['soc'][data['trajectory'] == traj_eval].values,y_pred[:,0], label=r'Predicted $V_t$', color = colors[0])

ax[1,0].plot(data['soc'][data['trajectory'] == traj_eval].values,data['Rx'][data['trajectory'] == traj_eval].values, label=r'True $F$', color = colors[1],ls = '--')
ax[1,0].plot(data['soc'][data['trajectory'] == traj_eval].values,y_pred[:,1], label=r'Predicted $F$', color = colors[0])    

ax[1,1].plot(data['soc'][data['trajectory'] == traj_eval].values,data['Rx'][data['trajectory'] == traj_eval].values + k.values[0] * x_train[x_train[:,-1] == traj_eval][:,1].numpy(), label=r'True $F_s$', color = colors[1], ls = '--')
ax[1,1].plot(data['soc'][data['trajectory'] == traj_eval].values,F, label=r'Pred $F_s$', color = colors[0])

for a in ax.flat:
    a.set_xlabel('State of Charge')
    a.legend()
    a.invert_xaxis()
ax[0,0].set_ylabel(r'$\eta$ and $IR_0$')
ax[0,1].set_ylabel(r'$V_t$ [V]')
ax[1,0].set_ylabel(r'$F$ [GN]')
ax[1,1].set_ylabel(r'$-k\Delta u$ [GN]')
plt.tight_layout()
# Out:
# /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_29960/3197020153.py:21: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   return 1 - np.exp(250*(soc - 1))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'soc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[130], line 22
#      20 f, ax = plt.subplots(2, 2, figsize=(10, 8))
#      21 #plt.plot(x_test[:,0].numpy()* R0.detach().numpy(), label='Predicted $R_0$')
# ---> 22 ax[0,0].plot(data['soc'][data['trajectory'] == traj_eval].values, R0, label=r'Predicted $IR_0$',color = colors[0])
#      23 ax[0,0].plot(data['soc'][data['trajectory'] == traj_eval].values,-data['eta'][data['trajectory'] == traj_eval].values / x_train[x_train[:,-1] == traj_eval][:,0].numpy(), label=r'True $\eta$',color = colors[1],ls = '--')
#      25 ax[0,1].plot(data['soc'][data['trajectory'] == traj_eval].values,data['V_t'][data['trajectory'] == traj_eval].values, label=r'True $V_t$', color = colors[1],ls = '--')
#
# File ~/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'soc'

# %%
def metrics(y_true, y_pred):
    mse = np.mean((y_true - y_pred) ** 2)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(y_true - y_pred))
    r2 = 1 - np.sum((y_true - y_pred) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2)
    return mse, rmse, mae, r2


def evaluate_metrics(model, x, y):
    model.eval()
    mse = np.zeros((torch.unique(x[:, -1]).numel(),2))
    rmse = np.zeros_like(mse)
    mae = np.zeros_like(mse)
    r2 = np.zeros_like(mse)
    j = 0
    for traj in x[:,-1].unique():
        x_traj = x[x[:,-1] == traj][:,:-1]
        y_traj = y[y[:,-1] == traj][:,:-1]
        with torch.no_grad():
            I = x_traj[:,0]
            u = x_traj[:,1]
            Ue = x_traj[:,2]

            R0_pred, F_pred = model(x_traj)
            y_pred = torch.stack([ECM_box(Ue,I,R0_pred), Mech_box(u,F_pred)],dim=1)

        y_true = y_traj.numpy()
        y_pred_np = y_pred.numpy()

        mse[j,0], rmse[j,0], mae[j,0], r2[j,0] = metrics(y_true[:,0], y_pred_np[:,0])
        mse[j,1], rmse[j,1], mae[j,1], r2[j,1] = metrics(y_true[:,1], y_pred_np[:,1])
        print(f"Test MSE: [{mse[j,0]:.3e},{mse[j,1]:.3e}], RMSE: [{rmse[j,0]:.3e},{rmse[j,1]:.3e}], MAE: [{mae[j,0]:.3e},{mae[j,1]:.3e}], R2: [{r2[j,0]:.3f},{r2[j,1]:.3f}]")
        j += 1
    return mse, rmse, mae, r2

mse, rmse, mae, r2 = evaluate_metrics(model, x_test, y_test)

f, ax = plt.subplots(4, 2, figsize=(7, 10),sharex=True)

ax[0,0].plot(mse[:,0], 'o-', color = colors[0])
ax[0,1].plot(mse[:,1], 'o-', color = colors[1])
ax[1,0].plot(rmse[:,0], 'o-', color = colors[2])
ax[1,1].plot(rmse[:,1], 'o-', color = colors[3])
ax[2,0].plot(mae[:,0], 'o-', color = colors[4])
ax[2,1].plot(mae[:,1], 'o-', color = colors[5])
ax[3,0].plot(r2[:,0], 'o-', color = colors[6])
ax[3,1].plot(r2[:,1], 'o-', color = colors[7])

ax[0,0].set_title('MSE for $V_t$')
ax[0,1].set_title('MSE for $F$')    
ax[1,0].set_title('RMSE for $V_t$')
ax[1,1].set_title('RMSE for $F$')
ax[2,0].set_title('MAE for $V_t$')
ax[2,1].set_title('MAE for $F$')
ax[3,0].set_title('R² for $V_t$')
ax[3,1].set_title('R² for $F$')
ax[3,0].set_xlabel('Trajectory')
ax[3,1].set_xlabel('Trajectory')
for a in ax.flat:
    a.set_ylabel('Error')
    a.grid(True, ls='--', lw=0.5)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_29960/3197020153.py:21: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   return 1 - np.exp(250*(soc - 1))
# Test MSE: [2.997e-03,1.742e-04], RMSE: [5.475e-02,1.320e-02], MAE: [3.560e-02,1.260e-02], R2: [0.961,0.996]
# Test MSE: [3.128e-03,1.720e-04], RMSE: [5.593e-02,1.311e-02], MAE: [3.581e-02,1.244e-02], R2: [0.959,0.996]
# Test MSE: [2.460e-03,2.242e-04], RMSE: [4.959e-02,1.497e-02], MAE: [3.237e-02,1.449e-02], R2: [0.966,0.994]
# Test MSE: [7.247e-03,3.670e-04], RMSE: [8.513e-02,1.916e-02], MAE: [4.569e-02,1.882e-02], R2: [0.902,0.989]
# Test MSE: [1.632e-03,1.284e-04], RMSE: [4.040e-02,1.133e-02], MAE: [2.134e-02,1.109e-02], R2: [0.979,0.997]
# Test MSE: [4.544e-03,2.556e-04], RMSE: [6.741e-02,1.599e-02], MAE: [4.501e-02,1.576e-02], R2: [0.939,0.993]
# Test MSE: [2.344e-03,1.088e-04], RMSE: [4.841e-02,1.043e-02], MAE: [2.983e-02,1.005e-02], R2: [0.968,0.997]
# Test MSE: [9.064e-03,6.240e-04], RMSE: [9.521e-02,2.498e-02], MAE: [6.498e-02,2.488e-02], R2: [0.882,0.979]
# Test MSE: [4.637e-03,2.223e-04], RMSE: [6.810e-02,1.491e-02], MAE: [3.972e-02,1.466e-02], R2: [0.936,0.994]
# Test MSE: [1.680e-03,5.945e-05], RMSE: [4.099e-02,7.710e-03], MAE: [1.811e-02,5.517e-03], R2: [0.980,0.999]
# Test MSE: [2.188e-03,2.105e-04], RMSE: [4.678e-02,1.451e-02], MAE: [2.934e-02,1.418e-02], R2: [0.971,0.995]
# Test MSE: [7.730e-03,5.734e-04], RMSE: [8.792e-02,2.395e-02], MAE: [4.840e-02,2.362e-02], R2: [0.892,0.982]
# Test MSE: [5.393e-03,5.306e-04], RMSE: [7.344e-02,2.304e-02], MAE: [4.976e-02,2.293e-02], R2: [0.924,0.984]
# Test MSE: [1.213e-02,6.025e-04], RMSE: [1.101e-01,2.455e-02], MAE: [8.956e-02,2.437e-02], R2: [0.843,0.980]
# Test MSE: [2.643e-03,1.740e-04], RMSE: [5.141e-02,1.319e-02], MAE: [2.962e-02,1.279e-02], R2: [0.965,0.996]
# Test MSE: [1.536e-03,4.168e-03], RMSE: [3.920e-02,6.456e-02], MAE: [2.091e-02,6.259e-02], R2: [0.983,0.912]
# Test MSE: [2.188e-03,1.008e-04], RMSE: [4.678e-02,1.004e-02], MAE: [2.046e-02,8.781e-03], R2: [0.974,0.998]
# Test MSE: [1.818e-03,1.400e-04], RMSE: [4.264e-02,1.183e-02], MAE: [2.567e-02,1.150e-02], R2: [0.976,0.997]
# Test MSE: [8.369e-03,6.604e-04], RMSE: [9.148e-02,2.570e-02], MAE: [7.125e-02,2.558e-02], R2: [0.883,0.979]
# Test MSE: [4.243e-03,2.278e-04], RMSE: [6.514e-02,1.509e-02], MAE: [3.901e-02,1.472e-02], R2: [0.943,0.994]
# Test MSE: [2.299e-03,1.600e-04], RMSE: [4.794e-02,1.265e-02], MAE: [3.018e-02,1.233e-02], R2: [0.970,0.996]
# Test MSE: [6.049e-03,3.766e-04], RMSE: [7.777e-02,1.941e-02], MAE: [4.457e-02,1.920e-02], R2: [0.915,0.989]
# Test MSE: [7.839e-03,6.296e-04], RMSE: [8.854e-02,2.509e-02], MAE: [6.730e-02,2.498e-02], R2: [0.890,0.980]
# Test MSE: [5.349e-03,2.966e-04], RMSE: [7.314e-02,1.722e-02], MAE: [4.305e-02,1.702e-02], R2: [0.927,0.991]
# Test MSE: [2.600e-03,2.220e-04], RMSE: [5.099e-02,1.490e-02], MAE: [3.356e-02,1.440e-02], R2: [0.964,0.994]
# Test MSE: [1.497e-03,1.036e-04], RMSE: [3.870e-02,1.018e-02], MAE: [2.211e-02,9.537e-03], R2: [0.981,0.998]
# Test MSE: [1.742e-03,1.108e-04], RMSE: [4.173e-02,1.052e-02], MAE: [1.541e-02,7.751e-03], R2: [0.980,0.998]
# Test MSE: [2.121e-03,1.565e-04], RMSE: [4.606e-02,1.251e-02], MAE: [1.890e-02,1.068e-02], R2: [0.975,0.997]
# Test MSE: [4.409e-03,3.130e-04], RMSE: [6.640e-02,1.769e-02], MAE: [4.061e-02,1.729e-02], R2: [0.941,0.991]

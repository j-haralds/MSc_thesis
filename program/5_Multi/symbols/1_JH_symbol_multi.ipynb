# %%
import torch
import numpy as np
import torch.nn as nn
from tqdm import trange
from pathlib import Path
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from torchinfo import summary
import time
import sys
import pandas as pd
import scipy
import seaborn as sns
import sklearn.gaussian_process as gp
from scipy import stats




sys.path.append('../..')
import plot_settings
import importlib
import multi_exp_log

from IPython.display import display, Math
from pysr import PySRRegressor, TemplateExpressionSpec
# import mean
from pysr import jl
jl.seval("using Statistics")

colors = plot_settings.colors()

def import_reload():
    plot_settings.apply()
    importlib.reload(multi_exp_log)

import_reload()
# Out:
# /Users/jonatanharaldsson/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %% [markdown]
# # Importing data

# %%
DT = 1
Q0 = 17921.57581 
#(data['I'][data['trajectory'] == 10].values)[0]  * 3600 / (data['C'][data['trajectory'] == 10].values)[0]  
#print(f'Q0: {Q0:.5f} As')

# %%
def read_data(file_name):
    df = pd.read_csv(
        f"../Multi_data/{file_name}.txt",
        sep=';',
        comment="%"
    )
    # cols = u_par,C,t,V,I,F,u,Ue,eta,trajectory,dV,dF,soc
    #df.columns = ['u_par','C','t','V','I','F','u','Ue','eta','trajectory','dV','dF','soc']
    # Sort by time within each batch
    return df


path = f'2_merged_data'

data = read_data(path)
display(data.head())
# Out:
#    u_par    C    t         V          I         F         u        Ue  \
# 0    0.4  2.2  0.0  4.239833  10.952074  0.030566 -0.057493  4.324996
# 1    0.4  2.2  1.0  4.211952  10.952074  0.030096 -0.057493  4.323139
# 2    0.4  2.2  2.0  4.195213  10.952074  0.029624 -0.057493  4.321278
# 3    0.4  2.2  3.0  4.183479  10.952074  0.029153 -0.057493  4.319417
# 4    0.4  2.2  4.0  4.176773  10.952074  0.028682 -0.057493  4.317557
#
#         eta  trajectory        dV        dF       soc
# 0 -0.085164           0 -0.027881 -0.000470  0.999389
# 1 -0.111187           0 -0.016738 -0.000471  0.998778
# 2 -0.126065           0 -0.011734 -0.000471  0.998167
# 3 -0.135938           0 -0.006706 -0.000471  0.997556
# 4 -0.140783           0 -0.005763 -0.000471  0.996944

# %% [markdown]
# To deal with more reasonable values, $F$ is measured in GN, while $\Delta u$ is measured in $10^{-5}$ m

# %% [markdown]
# ## The sampled terrain

# %%
u_C_pairs = data.loc[data['t'] == 0, ['u_par', 'C']]
plt.xlabel('C-rate [Ah]')
plt.ylabel(r'$\Delta u / L_{tot}$ [a.u.]')
plt.vlines(0.5,0,30, color='gray', linestyle='--')
plt.vlines(5,0,30, color='gray', linestyle='--')
plt.hlines(0,0.5,5, color='gray', linestyle='--')
plt.hlines(30,0.5,5, color='gray', linestyle='--')
plt.fill_between([0.5, 5], 0, 30, color='tab:blue', alpha=0.1)
plt.plot(u_C_pairs['C'], u_C_pairs['u_par'], 'o')

# %% [markdown]
# # Plotting data

# %%
plot_idx = data['trajectory'] == 0
f, ax = plt.subplots(2, 3, figsize=(10, 5))
ax[0,0].plot(data['V'][plot_idx], '-', color = colors[0], lw = 2)
ax[0,0].set_xlabel('Time step')
ax[0,0].set_ylabel('$V_{cell}$')
ax[0,1].plot(data['Ue'][plot_idx], '-', color = colors[1], lw = 2)
ax[0,1].set_xlabel('Time step')
ax[0,1].set_ylabel('Ue')
ax[0,2].plot(data['eta'][plot_idx], '-', color = colors[2], lw = 2)
ax[0,2].set_xlabel('Time step')
ax[0,2].set_ylabel(r'$\eta$')
ax[1,0].plot(data['F'][plot_idx], lw = 2,color = colors[3])
ax[1,0].set_xlabel('Time step')
ax[1,0].set_ylabel(r'$F$')
ax[1,1].plot(data['I'][plot_idx], lw = 2,color = colors[4])
ax[1,1].set_xlabel('Time step')
ax[1,1].set_ylabel(r'$I$')
ax[1,2].plot(data['u'][plot_idx], lw = 2,color = colors[5])
ax[1,2].set_xlabel('Time step')
ax[1,2].set_ylabel(r'$\Delta u$')

plt.tight_layout()
plt.show()

# %%
for plot_idx in np.unique(data['trajectory'].values):
    plt.plot(data['soc'][data['trajectory'] == plot_idx], -data['eta'][data['trajectory'] == plot_idx] / data['I'][data['trajectory'] == plot_idx], '-', color = colors[0], lw = 2,alpha=0.2)
plt.xlim(0.2,0.9)
plt.ylim(0.012,.02)
plt.gca().invert_xaxis()
plt.xlabel('State of Charge')
plt.ylabel(r'$\eta / I$ [Ohm]')
plt.title('Estimated R0 vs SoC')
# Out:
# Text(0.5, 1.0, 'Estimated R0 vs SoC')

# %%
u = data.groupby('trajectory')['u'].first().values
I = data.groupby('trajectory')['I'].first().values
eta_frac_list = []; I_list = []; soc_max_list = []
for traj in data['trajectory'].unique():
    soc_traj = data['soc'][(data['trajectory'] == traj)].max()
    soc_max_list.append(soc_traj)
    #print(f'Trajectory {traj}: SoC = {soc_traj:.2f}')
    eta_frac = -data['eta'][(data['trajectory'] == traj) & (data['soc'] == soc_traj)].values[0] / data['I'][(data['trajectory'] == traj)].max() 
    #print(eta_frac)
    I_list.append(data['I'][(data['trajectory'] == traj)].max())
    #/ data['I'][(data['trajectory'] == traj)].max()
    #idx = (eta_frac).abs().idxmin()
    eta_frac_list.append(eta_frac)
    print(f'Trajectory {traj}: Max |eta/I| = {eta_frac:.5f} Ohm at SoC = {soc_traj:.2f}')


R0_est = np.asarray(eta_frac_list)
# Out:
# Trajectory 0: Max |eta/I| = 0.00778 Ohm at SoC = 1.00
# Trajectory 1: Max |eta/I| = 0.00754 Ohm at SoC = 1.00
# Trajectory 2: Max |eta/I| = 0.00829 Ohm at SoC = 1.00
# Trajectory 3: Max |eta/I| = 0.00861 Ohm at SoC = 1.00
# Trajectory 4: Max |eta/I| = 0.00767 Ohm at SoC = 1.00
# Trajectory 5: Max |eta/I| = 0.00820 Ohm at SoC = 1.00
# Trajectory 6: Max |eta/I| = 0.00694 Ohm at SoC = 1.00
# Trajectory 7: Max |eta/I| = 0.00797 Ohm at SoC = 1.00
# Trajectory 8: Max |eta/I| = 0.00798 Ohm at SoC = 1.00
# Trajectory 9: Max |eta/I| = 0.00771 Ohm at SoC = 1.00
# Trajectory 10: Max |eta/I| = 0.00766 Ohm at SoC = 1.00
# Trajectory 11: Max |eta/I| = 0.00742 Ohm at SoC = 1.00
# Trajectory 12: Max |eta/I| = 0.00815 Ohm at SoC = 1.00
# Trajectory 13: Max |eta/I| = 0.00849 Ohm at SoC = 1.00
# Trajectory 14: Max |eta/I| = 0.00847 Ohm at SoC = 1.00
# Trajectory 15: Max |eta/I| = 0.00817 Ohm at SoC = 1.00
# Trajectory 16: Max |eta/I| = 0.00823 Ohm at SoC = 1.00
# Trajectory 17: Max |eta/I| = 0.00772 Ohm at SoC = 1.00
# Trajectory 18: Max |eta/I| = 0.00809 Ohm at SoC = 1.00
# Trajectory 19: Max |eta/I| = 0.00801 Ohm at SoC = 1.00
# Trajectory 20: Max |eta/I| = 0.00715 Ohm at SoC = 1.00
# Trajectory 21: Max |eta/I| = 0.00770 Ohm at SoC = 1.00
# Trajectory 22: Max |eta/I| = 0.00816 Ohm at SoC = 1.00
# Trajectory 23: Max |eta/I| = 0.00897 Ohm at SoC = 1.00
# Trajectory 24: Max |eta/I| = 0.00802 Ohm at SoC = 1.00
# Trajectory 25: Max |eta/I| = 0.00862 Ohm at SoC = 1.00
# Trajectory 26: Max |eta/I| = 0.00749 Ohm at SoC = 1.00
# Trajectory 27: Max |eta/I| = 0.00687 Ohm at SoC = 1.00
# Trajectory 28: Max |eta/I| = 0.00760 Ohm at SoC = 1.00
# Trajectory 29: Max |eta/I| = 0.00762 Ohm at SoC = 1.00
# Trajectory 30: Max |eta/I| = 0.00832 Ohm at SoC = 1.00
# Trajectory 31: Max |eta/I| = 0.00810 Ohm at SoC = 1.00
# Trajectory 32: Max |eta/I| = 0.00805 Ohm at SoC = 1.00
# Trajectory 33: Max |eta/I| = 0.00861 Ohm at SoC = 1.00
# Trajectory 34: Max |eta/I| = 0.00780 Ohm at SoC = 1.00
# Trajectory 35: Max |eta/I| = 0.00779 Ohm at SoC = 1.00
# Trajectory 36: Max |eta/I| = 0.00709 Ohm at SoC = 1.00
# Trajectory 37: Max |eta/I| = 0.00690 Ohm at SoC = 1.00
# Trajectory 38: Max |eta/I| = 0.00764 Ohm at SoC = 1.00
# Trajectory 39: Max |eta/I| = 0.00795 Ohm at SoC = 1.00
# Trajectory 40: Max |eta/I| = 0.00840 Ohm at SoC = 1.00
# Trajectory 41: Max |eta/I| = 0.00693 Ohm at SoC = 1.00
# Trajectory 42: Max |eta/I| = 0.00833 Ohm at SoC = 1.00
# Trajectory 43: Max |eta/I| = 0.00721 Ohm at SoC = 1.00
# Trajectory 44: Max |eta/I| = 0.00815 Ohm at SoC = 1.00
# Trajectory 45: Max |eta/I| = 0.00810 Ohm at SoC = 1.00
# Trajectory 46: Max |eta/I| = 0.00823 Ohm at SoC = 1.00
# Trajectory 47: Max |eta/I| = 0.00718 Ohm at SoC = 1.00
# Trajectory 48: Max |eta/I| = 0.00868 Ohm at SoC = 1.00
# Trajectory 49: Max |eta/I| = 0.00769 Ohm at SoC = 1.00
# Trajectory 50: Max |eta/I| = 0.00858 Ohm at SoC = 1.00
# Trajectory 51: Max |eta/I| = 0.00779 Ohm at SoC = 1.00
# Trajectory 52: Max |eta/I| = 0.00850 Ohm at SoC = 1.00
# Trajectory 53: Max |eta/I| = 0.00855 Ohm at SoC = 1.00
# Trajectory 54: Max |eta/I| = 0.00701 Ohm at SoC = 1.00
# Trajectory 55: Max |eta/I| = 0.00779 Ohm at SoC = 1.00
# Trajectory 56: Max |eta/I| = 0.00692 Ohm at SoC = 1.00
# Trajectory 57: Max |eta/I| = 0.00811 Ohm at SoC = 1.00
# Trajectory 58: Max |eta/I| = 0.00850 Ohm at SoC = 1.00
# Trajectory 59: Max |eta/I| = 0.00834 Ohm at SoC = 1.00
# Trajectory 60: Max |eta/I| = 0.00777 Ohm at SoC = 1.00
# Trajectory 61: Max |eta/I| = 0.00704 Ohm at SoC = 1.00
# Trajectory 62: Max |eta/I| = 0.00795 Ohm at SoC = 1.00
# Trajectory 63: Max |eta/I| = 0.00837 Ohm at SoC = 1.00
# Trajectory 64: Max |eta/I| = 0.00745 Ohm at SoC = 1.00
# Trajectory 65: Max |eta/I| = 0.00841 Ohm at SoC = 1.00
# Trajectory 66: Max |eta/I| = 0.00715 Ohm at SoC = 1.00
# Trajectory 67: Max |eta/I| = 0.00705 Ohm at SoC = 1.00
# Trajectory 68: Max |eta/I| = 0.00717 Ohm at SoC = 1.00
# Trajectory 69: Max |eta/I| = 0.00862 Ohm at SoC = 1.00
# Trajectory 70: Max |eta/I| = 0.00748 Ohm at SoC = 1.00
# Trajectory 71: Max |eta/I| = 0.00820 Ohm at SoC = 1.00
# Trajectory 72: Max |eta/I| = 0.00805 Ohm at SoC = 1.00
# Trajectory 73: Max |eta/I| = 0.00747 Ohm at SoC = 1.00
# Trajectory 74: Max |eta/I| = 0.00755 Ohm at SoC = 1.00
# Trajectory 75: Max |eta/I| = 0.00728 Ohm at SoC = 1.00
# Trajectory 76: Max |eta/I| = 0.00765 Ohm at SoC = 1.00
# Trajectory 77: Max |eta/I| = 0.00733 Ohm at SoC = 1.00
# Trajectory 78: Max |eta/I| = 0.00822 Ohm at SoC = 1.00
# Trajectory 79: Max |eta/I| = 0.00757 Ohm at SoC = 1.00
# Trajectory 80: Max |eta/I| = 0.00855 Ohm at SoC = 1.00
# Trajectory 81: Max |eta/I| = 0.00764 Ohm at SoC = 1.00
# Trajectory 82: Max |eta/I| = 0.00762 Ohm at SoC = 1.00
# Trajectory 83: Max |eta/I| = 0.00818 Ohm at SoC = 1.00
# Trajectory 84: Max |eta/I| = 0.00770 Ohm at SoC = 1.00
# Trajectory 85: Max |eta/I| = 0.00677 Ohm at SoC = 1.00
# Trajectory 86: Max |eta/I| = 0.00800 Ohm at SoC = 1.00
# Trajectory 87: Max |eta/I| = 0.00760 Ohm at SoC = 1.00
# Trajectory 88: Max |eta/I| = 0.00807 Ohm at SoC = 1.00
# Trajectory 89: Max |eta/I| = 0.00845 Ohm at SoC = 1.00
# Trajectory 90: Max |eta/I| = 0.00823 Ohm at SoC = 1.00
# Trajectory 91: Max |eta/I| = 0.00883 Ohm at SoC = 1.00
# Trajectory 92: Max |eta/I| = 0.00802 Ohm at SoC = 1.00
# Trajectory 93: Max |eta/I| = 0.00873 Ohm at SoC = 1.00
# Trajectory 94: Max |eta/I| = 0.00848 Ohm at SoC = 1.00
# Trajectory 95: Max |eta/I| = 0.00762 Ohm at SoC = 1.00
# Trajectory 96: Max |eta/I| = 0.00777 Ohm at SoC = 1.00
# Trajectory 97: Max |eta/I| = 0.00770 Ohm at SoC = 1.00
# Trajectory 98: Max |eta/I| = 0.00845 Ohm at SoC = 1.00
# Trajectory 99: Max |eta/I| = 0.00817 Ohm at SoC = 1.00
# Trajectory 100: Max |eta/I| = 0.00869 Ohm at SoC = 1.00
# Trajectory 101: Max |eta/I| = 0.00727 Ohm at SoC = 1.00
# Trajectory 102: Max |eta/I| = 0.00802 Ohm at SoC = 1.00
# Trajectory 103: Max |eta/I| = 0.00757 Ohm at SoC = 1.00
# Trajectory 104: Max |eta/I| = 0.00791 Ohm at SoC = 1.00
# Trajectory 105: Max |eta/I| = 0.00732 Ohm at SoC = 1.00
# Trajectory 106: Max |eta/I| = 0.00761 Ohm at SoC = 1.00
# Trajectory 107: Max |eta/I| = 0.00821 Ohm at SoC = 1.00
# Trajectory 108: Max |eta/I| = 0.00834 Ohm at SoC = 1.00
# Trajectory 109: Max |eta/I| = 0.00819 Ohm at SoC = 1.00
# Trajectory 110: Max |eta/I| = 0.00824 Ohm at SoC = 1.00
# Trajectory 111: Max |eta/I| = 0.00757 Ohm at SoC = 1.00
# Trajectory 112: Max |eta/I| = 0.00706 Ohm at SoC = 1.00
# Trajectory 113: Max |eta/I| = 0.00779 Ohm at SoC = 1.00
# Trajectory 114: Max |eta/I| = 0.00712 Ohm at SoC = 1.00
# Trajectory 115: Max |eta/I| = 0.00760 Ohm at SoC = 1.00
# Trajectory 116: Max |eta/I| = 0.00808 Ohm at SoC = 1.00
# Trajectory 117: Max |eta/I| = 0.00830 Ohm at SoC = 1.00
# Trajectory 118: Max |eta/I| = 0.00847 Ohm at SoC = 1.00
# Trajectory 119: Max |eta/I| = 0.00834 Ohm at SoC = 1.00
# Trajectory 120: Max |eta/I| = 0.00695 Ohm at SoC = 1.00
# Trajectory 121: Max |eta/I| = 0.00867 Ohm at SoC = 1.00
# Trajectory 122: Max |eta/I| = 0.00846 Ohm at SoC = 1.00
# Trajectory 123: Max |eta/I| = 0.00793 Ohm at SoC = 1.00
# Trajectory 124: Max |eta/I| = 0.00708 Ohm at SoC = 1.00
# Trajectory 125: Max |eta/I| = 0.00805 Ohm at SoC = 1.00
# Trajectory 126: Max |eta/I| = 0.00807 Ohm at SoC = 1.00
# Trajectory 127: Max |eta/I| = 0.00769 Ohm at SoC = 1.00
# Trajectory 128: Max |eta/I| = 0.00710 Ohm at SoC = 1.00
# Trajectory 129: Max |eta/I| = 0.00747 Ohm at SoC = 1.00
# Trajectory 130: Max |eta/I| = 0.00833 Ohm at SoC = 1.00
# Trajectory 131: Max |eta/I| = 0.00825 Ohm at SoC = 1.00
# Trajectory 132: Max |eta/I| = 0.00694 Ohm at SoC = 1.00
# Trajectory 133: Max |eta/I| = 0.00761 Ohm at SoC = 1.00
# Trajectory 134: Max |eta/I| = 0.00744 Ohm at SoC = 1.00
# Trajectory 135: Max |eta/I| = 0.00791 Ohm at SoC = 1.00
# Trajectory 136: Max |eta/I| = 0.00904 Ohm at SoC = 1.00
# Trajectory 137: Max |eta/I| = 0.00851 Ohm at SoC = 1.00
# Trajectory 138: Max |eta/I| = 0.00838 Ohm at SoC = 1.00
# Trajectory 139: Max |eta/I| = 0.00747 Ohm at SoC = 1.00
# Trajectory 140: Max |eta/I| = 0.00757 Ohm at SoC = 1.00
# Trajectory 141: Max |eta/I| = 0.00871 Ohm at SoC = 1.00
# Trajectory 142: Max |eta/I| = 0.00736 Ohm at SoC = 1.00
# Trajectory 143: Max |eta/I| = 0.00741 Ohm at SoC = 1.00
# Trajectory 144: Max |eta/I| = 0.00745 Ohm at SoC = 1.00
# Trajectory 145: Max |eta/I| = 0.00799 Ohm at SoC = 1.00
# Trajectory 146: Max |eta/I| = 0.00847 Ohm at SoC = 1.00
# Trajectory 147: Max |eta/I| = 0.00840 Ohm at SoC = 1.00
# Trajectory 148: Max |eta/I| = 0.00866 Ohm at SoC = 1.00
# Trajectory 149: Max |eta/I| = 0.00763 Ohm at SoC = 1.00
# Trajectory 150: Max |eta/I| = 0.00786 Ohm at SoC = 1.00
# Trajectory 151: Max |eta/I| = 0.00871 Ohm at SoC = 1.00
# Trajectory 152: Max |eta/I| = 0.00888 Ohm at SoC = 1.00
# Trajectory 153: Max |eta/I| = 0.00733 Ohm at SoC = 1.00
# Trajectory 154: Max |eta/I| = 0.00797 Ohm at SoC = 1.00
# Trajectory 155: Max |eta/I| = 0.00789 Ohm at SoC = 1.00
# Trajectory 156: Max |eta/I| = 0.00787 Ohm at SoC = 1.00
# Trajectory 157: Max |eta/I| = 0.00767 Ohm at SoC = 1.00
# Trajectory 158: Max |eta/I| = 0.00826 Ohm at SoC = 1.00
# Trajectory 159: Max |eta/I| = 0.00775 Ohm at SoC = 1.00
# Trajectory 160: Max |eta/I| = 0.00825 Ohm at SoC = 1.00
# Trajectory 161: Max |eta/I| = 0.00761 Ohm at SoC = 1.00
# Trajectory 162: Max |eta/I| = 0.00697 Ohm at SoC = 1.00
# Trajectory 163: Max |eta/I| = 0.00710 Ohm at SoC = 1.00
# Trajectory 164: Max |eta/I| = 0.00708 Ohm at SoC = 1.00
# Trajectory 165: Max |eta/I| = 0.00890 Ohm at SoC = 1.00
# Trajectory 166: Max |eta/I| = 0.00713 Ohm at SoC = 1.00
# Trajectory 167: Max |eta/I| = 0.00805 Ohm at SoC = 1.00
# Trajectory 168: Max |eta/I| = 0.00800 Ohm at SoC = 1.00
# Trajectory 169: Max |eta/I| = 0.00767 Ohm at SoC = 1.00
# Trajectory 170: Max |eta/I| = 0.00748 Ohm at SoC = 1.00
# Trajectory 171: Max |eta/I| = 0.00709 Ohm at SoC = 1.00
# Trajectory 172: Max |eta/I| = 0.00765 Ohm at SoC = 1.00
# Trajectory 173: Max |eta/I| = 0.00854 Ohm at SoC = 1.00
# Trajectory 174: Max |eta/I| = 0.00789 Ohm at SoC = 1.00
# Trajectory 175: Max |eta/I| = 0.00702 Ohm at SoC = 1.00
# Trajectory 176: Max |eta/I| = 0.00813 Ohm at SoC = 1.00
# Trajectory 177: Max |eta/I| = 0.00805 Ohm at SoC = 1.00
# Trajectory 178: Max |eta/I| = 0.00849 Ohm at SoC = 1.00
# Trajectory 179: Max |eta/I| = 0.00689 Ohm at SoC = 1.00
# Trajectory 180: Max |eta/I| = 0.00763 Ohm at SoC = 1.00
# Trajectory 181: Max |eta/I| = 0.00855 Ohm at SoC = 1.00
# Trajectory 182: Max |eta/I| = 0.00718 Ohm at SoC = 1.00
# Trajectory 183: Max |eta/I| = 0.00796 Ohm at SoC = 1.00
# Trajectory 184: Max |eta/I| = 0.00895 Ohm at SoC = 1.00
# Trajectory 185: Max |eta/I| = 0.00836 Ohm at SoC = 1.00
# Trajectory 186: Max |eta/I| = 0.00839 Ohm at SoC = 1.00
# Trajectory 187: Max |eta/I| = 0.00795 Ohm at SoC = 1.00
# Trajectory 188: Max |eta/I| = 0.00865 Ohm at SoC = 1.00
# Trajectory 189: Max |eta/I| = 0.00803 Ohm at SoC = 1.00
# Trajectory 190: Max |eta/I| = 0.00748 Ohm at SoC = 1.00
# Trajectory 191: Max |eta/I| = 0.00826 Ohm at SoC = 1.00
# Trajectory 192: Max |eta/I| = 0.00870 Ohm at SoC = 1.00
# Trajectory 193: Max |eta/I| = 0.00817 Ohm at SoC = 1.00
# Trajectory 194: Max |eta/I| = 0.00755 Ohm at SoC = 1.00
# Trajectory 195: Max |eta/I| = 0.00713 Ohm at SoC = 1.00
# Trajectory 196: Max |eta/I| = 0.00871 Ohm at SoC = 1.00
# Trajectory 197: Max |eta/I| = 0.00733 Ohm at SoC = 1.00
# Trajectory 198: Max |eta/I| = 0.00858 Ohm at SoC = 1.00
# Trajectory 199: Max |eta/I| = 0.00840 Ohm at SoC = 1.00
# Trajectory 200: Max |eta/I| = 0.00788 Ohm at SoC = 1.00
# Trajectory 201: Max |eta/I| = 0.00853 Ohm at SoC = 1.00
# Trajectory 202: Max |eta/I| = 0.00757 Ohm at SoC = 1.00
# Trajectory 203: Max |eta/I| = 0.00840 Ohm at SoC = 1.00
# Trajectory 204: Max |eta/I| = 0.00887 Ohm at SoC = 1.00
# Trajectory 205: Max |eta/I| = 0.00741 Ohm at SoC = 1.00
# Trajectory 206: Max |eta/I| = 0.00749 Ohm at SoC = 1.00
# Trajectory 207: Max |eta/I| = 0.00773 Ohm at SoC = 1.00
# Trajectory 208: Max |eta/I| = 0.00823 Ohm at SoC = 1.00
# Trajectory 209: Max |eta/I| = 0.00708 Ohm at SoC = 1.00
# Trajectory 210: Max |eta/I| = 0.00763 Ohm at SoC = 1.00
# Trajectory 211: Max |eta/I| = 0.00800 Ohm at SoC = 1.00
# Trajectory 212: Max |eta/I| = 0.00826 Ohm at SoC = 1.00
# Trajectory 213: Max |eta/I| = 0.00784 Ohm at SoC = 1.00
# Trajectory 214: Max |eta/I| = 0.00687 Ohm at SoC = 1.00
# Trajectory 215: Max |eta/I| = 0.00805 Ohm at SoC = 1.00
# Trajectory 216: Max |eta/I| = 0.00688 Ohm at SoC = 1.00
# Trajectory 217: Max |eta/I| = 0.00851 Ohm at SoC = 1.00
# Trajectory 218: Max |eta/I| = 0.00737 Ohm at SoC = 1.00
# Trajectory 219: Max |eta/I| = 0.00761 Ohm at SoC = 1.00
# Trajectory 220: Max |eta/I| = 0.00783 Ohm at SoC = 1.00
# Trajectory 221: Max |eta/I| = 0.00837 Ohm at SoC = 1.00
# Trajectory 222: Max |eta/I| = 0.00704 Ohm at SoC = 1.00
# Trajectory 223: Max |eta/I| = 0.00694 Ohm at SoC = 1.00
# Trajectory 224: Max |eta/I| = 0.00825 Ohm at SoC = 1.00
# Trajectory 225: Max |eta/I| = 0.00812 Ohm at SoC = 1.00
# Trajectory 226: Max |eta/I| = 0.00707 Ohm at SoC = 1.00
# Trajectory 227: Max |eta/I| = 0.00825 Ohm at SoC = 1.00
# Trajectory 228: Max |eta/I| = 0.00726 Ohm at SoC = 1.00
# Trajectory 229: Max |eta/I| = 0.00722 Ohm at SoC = 1.00
# Trajectory 230: Max |eta/I| = 0.00789 Ohm at SoC = 1.00
# Trajectory 231: Max |eta/I| = 0.00859 Ohm at SoC = 1.00
# Trajectory 232: Max |eta/I| = 0.00748 Ohm at SoC = 1.00
# Trajectory 233: Max |eta/I| = 0.00726 Ohm at SoC = 1.00
# Trajectory 234: Max |eta/I| = 0.00782 Ohm at SoC = 1.00
# Trajectory 235: Max |eta/I| = 0.00764 Ohm at SoC = 1.00
# Trajectory 236: Max |eta/I| = 0.00885 Ohm at SoC = 1.00
# Trajectory 237: Max |eta/I| = 0.00807 Ohm at SoC = 1.00
# Trajectory 238: Max |eta/I| = 0.00846 Ohm at SoC = 1.00
# Trajectory 239: Max |eta/I| = 0.00837 Ohm at SoC = 1.00
# Trajectory 240: Max |eta/I| = 0.00845 Ohm at SoC = 1.00
# Trajectory 241: Max |eta/I| = 0.00742 Ohm at SoC = 1.00
# Trajectory 242: Max |eta/I| = 0.00824 Ohm at SoC = 1.00
# Trajectory 243: Max |eta/I| = 0.00805 Ohm at SoC = 1.00
# Trajectory 244: Max |eta/I| = 0.00771 Ohm at SoC = 1.00
# Trajectory 245: Max |eta/I| = 0.00770 Ohm at SoC = 1.00
# Trajectory 246: Max |eta/I| = 0.00846 Ohm at SoC = 1.00
# Trajectory 247: Max |eta/I| = 0.00834 Ohm at SoC = 1.00

# %%
f, ax = plt.subplots(1,2,figsize=(12,4))

sc0 = ax[0].scatter(30 * u/u.min(), R0_est, c=I_list, cmap='coolwarm')
ax[0].set_xlabel(r'$\Delta u / L_{tot}$ [a.u.]')
ax[0].set_ylabel('Estimated R0 [Ohm]')
cbar0 = plt.colorbar(sc0, ax=ax[0])
cbar0.set_label('Current [A]')

sc1 = ax[1].scatter(I, R0_est*I_list, c=30 * u/u.min(), cmap='coolwarm')
ax[1].set_xlabel('Current [A]')
ax[1].set_ylabel('Estimated R0 [Ohm]')
cbar1 = plt.colorbar(sc1, ax=ax[1])
cbar1.set_label(r'$\Delta u / L_{tot}$ [a.u.]')

plt.tight_layout()

# %%
plt.plot(I_list, soc_max_list, 'o')

# %%
#R0_est = data['eta'][(data['soc'] < 0.8) & (data['soc'] > 0.3)].values / data['I'][(data['soc'] < 0.8) & (data['soc'] > 0.3)].values

plt.scatter(u,I, c = R0_est, cmap = 'copper')
plt.colorbar(label = r'Estimated $R_0$ [Ohm]')
plt.xlabel(r'$\Delta u$ [µm]')
plt.ylabel(r'$I$ [A]')
plt.title('Estimated $R_0$ across trajectories')
plt.show()

# %%
X_data = np.vstack((u,I)).T
Y_data = R0_est

print(f'X_data shape: {X_data.shape}')
print(f'Y_data shape: {Y_data.shape}')
# Out:
# X_data shape: (248, 2)
# Y_data shape: (248, 1)

# %%
model = PySRRegressor(
    model_selection="score",
    niterations=250,
    binary_operators=[
        "+", "*", '-','/'
    ],
    unary_operators=['sqrt','square', 'cube'],
    elementwise_loss="loss(x, y) = (x - y)^2",
    populations=20,
    verbosity=0
)

# %%
model.fit(X_data, Y_data)
# Out:
# /Users/jonatanharaldsson/Library/CloudStorage/OneDrive-Personal/0_Skola/Thesis/MSc_thesis/program/.venv/lib/python3.12/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                        0.007891641
# 	1         0.396083                  (x1 * -7.37933e-5) - -0.008898606
# 	2         0.452101          0.0087710265 - ((x1 + x0) * 7.6535754e-5)
# 	3         0.455712   0.008332411 - ((x1 - square(x0)) * 5.9160935e-5)
# 	4   >>>>  1.433608  ((x0 * -0.0001887521) + 0.008446693) - (x1 * 7...
# 	5         0.699460  (square(x0) * 4.3021093e-5) + ((x1 * -7.132249...
# 	6         0.000960  (0.008598342 - (x1 * 7.13213e-5)) - (square(0....
# 	7         0.131851  ((x0 * ((x0 * 3.2555054e-5) + -4.8187583e-5)) ...
# 	8         0.061253  ((0.008537985 + (x0 * -0.00010341921)) - (7.11...
# 	9         0.123497  (0.008303115 + (4.2970645e-5 * square(x0))) + ...
# 	10        0.000004  ((x0 * x0) * 4.297962e-5) + ((((0.00018363578 ...
# 	11        0.006993  (((x0 + -0.044432815) * (x0 * 4.2572246e-5)) +...
# 	12        0.234631  (((x0 + (4.9067364 / sqrt(x1))) * -0.000104666...
# 	13        0.056247  ((x0 * -2.0730546e-5) + ((cube(x0) * -9.92367e...
# 	14        0.000319  (0.0021068018 + ((x0 * -2.6389342e-5) + ((cube...
# 	15        0.001968  ((0.0016792585 - ((x0 - (x0 / cube(x1))) * 2.0...
# 	16        0.001061  ((cube(4.1358085 / square(x1)) + x0) * -0.0001...
# 	17        0.000044  (((cube(x0) * -8.4646496e-7) - (x1 * 9.262679e...
#
# 	            loss  complexity
# 	0   2.840073e-07           1
# 	1   5.824560e-08           5
# 	2   2.358159e-08           7
# 	3   1.495065e-08           8
# 	4   3.564940e-09           9
# 	5   1.771253e-09          10
# 	6   1.767855e-09          12
# 	7   1.549475e-09          13
# 	8   1.457413e-09          14
# 	9   1.288097e-09          15
# 	10  1.288092e-09          16
# 	11  1.270201e-09          18
# 	12  1.004554e-09          19
# 	13  8.976717e-10          21
# 	14  8.968119e-10          24
# 	15  8.932887e-10          26
# 	16  8.923418e-10          27
# 	17  8.922638e-10          29
# ]

# %%
df_model = model.equations_

plt.scatter(df_model['complexity'], df_model['loss'])
plt.xlabel('Complexity')
plt.ylabel('Loss')
plt.title('Model Complexity vs Loss')
# Out:
# Text(0.5, 1.0, 'Model Complexity vs Loss')

# %%
model_index = None
display(Math(f'\\LARGE {model.latex(model_index)}'))
print(f'Best model in symbolic form: {model.sympy()}')
# Out:
# $\displaystyle \LARGE x_{0} \left(-0.000189\right) - x_{1} \cdot 7.05 \cdot 10^{-5} + 0.00845$
# Best model in symbolic form: x0*(-0.0001887521) - 7.049519e-5*x1 + 0.008446693

# %%
rand_samples = np.random.choice(len(u),size=5, replace=False)
I_test = I[rand_samples]
u_test = u[rand_samples]
R0_test = R0_est[:5]
R0_pred = model.predict(np.vstack((u_test, I_test)).T)

f, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].scatter(I_test, R0_test, label='Data', color=colors[0])
ax[0].scatter(I_test, R0_pred, label='Model Predictions', color=colors[1], marker='x', s=100)
ax[0].set_xlabel('Current (I) [A]')
ax[0].set_ylabel('Estimated $R_0$ [Ohm]')
ax[0].set_title('Current vs Estimated $R_0$')
ax[0].legend()
ax[1].scatter(u_test, R0_test, label='Data', color=colors[0])
ax[1].scatter(u_test, R0_pred, label='Model Predictions', color=colors[1], marker='x', s=100)
ax[1].set_xlabel(r'$\Delta u$ [µm]')
ax[1].set_ylabel('Estimated $R_0$ [Ohm]')
ax[1].set_title(r'$\Delta u$ vs Estimated $R_0$')
ax[1].legend()
plt.tight_layout()
plt.show()

# %%
# Parity plot
R0_pred = model.predict(X_data)
plt.scatter(R0_est, R0_pred, color=colors[0],alpha = 0.7)
plt.plot([R0_est.min(), R0_est.max()], [R0_est.min(), R0_est.max()], 'k--', lw=2)
plt.xlabel('Actual Estimated $R_0$ [Ohm]')
plt.ylabel('Predicted $R_0$ [Ohm]')
plt.title('Parity Plot for $R_0$ Predictions')
plt.show()

# %%
plt.hist(100 * (1  - R0_pred / R0_est).ravel(), bins=20, color=colors[3], edgecolor='k', alpha=0.55, density=True)
plt.show()

# %%
plot_idx = 8

plt.plot(data['soc'][data['trajectory'] == plot_idx], -data['eta'][data['trajectory'] == plot_idx] / data['I'][data['trajectory'] == plot_idx], '--', color = colors[1], lw = 2,alpha=1)
plt.plot(data['soc'][data['trajectory'] == plot_idx], model.predict(np.vstack((data['u'][data['trajectory'] == plot_idx], data['I'][data['trajectory'] == plot_idx])).T), '-', color = colors[2], lw = 2,alpha=1)

plt.ylim(0.0,.02)
plt.gca().invert_xaxis()
plt.xlabel('State of Charge')
plt.ylabel(r'$\eta / I$ [Ohm]')
plt.title('Estimated R0 vs SoC')
# Out:
# Text(0.5, 1.0, 'Estimated R0 vs SoC')

# %%
u_grid, I_grid = plot_settings.grid_gen([np.min(u), np.max(u)], [np.min(I), np.max(I)], [100,100])

R0_grid = model.predict(np.vstack((u_grid.ravel(), I_grid.ravel())).T).reshape(u_grid.shape)

plt.contourf(I_grid, u_grid, R0_grid, levels=50, cmap='Blues')
plt.colorbar(label = 'Estimated $R_0$ [Ohm]')
plt.xlabel('Current [A]')
plt.ylabel(r'$\Delta u$ [µm]')
plt.title('Estimated $R_0$ across the input space')
# Out:
# Text(0.5, 1.0, 'Estimated $R_0$ across the input space')

# %% [markdown]
# {4.1, 4.0, 4.9, 4.6, 4.7, 4.3, 4.5, 5.0, 4.7, 3.6, 3.7, 3.5, 3.5, 4.9, 4.6, 4.0, 4.1, 4.3, 4.7, 3.9, 3.6, 4.2, 4.8, 4.4, 4.5, 3.7, 4.4, 4.6, 3.8, 3.8, 4.9, 4.8, 4.0, 4.4, 4.7, 4.9, 3.8, 4.3, 4.0, 4.1, 3.7, 5.0, 3.7, 3.6, 4.0, 4.2, 3.8, 3.7, 4.8, 4.4, 4.2, 4.6, 3.9, 3.6, 4.3, 3.9, 4.1, 3.5, 4.5, 4.7, 4.5, 4.8, 4.7, 4.4, 3.8, 4.2, 4.2, 4.9, 3.9, 4.3}
#
#
# {2.8, 3.3, 22.8, 15.9, 3.8, 2.2, 1.2, 18.8, 1.3, 28.9, 17.8, 29.8, 5.9, 17.4, 26.2, 26.9, 18.9, 23.4, 12.7, 19.5, 10.7, 7.6, 6.1, 13.8, 15.7, 16.5, 15.2, 28.4, 24.6, 23.9, 13.0, 4.5, 0.8, 11.7, 27.8, 29.4, 7.0, 12.0, 27.1, 13.4, 22.1, 24.3, 14.3, 26.1, 7.7, 22.5, 20.8, 4.8, 4.0, 20.5, 25.2, 0.0, 11.4, 1.9, 10.1, 21.6, 5.2, 18.2, 25.4, 28.0, 8.6, 9.8, 16.9, 21.1, 14.9, 6.6, 8.2, 20.0, 9.1, 11.1}

# %%
c_list = [4.1, 4.0, 4.9, 4.6, 4.7, 4.3, 4.5, 5.0, 4.7, 3.6, 3.7, 3.5, 3.5, 4.9, 4.6, 4.0, 4.1, 4.3, 4.7, 3.9, 3.6, 4.2, 4.8, 4.4, 4.5, 3.7, 4.4, 4.6, 3.8, 3.8, 4.9, 4.8, 4.0, 4.4, 4.7, 4.9, 3.8, 4.3, 4.0, 4.1, 3.7, 5.0, 3.7, 3.6, 4.0, 4.2, 3.8, 3.7, 4.8, 4.4, 4.2, 4.6, 3.9, 3.6, 4.3, 3.9, 4.1, 3.5, 4.5, 4.7, 4.5, 4.8, 4.7, 4.4, 3.8, 4.2, 4.2, 4.9, 3.9, 4.3]
u_list = [2.8, 3.3, 22.8, 15.9, 3.8, 2.2, 1.2, 18.8, 1.3, 28.9, 17.8, 29.8, 5.9, 17.4, 26.2, 26.9, 18.9, 23.4, 12.7, 19.5, 10.7, 7.6, 6.1, 13.8, 15.7, 16.5, 15.2, 28.4, 24.6, 23.9, 13.0, 4.5, 0.8, 11.7, 27.8, 29.4, 7.0, 12.0, 27.1, 13.4, 22.1, 24.3, 14.3, 26.1, 7.7, 22.5, 20.8, 4.8, 4.0, 20.5, 25.2, 0.0, 11.4, 1.9, 10.1, 21.6, 5.2, 18.2, 25.4, 28.0, 8.6, 9.8, 16.9, 21.1, 14.9, 6.6, 8.2, 20.0, 9.1, 11.1]

print(len(c_list), len(u_list))
# Out:
# 70 70

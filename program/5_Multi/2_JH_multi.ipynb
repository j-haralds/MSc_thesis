# %%
import torch
import numpy as np
import torch.nn as nn
from tqdm import trange
from pathlib import Path
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import importlib
from torchinfo import summary
import time
import sys
import pandas as pd
import scipy


sys.path.append('..')
import plot_settings
plot_settings.apply()
colors = plot_settings.colors()

# %% [markdown]
# # Importing data

# %%
def read_data(file_name):
    df = pd.read_csv(
        f"Multi_data/{file_name}.txt",
        delim_whitespace=True,
        comment="%",
        header=None
    )

    df.columns = ['u_par','C','t','E_cell (V)','I_cell (A)','Rx_cell (N)','u_cell (m)','E_ocv_cell (V)']

    # Sort by time within each batch
    df = df.sort_values(["C", "t"])
    return df



path = f'test_data_50beta_20p'

data = read_data(path)

#rename columns
data.columns = ['u_par','C','t','V_t','I','Rx','u','ocv']
# Out:
# /var/folders/xl/schcbct544b8f32_b4484x5c0000gn/T/ipykernel_31163/1032795895.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(

# %%
# Add numeric trajectory id for each unique (C, u_par) pair
data['trajectory_id'] = data.groupby(['C', 'u_par'], sort=True).ngroup()

# Optional lookup table (one row per trajectory)
trajectory_lookup = (
    data[['C', 'u_par', 'trajectory_id']]
    .drop_duplicates()
    .sort_values('trajectory_id')
    .reset_index(drop=True)
)

print(trajectory_lookup)
print(f"Number of trajectories: {trajectory_lookup['trajectory_id'].nunique()}")
# Out:
#       C  u_par  trajectory_id
# 0   0.7   13.2              0
# 1   0.8    2.2              1
# 2   1.1   27.0              2
# 3   1.3   20.1              3
# 4   1.4   10.0              4
# 5   1.8   25.8              5
# 6   2.0   15.5              6
# 7   2.3   11.2              7
# 8   2.3   24.2              8
# 9   2.6   14.6              9
# 10  2.8    0.6             10
# 11  3.2   17.7             11
# 12  3.3    4.7             12
# 13  3.6    6.7             13
# 14  3.7   19.2             14
# 15  3.9   21.4             15
# 16  4.2   23.5             16
# 17  4.3   29.7             17
# 18  4.7    3.3             18
# 19  4.9    7.8             19
# Number of trajectories: 20

# %%
# Add a trajectory column (reuse existing IDs if already available)
if 'trajectory_id' in data.columns:
	data['trajectory'] = data['trajectory_id']
else:
	data['trajectory'] = data.groupby(['C', 'u_par'], sort=True).ngroup()

display(data)
# Out:
#        u_par    C    t       V_t          I            Rx         u       ocv  \
# 10542   13.2  0.7    0  4.295441  -3.484751 -1.008673e+09  0.000019  4.324999
# 10543   13.2  0.7    2  4.279840  -3.484751 -1.008373e+09  0.000019  4.323816
# 10544   13.2  0.7    4  4.271748  -3.484751 -1.008073e+09  0.000019  4.322632
# 10545   13.2  0.7    6  4.265244  -3.484751 -1.007773e+09  0.000019  4.321447
# 10546   13.2  0.7    8  4.259728  -3.484751 -1.007474e+09  0.000019  4.320263
# ...      ...  ...  ...       ...        ...           ...       ...       ...
# 5905     7.8  4.9  560  2.774639 -24.393256 -8.372057e+06  0.000011  3.598965
# 5906     7.8  4.9  562  2.734914 -24.393256 -6.273263e+06  0.000011  3.596569
# 5907     7.8  4.9  564  2.691822 -24.393256 -4.174469e+06  0.000011  3.594173
# 5908     7.8  4.9  566  2.635744 -24.393256 -2.075675e+06  0.000011  3.591777
# 5909     7.8  4.9  568  2.547274 -24.393256  2.311904e+04  0.000011  3.589343
#
#        trajectory_id  trajectory
# 10542              0           0
# 10543              0           0
# 10544              0           0
# 10545              0           0
# 10546              0           0
# ...              ...         ...
# 5905              19          19
# 5906              19          19
# 5907              19          19
# 5908              19          19
# 5909              19          19
#
# [15406 rows x 10 columns]

# %%
# Add finite-difference columns with the same length as `data`
dV = np.diff(data['V_t'].to_numpy())
dRx = np.diff(data['Rx'].to_numpy())

if len(dV) > 0:
    dV = np.append(dV, dV[-1])
    dRx = np.append(dRx, dRx[-1])
else:
    dV = np.array([0.0])
    dRx = np.array([0.0])

data['dV_t'] = dV
data['dRx'] = dRx

data[['V_t', 'Rx', 'dV_t', 'dRx']].head()
# Out:
#             V_t            Rx      dV_t            dRx
# 10542  4.295441 -1.008673e+09 -0.015601  299527.458244
# 10543  4.279840 -1.008373e+09 -0.008093  299827.722061
# 10544  4.271748 -1.008073e+09 -0.006504  299827.722029
# 10545  4.265244 -1.007773e+09 -0.005516  299827.722010
# 10546  4.259728 -1.007474e+09 -0.004856  299827.722066

# %% [markdown]
# # Plotting data

# %%
plot_idx = data['trajectory'] == 2
f, ax = plt.subplots(1, 4, figsize=(15, 3))
ax[0].plot(data['V_t'][plot_idx], '-', color = colors[0], lw = 2)
ax[0].set_xlabel('Time step')
ax[0].set_ylabel('$V_{cell}$')
ax[1].plot(data['Rx'][plot_idx], lw = 2,color = colors[1])
ax[1].set_xlabel('Time step')
ax[1].set_ylabel('$F$')
ax[2].plot(data['I'][plot_idx], lw = 2,color = colors[2])
ax[2].set_xlabel('Time step')
ax[2].set_ylabel('$I$')
ax[3].plot(data['u'][plot_idx], lw = 2,color = colors[3])
ax[3].set_xlabel('Time step')
ax[3].set_ylabel(r'$\Delta u$')

plt.tight_layout()
plt.show()

# %%
# Correlation matrix for current signals in this batch

X = data[['V_t','I','Rx','u_par','ocv','dRx','dV_t']].values
feature_names = ['$V_t$','$I$','$R_x$',r'$\Delta u$','$E_{ocv}$',r'$\Delta R_x$',r'$\Delta V_t$']
with np.errstate(invalid="ignore", divide="ignore"):
    corr = np.corrcoef(X, rowvar=False)


fig, ax_corr = plt.subplots(figsize=(7, 5))
im = ax_corr.imshow(corr, cmap="coolwarm", vmin=-1, vmax=1)

ax_corr.set_xticks(np.arange(len(feature_names)))
ax_corr.set_yticks(np.arange(len(feature_names)))
ax_corr.set_xticklabels(feature_names, rotation=45, ha="right")
ax_corr.set_yticklabels(feature_names)
ax_corr.set_title("Correlation matrix")

for i in range(corr.shape[0]):
    for j in range(corr.shape[1]):
        ax_corr.text(j, i, f"{corr[i, j]:.2f}", ha="center", va="center", color="black")

fig.colorbar(im, ax=ax_corr, label="Correlation")
plt.tight_layout()
plt.show()

# %%
L_tot = 14.8e-5
traj = 0
plt.plot(data['u_par'][data['trajectory'] == traj]* L_tot / 100, data['Rx'][data['trajectory'] == traj], lw = 2, color = colors[0])
groups = data.groupby('u_par')['Rx']


first_rx = data.groupby('u_par')['Rx'].first()
k = -first_rx / (data.groupby('u_par')['u_par'].first() * L_tot / 100)

# %%
ds = data['Rx'][data['trajectory'] == traj] / k.values[0] + data['u_par'][data['trajectory'] == traj] * L_tot / 100

plt.plot(ds,data['Rx'][data['trajectory'] == traj], lw = 2, color = colors[1])
plt.xlabel('Swelling [m]')
plt.ylabel('$F$')
# Out:
# Text(0, 0.5, '$F$')

# %%
f, ax = plt.subplots(3,2,figsize=(6, 5))

ax[0,0].hist(np.unique(data['I']), bins=30, color=colors[0], alpha=0.5,edgecolor='black',density=True)
ax[0,1].hist(np.unique(data['u_par']) * L_tot / 100, bins=30, color=colors[1], alpha=0.5,edgecolor='black',density=True)
ax[1,0].hist(data['V_t'], bins=30, color=colors[2], alpha=0.5,edgecolor='black',density=True)
ax[1,1].hist(np.unique(data['Rx']), bins=30, color=colors[3], alpha=0.5,edgecolor='black',density=True)
ax[2,1].hist(data['dV_t'], bins=30, color=colors[4], alpha=0.5,edgecolor='black',density=True)
ax[2,0].hist((data['dRx']), bins=30, color=colors[5], alpha=0.5,edgecolor='black',density=True)
ax[0,0].set_xlabel('$I$')
ax[0,1].set_xlabel(r'$\Delta u$')
ax[1,0].set_xlabel('$V_t$')
ax[1,1].set_xlabel('$F$')
#ax[2,0].set_xlabel('$E_{ocv}$')
#ax[2,1].set_xlabel('$d$')
for a in ax.flat:
    a.set_yticklabels([])
plt.tight_layout()
plt.show()

# %% [markdown]
# # Normalizing data
#
# ### Characteristics that should be preserved after normalization?
#
#
# - $\Delta u$: It should primarily be compression, so have a negative sign.
#     - $\Delta u / L$ gives a fractional compression
# - $I$: The sign of it should reflect if we have charge/discharge
#     - Maybe just a `standard` normalization on this?
# - $V$: It should always be positive
#     - Maybe just a `min-max` normalization on this?
# - $F$: The sign of it should in some way reflect the sign of $\Delta u$. Especially in the cases with low swelling.
#     - Maybe just a `standard` normalization on this?

# %%
stats = {}

def compute_stats(x, name):
    if name == 'Rx':
        stats[name] = (np.mean(x), np.std(x))
    else:
        stats[name] = (np.min(x), np.max(x))
    return stats[name]
stats['I'] = compute_stats(data['I'], 'I')
stats['V_t'] = compute_stats(data['V_t'], 'V_t')
stats['u_par'] = compute_stats(data['u_par'], 'u_par')
stats['Rx'] = compute_stats(data['Rx'], 'Rx')
stats['dV_t'] = compute_stats(data['dV_t'], 'dV_t')
stats['dRx'] = compute_stats(data['dRx'], 'dRx')

def normalize(x, name, stats = stats):
    if name == 'Rx':
        return (x - stats[name][0]) / stats[name][1]
    else: 
        return (x - stats[name][0]) / (stats[name][1] - stats[name][0])

    
def denormalize(x, name, stats=stats):
    if name == 'Rx':
        return x * stats[name][1] + stats[name][0]
    else:   
        return x * (stats[name][1] - stats[name][0]) + stats[name][0]
    
data['I_norm'] = normalize(data['I'], 'I')
data['V_t_norm'] = normalize(data['V_t'], 'V_t')
data['u_par_norm'] = normalize(data['u_par'], 'u_par')
data['Rx_norm'] = normalize(data['Rx'], 'Rx')

f, ax = plt.subplots(3,2,figsize=(6, 6))
ax[0,0].hist(data['I_norm'], bins=30, color=colors[0], alpha=0.5,edgecolor='black',density=True)
ax[0,1].hist(data['u_par_norm'], bins=30, color=colors[1], alpha=0.5,edgecolor='black',density=True)    
ax[1,0].hist(data['V_t_norm'], bins=30, color=colors[2], alpha=0.5,edgecolor='black',density=True)
ax[1,1].hist(data['Rx_norm'], bins=30, color=colors[3], alpha=0.5,edgecolor='black',density=True)
ax[2,0].hist(data['dRx'], bins=30, color=colors[4], alpha=0.5,edgecolor='black',density=True)
ax[2,1].hist(data['dV_t'], bins=30, color=colors[5], alpha=0.5,edgecolor='black',density=True)
ax[0,0].set_xlabel('$I$ (normalized)')
ax[0,1].set_xlabel(r'$\Delta u$ (normalized)')
ax[1,0].set_xlabel('$V_t$ (normalized)')
ax[1,1].set_xlabel('$F$ (normalized)')
for a in ax.flat:
    a.set_yticklabels([])
plt.tight_layout()
plt.show()

# %% [markdown]
# # Splitting data
#
# - The targets $y_{k+1}$ have to be extracted
#     - Ensuring that the targets are within the same trajectory
#     - One can check by using a `valid = (traj_id[:-1] == traj_id[1:])`
# - Next, they have to matched such that each training-pair has the following form $$(y_{k+1})\sim(y_k,x_k)$$

# %%
N_trajs = len(data['trajectory'].unique())


test_inds = data['trajectory'] >= int(N_trajs * 0.8)

print(test_inds.sum(), 'test samples')

X = np.zeros((len(data) +1, 4))
y = np.zeros((len(data) + 1,2))
print(len(data[['V_t_norm']].values))
traj_len0 = 0

for traj_ids in range(0, N_trajs):
    print(f'{traj_ids} \t {traj_len0} \t {traj_len0 + len(data[data['trajectory'] == traj_ids])}')
    traj_len1 = traj_len0 + len(data[data['trajectory'] == traj_ids]) 
    X[traj_len0:traj_len1,...] = data[['V_t_norm','Rx_norm','I_norm','u_par_norm']][data['trajectory'] == traj_ids].values
    y[traj_len0:traj_len1 - 1,0] = np.diff(data['V_t'][data['trajectory'] == traj_ids].values)
    y[traj_len1,0] = np.diff(data['V_t'][data['trajectory'] == traj_ids].values)[-1]

    y[traj_len0:traj_len1-1,1] = np.diff(data['Rx'][data['trajectory'] == traj_ids].values)
    y[traj_len1,1] = np.diff(data['Rx'][data['trajectory'] == traj_ids].values)[-1]

    traj_len0 = traj_len1
y[:,0] = normalize(y[:,0], 'dV_t', stats)
y[:,1] = normalize(y[:,1], 'dRx', stats)
print(X.shape)
# Out:
# 1271 test samples
# 15406
# 0 	 0 	 1801
# 1 	 1801 	 3602
# 2 	 3602 	 5158
# 3 	 5158 	 6465
# 4 	 6465 	 7670
# 5 	 7670 	 8590
# 6 	 8590 	 9409
# 7 	 9409 	 10110
# 8 	 10110 	 10813
# 9 	 10813 	 11424
# 10 	 11424 	 11987
# 11 	 11987 	 12469
# 12 	 12469 	 12932
# 13 	 12932 	 13351
# 14 	 13351 	 13756
# 15 	 13756 	 14135
# 16 	 14135 	 14482
# 17 	 14482 	 14819
# 18 	 14819 	 15121
# 19 	 15121 	 15406
# (15407, 4)

# %%
plt.plot(np.linspace(0,3600,len(data['V_t_norm'][data['trajectory'] == 19])-1),np.diff(data['Rx_norm'][data['trajectory'] == 19]), '-', color = colors[0], lw = 2, label='True')
plt.plot(np.linspace(0,3600,len(data['V_t_norm'][data['trajectory'] == 19])),y[15121:15406,1],color = colors[1], lw = 2, label='Diff')

# %%
print(f"Number of trajectories: {N_trajs}")
# Out:
# Number of trajectories: 20

# %%
#valid = (traj_id[:-1] == traj_id[1:])
#idx = torch.where(valid)[0]


x_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32)

split = (data['trajectory']< int(N_trajs *0.8)).sum()

def _split_flat(arr, split = split):
    return arr[:split], arr[split:]   # Same as reshape(B * T, C)    # (B*T, 4)

x_train, x_test = _split_flat(x_tensor); y_train, y_test = _split_flat(y_tensor)

print(f'X shape {x_tensor.shape}\ty shape {y_tensor.shape}\nX-train shape: {x_train.shape}\ty-train shape: {y_train.shape}\nX-test shape: {x_test.shape}\ty-test shape: {y_test.shape}')



train_loader_flat = DataLoader(TensorDataset(x_train, y_train), batch_size=int(len(data) / 8) , shuffle=True)
# Out:
# X shape torch.Size([15407, 4])	y shape torch.Size([15407, 2])
# X-train shape: torch.Size([14135, 4])	y-train shape: torch.Size([14135, 2])
# X-test shape: torch.Size([1272, 4])	y-test shape: torch.Size([1272, 2])

# %% [markdown]
# # Defining model
#
# Inputs: $I_t$, $\Delta u_t$, $V_t$, $F_t$
#
# Outputs $\dot{V}_t$, $\dot{F}_t$
#
# Employing a NODE setup, with the state variable $\xi = [V,F]$, we get $$\dot{\xi}=f_{NN}(I_t,\Delta u_t,\xi)\Rightarrow \xi(t) = \int_0^tf_{NN}(I_t,\Delta u_t,\xi)\,\mathrm{d}t$$

# %%
''' Mk 1 '''
class Net(nn.Module):
    def __init__(self, input_size=4, hidden_size=256): 
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 2)   # output size is 2 for (V_cell, F)
        )
    
    # def forward(self, x):
    #     x = self.net(x)
    #     return x
    def forward(self, input, PE = False):
        if PE:
            pass
        else:
            return self.net(input)
    
model = Net()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
summary(model, input_data=x_train[:2])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Net                                      [2, 2]                    --
# ├─Sequential: 1-1                        [2, 2]                    --
# │    └─Linear: 2-1                       [2, 256]                  1,280
# │    └─ReLU: 2-2                         [2, 256]                  --
# │    └─Linear: 2-3                       [2, 256]                  65,792
# │    └─ReLU: 2-4                         [2, 256]                  --
# │    └─Linear: 2-5                       [2, 2]                    514
# ==========================================================================================
# Total params: 67,586
# Trainable params: 67,586
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.14
# ==========================================================================================
# Input size (MB): 0.25
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.27
# Estimated Total Size (MB): 0.53
# ==========================================================================================

# %% [markdown]
# # Training
# Since we only have values for $V_t$ and $F_t$, we need to add a torch-compatible integrator within the training procedure. For starters, we use the simple Euler forward, yielding the following loss $$\mathcal{L} = \|\xi_t-f_{NN}(x_t)\Delta t\|^2_2\quad x_t = [I_t,\Delta u_t].$$
# After training, the model could in principle be used in your favorite integrator.

# %%
def next_step(dy,X, dt = 2, stats = stats):
    y = X[:,:2]
    V = denormalize(y[:,0], 'V_t', stats)

    F = denormalize(y[:,1], 'Rx', stats)
    V1 = V + dy[:,0] * dt
    F1 = F + dy[:,1] * dt
    y1 = torch.zeros_like(y)
    y1[:,0] = normalize(V1, 'V_t',stats)
    y1[:,1] = normalize(F1, 'Rx',stats)
    y1 = dy * dt + y
    return y1


    

def training(epochs=30, PE = True):
    history = {"loss": [], "d_loss": [], "p_loss": [], "time per ep": []}
    for ep in range(epochs):
        model.train()
        tot_ep_loss = 0.0
        d_ep_loss = 0.0
        start_t = time.perf_counter()
        for x_b, y_b in train_loader_flat:
            # print('batch shapes:', x_b.shape, y_b.shape, mask_b.shape)
            dy = model(x_b, PE=PE) 
            #y_pred = next_step(dy,x_b)

            d_loss = nn.MSELoss()(dy, y_b)
            tot_loss = d_loss
            # print('pred shapes:', pred.shape)
            optimizer.zero_grad()
            tot_loss.backward()
            optimizer.step()
            tot_ep_loss += d_loss.item()
            d_ep_loss += d_loss.item()
        tot_last = tot_ep_loss / len(train_loader_flat)  # Average loss per batch
        d_last = d_ep_loss / len(train_loader_flat)
        end_t = time.perf_counter()

        history["loss"].append(tot_last)
        history["d_loss"].append(d_last)
        history["time per ep"].append(end_t - start_t)
        if ep == 0:
            print(f'ETA: {(end_t - start_t) * epochs / 60:.2f} min')
        print(f"Epoch {ep+1} | loss {tot_last:.3e} | time {end_t - start_t:.2f}s")

    return history

# %%
history = training(epochs=150, PE=False)
# Out:
# ETA: 0.60 min
# Epoch 1 | loss 5.123e-02 | time 0.14s
# Epoch 2 | loss 8.310e-03 | time 0.08s
# Epoch 3 | loss 3.453e-03 | time 0.08s
# Epoch 4 | loss 1.989e-03 | time 0.08s
# Epoch 5 | loss 8.713e-04 | time 0.09s
# Epoch 6 | loss 4.134e-04 | time 0.09s
# Epoch 7 | loss 2.073e-04 | time 0.08s
# Epoch 8 | loss 1.130e-04 | time 0.08s
# Epoch 9 | loss 6.648e-05 | time 0.08s
# Epoch 10 | loss 4.261e-05 | time 0.33s
# Epoch 11 | loss 3.155e-05 | time 0.09s
# Epoch 12 | loss 2.476e-05 | time 0.08s
# Epoch 13 | loss 2.045e-05 | time 0.08s
# Epoch 14 | loss 1.784e-05 | time 0.08s
# Epoch 15 | loss 1.590e-05 | time 0.08s
# Epoch 16 | loss 1.455e-05 | time 0.08s
# Epoch 17 | loss 1.317e-05 | time 0.15s
# Epoch 18 | loss 1.208e-05 | time 0.08s
# Epoch 19 | loss 1.117e-05 | time 0.08s
# Epoch 20 | loss 1.036e-05 | time 0.08s
# Epoch 21 | loss 9.885e-06 | time 0.08s
# Epoch 22 | loss 9.159e-06 | time 0.23s
# Epoch 23 | loss 8.729e-06 | time 0.09s
# Epoch 24 | loss 8.171e-06 | time 0.09s
# Epoch 25 | loss 7.765e-06 | time 0.09s
# Epoch 26 | loss 7.384e-06 | time 0.08s
# Epoch 27 | loss 7.000e-06 | time 0.08s
# Epoch 28 | loss 6.618e-06 | time 0.08s
# Epoch 29 | loss 6.320e-06 | time 0.08s
# Epoch 30 | loss 6.087e-06 | time 0.08s
# Epoch 31 | loss 5.761e-06 | time 0.08s
# Epoch 32 | loss 5.399e-06 | time 0.23s
# Epoch 33 | loss 5.200e-06 | time 0.08s
# Epoch 34 | loss 5.162e-06 | time 0.07s
# Epoch 35 | loss 4.902e-06 | time 0.08s
# Epoch 36 | loss 4.750e-06 | time 0.07s
# Epoch 37 | loss 4.538e-06 | time 0.07s
# Epoch 38 | loss 4.463e-06 | time 0.07s
# Epoch 39 | loss 4.295e-06 | time 0.08s
# Epoch 40 | loss 4.184e-06 | time 0.08s
# Epoch 41 | loss 4.028e-06 | time 0.08s
# Epoch 42 | loss 3.843e-06 | time 0.08s
# Epoch 43 | loss 3.765e-06 | time 0.08s
# Epoch 44 | loss 3.643e-06 | time 0.08s
# Epoch 45 | loss 3.478e-06 | time 0.08s
# Epoch 46 | loss 3.316e-06 | time 0.23s
# Epoch 47 | loss 3.133e-06 | time 0.08s
# Epoch 48 | loss 3.105e-06 | time 0.08s
# Epoch 49 | loss 2.946e-06 | time 0.08s
# Epoch 50 | loss 2.708e-06 | time 0.08s
# Epoch 51 | loss 2.583e-06 | time 0.08s
# Epoch 52 | loss 2.492e-06 | time 0.08s
# Epoch 53 | loss 2.394e-06 | time 0.08s
# Epoch 54 | loss 2.369e-06 | time 0.08s
# Epoch 55 | loss 2.342e-06 | time 0.08s
# Epoch 56 | loss 2.223e-06 | time 0.08s
# Epoch 57 | loss 2.138e-06 | time 0.08s
# Epoch 58 | loss 2.247e-06 | time 0.23s
# Epoch 59 | loss 2.151e-06 | time 0.08s
# Epoch 60 | loss 2.304e-06 | time 0.08s
# Epoch 61 | loss 1.989e-06 | time 0.08s
# Epoch 62 | loss 2.162e-06 | time 0.08s
# Epoch 63 | loss 1.997e-06 | time 0.08s
# Epoch 64 | loss 1.991e-06 | time 0.08s
# Epoch 65 | loss 1.950e-06 | time 0.08s
# Epoch 66 | loss 1.920e-06 | time 0.23s
# Epoch 67 | loss 1.805e-06 | time 0.08s
# Epoch 68 | loss 1.812e-06 | time 0.08s
# Epoch 69 | loss 1.757e-06 | time 0.08s
# Epoch 70 | loss 1.799e-06 | time 0.08s
# Epoch 71 | loss 1.742e-06 | time 0.08s
# Epoch 72 | loss 1.734e-06 | time 0.08s
# Epoch 73 | loss 1.669e-06 | time 0.08s
# Epoch 74 | loss 1.662e-06 | time 0.08s
# Epoch 75 | loss 1.648e-06 | time 0.08s
# Epoch 76 | loss 1.717e-06 | time 0.08s
# Epoch 77 | loss 1.675e-06 | time 0.08s
# Epoch 78 | loss 1.633e-06 | time 0.08s
# Epoch 79 | loss 1.615e-06 | time 0.08s
# Epoch 80 | loss 1.623e-06 | time 0.08s
# Epoch 81 | loss 1.630e-06 | time 0.23s
# Epoch 82 | loss 1.619e-06 | time 0.08s
# Epoch 83 | loss 1.686e-06 | time 0.08s
# Epoch 84 | loss 1.621e-06 | time 0.08s
# Epoch 85 | loss 1.631e-06 | time 0.08s
# Epoch 86 | loss 1.562e-06 | time 0.08s
# Epoch 87 | loss 1.513e-06 | time 0.09s
# Epoch 88 | loss 1.435e-06 | time 0.08s
# Epoch 89 | loss 1.439e-06 | time 0.08s
# Epoch 90 | loss 1.461e-06 | time 0.09s
# Epoch 91 | loss 1.464e-06 | time 0.09s
# Epoch 92 | loss 1.397e-06 | time 0.08s
# Epoch 93 | loss 1.537e-06 | time 0.23s
# Epoch 94 | loss 1.425e-06 | time 0.08s
# Epoch 95 | loss 1.383e-06 | time 0.08s
# Epoch 96 | loss 1.362e-06 | time 0.15s
# Epoch 97 | loss 1.545e-06 | time 0.10s
# Epoch 98 | loss 1.467e-06 | time 0.10s
# Epoch 99 | loss 1.381e-06 | time 0.10s
# Epoch 100 | loss 1.394e-06 | time 0.12s
# Epoch 101 | loss 1.461e-06 | time 0.11s
# Epoch 102 | loss 1.344e-06 | time 0.09s
# Epoch 103 | loss 1.338e-06 | time 0.25s
# Epoch 104 | loss 1.374e-06 | time 0.08s
# Epoch 105 | loss 1.318e-06 | time 0.08s
# Epoch 106 | loss 1.276e-06 | time 0.08s
# Epoch 107 | loss 1.320e-06 | time 0.08s
# Epoch 108 | loss 1.272e-06 | time 0.08s
# Epoch 109 | loss 1.263e-06 | time 0.08s
# Epoch 110 | loss 1.309e-06 | time 0.08s
# Epoch 111 | loss 1.317e-06 | time 0.08s
# Epoch 112 | loss 1.235e-06 | time 0.08s
# Epoch 113 | loss 1.308e-06 | time 0.08s
# Epoch 114 | loss 1.206e-06 | time 0.08s
# Epoch 115 | loss 1.297e-06 | time 0.08s
# Epoch 116 | loss 1.246e-06 | time 0.08s
# Epoch 117 | loss 1.243e-06 | time 0.23s
# Epoch 118 | loss 1.194e-06 | time 0.08s
# Epoch 119 | loss 1.229e-06 | time 0.08s
# Epoch 120 | loss 1.221e-06 | time 0.08s
# Epoch 121 | loss 1.223e-06 | time 0.08s
# Epoch 122 | loss 1.174e-06 | time 0.08s
# Epoch 123 | loss 1.235e-06 | time 0.08s
# Epoch 124 | loss 1.162e-06 | time 0.08s
# Epoch 125 | loss 1.226e-06 | time 0.14s
# Epoch 126 | loss 1.222e-06 | time 0.08s
# Epoch 127 | loss 1.341e-06 | time 0.08s
# Epoch 128 | loss 1.189e-06 | time 0.08s
# Epoch 129 | loss 1.243e-06 | time 0.23s
# Epoch 130 | loss 1.156e-06 | time 0.08s
# Epoch 131 | loss 1.178e-06 | time 0.08s
# Epoch 132 | loss 1.201e-06 | time 0.08s
# Epoch 133 | loss 1.193e-06 | time 0.08s
# Epoch 134 | loss 1.213e-06 | time 0.08s
# Epoch 135 | loss 1.085e-06 | time 0.08s
# Epoch 136 | loss 1.174e-06 | time 0.09s
# Epoch 137 | loss 1.155e-06 | time 0.25s
# Epoch 138 | loss 1.130e-06 | time 0.08s
# Epoch 139 | loss 1.153e-06 | time 0.08s
# Epoch 140 | loss 1.146e-06 | time 0.08s
# Epoch 141 | loss 1.259e-06 | time 0.08s
# Epoch 142 | loss 1.097e-06 | time 0.08s
# Epoch 143 | loss 1.090e-06 | time 0.08s
# Epoch 144 | loss 1.142e-06 | time 0.08s
# Epoch 145 | loss 1.072e-06 | time 0.08s
# Epoch 146 | loss 1.145e-06 | time 0.08s
# Epoch 147 | loss 1.058e-06 | time 0.08s
# Epoch 148 | loss 1.072e-06 | time 0.08s
# Epoch 149 | loss 1.217e-06 | time 0.08s
# Epoch 150 | loss 1.102e-06 | time 0.08s
# Epoch 151 | loss 1.143e-06 | time 0.08s
# Epoch 152 | loss 1.150e-06 | time 0.23s
# Epoch 153 | loss 1.133e-06 | time 0.08s
# Epoch 154 | loss 1.049e-06 | time 0.08s
# Epoch 155 | loss 1.099e-06 | time 0.08s
# Epoch 156 | loss 1.077e-06 | time 0.07s
# Epoch 157 | loss 1.089e-06 | time 0.08s
# Epoch 158 | loss 1.088e-06 | time 0.07s
# Epoch 159 | loss 1.026e-06 | time 0.07s
# Epoch 160 | loss 1.165e-06 | time 0.07s
# Epoch 161 | loss 1.058e-06 | time 0.07s
# Epoch 162 | loss 1.061e-06 | time 0.08s
# Epoch 163 | loss 1.008e-06 | time 0.07s
# Epoch 164 | loss 1.045e-06 | time 0.23s
# Epoch 165 | loss 1.057e-06 | time 0.08s
# Epoch 166 | loss 1.060e-06 | time 0.08s
# Epoch 167 | loss 1.051e-06 | time 0.08s
# Epoch 168 | loss 1.047e-06 | time 0.08s
# Epoch 169 | loss 9.929e-07 | time 0.08s
# Epoch 170 | loss 1.038e-06 | time 0.08s
# Epoch 171 | loss 9.866e-07 | time 0.08s
# Epoch 172 | loss 1.072e-06 | time 0.08s
# Epoch 173 | loss 1.014e-06 | time 0.08s
# Epoch 174 | loss 1.005e-06 | time 0.23s
# Epoch 175 | loss 9.882e-07 | time 0.08s
# Epoch 176 | loss 1.007e-06 | time 0.08s
# Epoch 177 | loss 1.041e-06 | time 0.08s
# Epoch 178 | loss 1.030e-06 | time 0.08s
# Epoch 179 | loss 1.036e-06 | time 0.08s
# Epoch 180 | loss 1.009e-06 | time 0.08s
# Epoch 181 | loss 1.054e-06 | time 0.08s
# Epoch 182 | loss 1.007e-06 | time 0.08s
# Epoch 183 | loss 1.003e-06 | time 0.08s
# Epoch 184 | loss 1.052e-06 | time 0.08s
# Epoch 185 | loss 9.798e-07 | time 0.08s
# Epoch 186 | loss 1.076e-06 | time 0.08s
# Epoch 187 | loss 9.690e-07 | time 0.08s
# Epoch 188 | loss 9.900e-07 | time 0.23s
# Epoch 189 | loss 9.582e-07 | time 0.08s
# Epoch 190 | loss 9.853e-07 | time 0.08s
# Epoch 191 | loss 1.112e-06 | time 0.08s
# Epoch 192 | loss 9.603e-07 | time 0.08s
# Epoch 193 | loss 1.072e-06 | time 0.08s
# Epoch 194 | loss 9.536e-07 | time 0.08s
# Epoch 195 | loss 9.507e-07 | time 0.08s
# Epoch 196 | loss 1.005e-06 | time 0.08s
# Epoch 197 | loss 1.045e-06 | time 0.08s
# Epoch 198 | loss 9.917e-07 | time 0.08s
# Epoch 199 | loss 9.692e-07 | time 0.08s
# Epoch 200 | loss 9.686e-07 | time 0.23s
# Epoch 201 | loss 9.933e-07 | time 0.08s
# Epoch 202 | loss 9.969e-07 | time 0.08s
# Epoch 203 | loss 9.921e-07 | time 0.08s
# Epoch 204 | loss 1.065e-06 | time 0.08s
# Epoch 205 | loss 9.204e-07 | time 0.08s
# Epoch 206 | loss 9.901e-07 | time 0.08s
# Epoch 207 | loss 9.755e-07 | time 0.09s
# Epoch 208 | loss 9.668e-07 | time 0.24s
# Epoch 209 | loss 9.763e-07 | time 0.08s
# Epoch 210 | loss 9.613e-07 | time 0.08s
# Epoch 211 | loss 1.007e-06 | time 0.08s
# Epoch 212 | loss 9.826e-07 | time 0.08s
# Epoch 213 | loss 1.043e-06 | time 0.08s
# Epoch 214 | loss 9.734e-07 | time 0.08s
# Epoch 215 | loss 1.005e-06 | time 0.08s
# Epoch 216 | loss 9.689e-07 | time 0.08s
# Epoch 217 | loss 9.257e-07 | time 0.08s
# Epoch 218 | loss 9.992e-07 | time 0.08s
# Epoch 219 | loss 1.031e-06 | time 0.08s
# Epoch 220 | loss 9.467e-07 | time 0.08s
# Epoch 221 | loss 9.890e-07 | time 0.08s
# Epoch 222 | loss 9.027e-07 | time 0.08s
# Epoch 223 | loss 8.814e-07 | time 0.23s
# Epoch 224 | loss 9.107e-07 | time 0.08s
# Epoch 225 | loss 9.467e-07 | time 0.08s
# Epoch 226 | loss 9.358e-07 | time 0.08s
# Epoch 227 | loss 9.960e-07 | time 0.08s
# Epoch 228 | loss 9.467e-07 | time 0.08s
# Epoch 229 | loss 8.869e-07 | time 0.08s
# Epoch 230 | loss 8.958e-07 | time 0.08s
# Epoch 231 | loss 8.919e-07 | time 0.07s
# Epoch 232 | loss 9.214e-07 | time 0.07s
# Epoch 233 | loss 9.002e-07 | time 0.07s
# Epoch 234 | loss 1.018e-06 | time 0.07s
# Epoch 235 | loss 8.555e-07 | time 0.23s
# Epoch 236 | loss 8.813e-07 | time 0.08s
# Epoch 237 | loss 9.056e-07 | time 0.08s
# Epoch 238 | loss 9.092e-07 | time 0.08s
# Epoch 239 | loss 8.958e-07 | time 0.08s
# Epoch 240 | loss 9.403e-07 | time 0.08s
# Epoch 241 | loss 8.648e-07 | time 0.08s
# Epoch 242 | loss 8.954e-07 | time 0.08s
# Epoch 243 | loss 8.817e-07 | time 0.08s
# Epoch 244 | loss 9.829e-07 | time 0.08s
# Epoch 245 | loss 9.417e-07 | time 0.23s
# Epoch 246 | loss 9.564e-07 | time 0.08s
# Epoch 247 | loss 9.520e-07 | time 0.08s
# Epoch 248 | loss 9.245e-07 | time 0.08s
# Epoch 249 | loss 9.089e-07 | time 0.08s
# Epoch 250 | loss 8.709e-07 | time 0.08s

# %%
#model_name = 'Second_PENN_ReLU'
#PENN_exp_log.exp_log(model, history, current = currents,name=model_name, d_loss_type = 'mse')
#torch.save(model.state_dict(), f'models/{model_name}_{currents}.pth')
print(history['loss'][-1])
fig, (ax1) = plt.subplots(1, 1, figsize=(4, 3))
ax1.semilogy(history["loss"], label="Train loss")
# ax1.set_yscale("log")
ax1.set_xlabel("epoch")
ax1.set_ylabel("MSE")
ax1.legend()
# Out:
# 8.708826015890736e-07

# %%
from scipy.interpolate import interp1d

def denorm_y(y, stats=stats):
    V = denormalize(y[:,0], 'V_t', stats)
    F = denormalize(y[:,1], 'Rx', stats)
    return np.stack([V, F], axis=1)

def rollout(model, x_init, steps=100, PE=False):
    traj = np.zeros((steps, 2))
    traj_dy = np.zeros((steps, 2))
    x = x_init.clone()
    traj[0] = x[0, :2].numpy()
    model.eval()
    for t in range(1,steps):
        with torch.no_grad():
            dy = model(x, PE=PE)
            x[:, :2] += dy
            traj[t] = x[0, :2].numpy()
            traj_dy[t] = dy[0].numpy()
    return traj,traj_dy

traj,traj_dy = rollout(model, x_test[:1], steps=100, PE=False)
plt.plot(traj_dy[:,0], label='Predicted dV', color=colors[0])

# %%
#plt.plot(data['V_t'][data['trajectory'] == 16], '-', color = colors[0], lw = 2)

x_init = data[['V_t_norm','Rx_norm','I_norm','u_par_norm']][data['trajectory'] == 17].values[0]

def rollout(model, x_init, steps=1000, PE=False, dt = 2):
    traj = np.zeros((steps, 2))
    X = torch.tensor(x_init, dtype=torch.float32)
    y0 = X[:2].numpy()
    traj[0] = y0
    for t in range(1, steps):
        with torch.no_grad():
            dy = model(X, PE=PE)
            y1 = dy * dt + X[:2]
            X = torch.cat([y1, X[2:]], dim=-1)             
            traj[t] = y1.numpy()
    return traj

traj_pred = rollout(model, x_init, steps=400, PE=False)
print(denorm_y(traj_pred))
# Out:
# [[ 4.15614823e+00 -2.26951124e+09]
#  [ 4.48215851e+00 -1.37119744e+09]
#  [ 4.80904292e+00 -3.52979777e+08]
#  [ 5.17515268e+00  7.97759379e+08]
#  [ 5.66794185e+00  2.13687884e+09]
#  [ 6.18208053e+00  3.73344583e+09]
#  [ 6.81373423e+00  5.70588452e+09]
#  [ 7.66612524e+00  8.17286197e+09]
#  [ 8.83223314e+00  1.12822076e+10]
#  [ 1.03926699e+01  1.52031635e+10]
#  [ 1.24321611e+01  2.01552189e+10]
#  [ 1.54190296e+01  2.64198244e+10]
#  [ 1.92204178e+01  3.43385714e+10]
#  [ 2.40285338e+01  4.43480520e+10]
#  [ 3.01113260e+01  5.70017975e+10]
#  [ 3.78015883e+01  7.29983331e+10]
#  [ 4.75234741e+01  9.32207251e+10]
#  [ 5.98136232e+01  1.18785339e+11]
#  [ 7.53505152e+01  1.51103443e+11]
#  [ 9.49918398e+01  1.91959139e+11]
#  [ 1.19821879e+02  2.43607815e+11]
#  [ 1.51211348e+02  3.08900708e+11]
#  [ 1.90893105e+02  3.91442229e+11]
#  [ 2.41057730e+02  4.95789044e+11]
#  [ 3.04474488e+02  6.27701525e+11]
#  [ 3.84644285e+02  7.94461767e+11]
#  [ 4.85992781e+02  1.00527571e+12]
#  [ 6.14114991e+02  1.27178103e+12]
#  [ 7.76083454e+02  1.60868997e+12]
#  [ 9.80839848e+02  2.03460139e+12]
#  [ 1.23968752e+03  2.57302737e+12]
#  [ 1.56691565e+03  3.25369106e+12]
#  [ 1.98058881e+03  4.11416818e+12]
#  [ 2.50354372e+03  5.20196035e+12]
#  [ 3.16464902e+03  6.57711850e+12]
#  [ 4.00040095e+03  8.31555695e+12]
#  [ 5.05693788e+03  1.05132448e+13]
#  [ 6.39258185e+03  1.32915029e+13]
#  [ 8.08106845e+03  1.68037035e+13]
#  [ 1.02156087e+04  2.12437347e+13]
#  [ 1.29140358e+04  2.68567043e+13]
#  [ 1.63253176e+04  3.39524740e+13]
#  [ 2.06377688e+04  4.29227555e+13]
#  [ 2.60894575e+04  5.42627465e+13]
#  [ 3.29813342e+04  6.85984648e+13]
#  [ 4.16938686e+04  8.67212979e+13]
#  [ 5.27080162e+04  1.09631699e+14]
#  [ 6.66318103e+04  1.38594420e+14]
#  [ 8.42339019e+04  1.75208332e+14]
#  [ 1.06486008e+05  2.21494667e+14]
#  [ 1.34616507e+05  2.80008615e+14]
#  [ 1.70178345e+05  3.53980424e+14]
#  [ 2.15134692e+05  4.47493592e+14]
#  [ 2.71967338e+05  5.65710460e+14]
#  [ 3.43813663e+05  7.15157122e+14]
#  [ 4.34639831e+05  9.04083572e+14]
#  [ 5.49459797e+05  1.14291942e+15]
#  [ 6.94612245e+05  1.44484932e+15]
#  [ 8.78110065e+05  1.82654101e+15]
#  [ 1.11008326e+06  2.30906560e+15]
#  [ 1.40333748e+06  2.91906037e+15]
#  [ 1.77406177e+06  3.69019950e+15]
#  [ 2.24272131e+06  4.66505351e+15]
#  [ 2.83518884e+06  5.89743761e+15]
#  [ 3.58416983e+06  7.45538500e+15]
#  [ 4.53101258e+06  9.42490142e+15]
#  [ 5.72798570e+06  1.19147114e+16]
#  [ 7.24116716e+06  1.50622624e+16]
#  [ 9.15409037e+06  1.90413136e+16]
#  [ 1.15723584e+07  2.40715251e+16]
#  [ 1.46294686e+07  3.04305837e+16]
#  [ 1.84941849e+07  3.84695393e+16]
#  [ 2.33798578e+07  4.86321747e+16]
#  [ 2.95561991e+07  6.14795041e+16]
#  [ 3.73641622e+07  7.77207600e+16]
#  [ 4.72347880e+07  9.82525255e+16]
#  [ 5.97129652e+07  1.24208239e+17]
#  [ 7.54875380e+07  1.57020771e+17]
#  [ 9.54293462e+07  1.98501495e+17]
#  [ 1.20639258e+08  2.50940333e+17]
#  [ 1.52508962e+08  3.17232122e+17]
#  [ 1.92797763e+08  4.01036451e+17]
#  [ 2.43729854e+08  5.06979644e+17]
#  [ 3.08116799e+08  6.40910252e+17]
#  [ 3.89513101e+08  8.10221745e+17]
#  [ 4.92412152e+08  1.02426081e+18]
#  [ 6.22494365e+08  1.29484334e+18]
#  [ 7.86940843e+08  1.63690658e+18]
#  [ 9.94829794e+08  2.06933387e+18]
#  [ 1.25763717e+09  2.61599691e+18]
#  [ 1.58987183e+09  3.30707391e+18]
#  [ 2.00987377e+09  4.18071514e+18]
#  [ 2.54082932e+09  5.28514930e+18]
#  [ 3.21204868e+09  6.68134542e+18]
#  [ 4.06058659e+09  8.44637983e+18]
#  [ 5.13328623e+09  1.06776899e+19]
#  [ 6.48936435e+09  1.34984520e+19]
#  [ 8.20368261e+09  1.70643848e+19]
#  [ 1.03708780e+10  2.15723438e+19]
#  [ 1.31105887e+10  2.72711858e+19]
#  [ 1.65740588e+10  3.44755108e+19]
#  [ 2.09524857e+10  4.35830252e+19]
#  [ 2.64875772e+10  5.50965040e+19]
#  [ 3.34848925e+10  6.96515406e+19]
#  [ 4.23307126e+10  8.80516333e+19]
#  [ 5.35133703e+10  1.11312543e+20]
#  [ 6.76501817e+10  1.40718358e+20]
#  [ 8.55215667e+10  1.77892414e+20]
#  [ 1.08114093e+11  2.24886871e+20]
#  [ 1.36674964e+11  2.84296014e+20]
#  [ 1.72780863e+11  3.59399481e+20]
#  [ 2.18424987e+11  4.54343319e+20]
#  [ 2.76127095e+11  5.74368815e+20]
#  [ 3.49072594e+11  7.26101826e+20]
#  [ 4.41288284e+11  9.17918689e+20]
#  [ 5.57864970e+11  1.16040847e+21]
#  [ 7.05238120e+11  1.46695764e+21]
#  [ 8.91543245e+11  1.85448904e+21]
#  [ 1.12706555e+12  2.34439582e+21]
#  [ 1.42480617e+12  2.96372298e+21]
#  [ 1.80120227e+12  3.74666005e+21]
#  [ 2.27703220e+12  4.73642834e+21]
#  [ 2.87856366e+12  5.98766745e+21]
#  [ 3.63900401e+12  7.56945052e+21]
#  [ 4.60033253e+12  9.56909862e+21]
#  [ 5.81561856e+12  1.20970015e+22]
#  [ 7.35195105e+12  1.52927076e+22]
#  [ 9.29414039e+12  1.93326351e+22]
#  [ 1.17494060e+13  2.44398057e+22]
#  [ 1.48532896e+13  3.08961535e+22]
#  [ 1.87771342e+13  3.90580963e+22]
#  [ 2.37375532e+13  4.93762072e+22]
#  [ 3.00083838e+13  6.24200907e+22]
#  [ 3.79358011e+13  7.89098248e+22]
#  [ 4.79574329e+13  9.97557110e+22]
#  [ 6.06265222e+13  1.26108521e+23]
#  [ 7.66424430e+13  1.59423055e+23]
#  [ 9.68893303e+13  2.01538406e+23]
#  [ 1.22484935e+14  2.54779515e+23]
#  [ 1.54842216e+14  3.22085517e+23]
#  [ 1.95747426e+14  4.07171967e+23]
#  [ 2.47458691e+14  5.14736016e+23]
#  [ 3.12830752e+14  6.50715632e+23]
#  [ 3.95472349e+14  8.22617433e+23]
#  [ 4.99945635e+14  1.03993116e+24]
#  [ 6.32017988e+14  1.31465338e+24]
#  [ 7.98980352e+14  1.66194987e+24]
#  [ 1.01004978e+15  2.10099291e+24]
#  [ 1.27687820e+15  2.65601957e+24]
#  [ 1.61419543e+15  3.35766940e+24]
#  [ 2.04062309e+15  4.24467667e+24]
#  [ 2.57970175e+15  5.36600764e+24]
#  [ 3.26119030e+15  6.78356458e+24]
#  [ 4.12271044e+15  8.57560238e+24]
#  [ 5.21182071e+15  1.08410489e+25]
#  [ 6.58864629e+15  1.37049668e+25]
#  [ 8.32919172e+15  1.73254564e+25]
#  [ 1.05295436e+16  2.19023817e+25]
#  [ 1.33111691e+16  2.76884097e+25]
#  [ 1.68276255e+16  3.50029547e+25]
#  [ 2.12730395e+16  4.42498072e+25]
#  [ 2.68928153e+16  5.59394315e+25]
#  [ 3.39971822e+16  7.07171464e+25]
#  [ 4.29783345e+16  8.93987417e+25]
#  [ 5.43320748e+16  1.13015523e+26]
#  [ 6.86851627e+16  1.42871234e+26]
#  [ 8.68299741e+16  1.80614025e+26]
#  [ 1.09768161e+17  2.28327467e+26]
#  [ 1.38765996e+17  2.88645519e+26]
#  [ 1.75424281e+17  3.64898010e+26]
#  [ 2.21766708e+17  4.61294397e+26]
#  [ 2.80351599e+17  5.83156121e+26]
#  [ 3.54413010e+17  7.37210523e+26]
#  [ 4.48039587e+17  9.31961982e+26]
#  [ 5.66399783e+17  1.17816167e+27]
#  [ 7.16027555e+17  1.48940070e+27]
#  [ 9.05183125e+17  1.88286090e+27]
#  [ 1.14430849e+18  2.38026294e+27]
#  [ 1.44660453e+18  3.00906535e+27]
#  [ 1.82875898e+18  3.80398049e+27]
#  [ 2.31186862e+18  4.80889137e+27]
#  [ 2.92260305e+18  6.07927268e+27]
#  [ 3.69467737e+18  7.68525540e+27]
#  [ 4.67071294e+18  9.71549598e+27]
#  [ 5.90459132e+18  1.22820723e+28]
#  [ 7.46442794e+18  1.55266701e+28]
#  [ 9.43633181e+18  1.96284051e+28]
#  [ 1.19291605e+19  2.48137096e+28]
#  [ 1.50805283e+19  3.13688349e+28]
#  [ 1.90644061e+19  3.96556485e+28]
#  [ 2.41007153e+19  5.01316189e+28]
#  [ 3.04674833e+19  6.33750656e+28]
#  [ 3.85161885e+19  8.01170802e+28]
#  [ 4.86911436e+19  1.01281883e+29]
#  [ 6.15540533e+19  1.28037877e+29]
#  [ 7.78150069e+19  1.61862095e+29]
#  [ 9.83716739e+19  2.04621775e+29]
#  [ 1.24358858e+20  2.58677438e+29]
#  [ 1.57211166e+20  3.27013148e+29]
#  [ 1.98742198e+20  4.13401334e+29]
#  [ 2.51244598e+20  5.22611009e+29]
#  [ 3.17616732e+20  6.60671013e+29]
#  [ 4.01522730e+20  8.35202810e+29]
#  [ 5.07594407e+20  1.05584124e+30]
#  [ 6.41687416e+20  1.33476648e+30]
#  [ 8.11204158e+20  1.68737638e+30]
#  [ 1.02550282e+21  2.13313653e+30]
#  [ 1.29641332e+21  2.69665455e+30]
#  [ 1.63889128e+21  3.40903905e+30]
#  [ 2.07184290e+21  4.30961656e+30]
#  [ 2.61916919e+21  5.44810297e+30]
#  [ 3.31108349e+21  6.88734699e+30]
#  [ 4.18578403e+21  8.70680152e+30]
#  [ 5.29155739e+21  1.10069072e+31]
#  [ 6.68944656e+21  1.39146396e+31]
#  [ 8.45662017e+21  1.75905179e+31]
#  [ 1.06906360e+22  2.22374653e+31]
#  [ 1.35148165e+22  2.81120134e+31]
#  [ 1.70850725e+22  3.55384608e+31]
#  [ 2.15984942e+22  4.49267803e+31]
#  [ 2.73042457e+22  5.67952478e+31]
#  [ 3.45173024e+22  7.17990474e+31]
#  [ 4.36358628e+22  9.07664476e+31]
#  [ 5.51632971e+22  1.14744540e+32]
#  [ 6.97359767e+22  1.45057008e+32]
#  [ 8.81583780e+22  1.83377226e+32]
#  [ 1.11447481e+23  2.31820617e+32]
#  [ 1.40888952e+23  2.93061478e+32]
#  [ 1.78108063e+23  3.70480541e+32]
#  [ 2.25159498e+23  4.68351689e+32]
#  [ 2.84640660e+23  5.92077786e+32]
#  [ 3.59835201e+23  7.48489042e+32]
#  [ 4.54894087e+23  9.46220020e+32]
#  [ 5.75065048e+23  1.19618621e+33]
#  [ 7.26981970e+23  1.51218692e+33]
#  [ 9.19031377e+23  1.91166654e+33]
#  [ 1.16181512e+24  2.41667817e+33]
#  [ 1.46873575e+24  3.05510047e+33]
#  [ 1.85673690e+24  3.86217715e+33]
#  [ 2.34723768e+24  4.88246186e+33]
#  [ 2.96731582e+24  6.17227907e+33]
#  [ 3.75120238e+24  7.80283161e+33]
#  [ 4.74216954e+24  9.86413283e+33]
#  [ 5.99492514e+24  1.24699750e+34]
#  [ 7.57862471e+24  1.57642117e+34]
#  [ 9.58069786e+24  1.99286988e+34]
#  [ 1.21116627e+25  2.51933316e+34]
#  [ 1.53112443e+25  3.18487423e+34]
#  [ 1.93560677e+25  4.02623338e+34]
#  [ 2.44694284e+25  5.08985743e+34]
#  [ 3.09336017e+25  6.43446282e+34]
#  [ 3.91054379e+25  8.13427735e+34]
#  [ 4.94360592e+25  1.02831379e+35]
#  [ 6.24957580e+25  1.29996705e+35]
#  [ 7.90054788e+25  1.64338387e+35]
#  [ 9.98766339e+25  2.07752223e+35]
#  [ 1.26261399e+26  2.62634852e+35]
#  [ 1.59616305e+26  3.32016009e+35]
#  [ 2.01782683e+26  4.19725851e+35]
#  [ 2.55088327e+26  5.30606276e+35]
#  [ 3.22475910e+26  6.70778394e+35]
#  [ 4.07665467e+26  8.47980316e+35]
#  [ 5.15359926e+26  1.07199427e+36]
#  [ 6.51504358e+26  1.35518674e+36]
#  [ 8.23614479e+26  1.71319105e+36]
#  [ 1.04119155e+27  2.16577069e+36]
#  [ 1.31624682e+27  2.73790978e+36]
#  [ 1.66396432e+27  3.46119291e+36]
#  [ 2.10353953e+27  4.37554831e+36]
#  [ 2.65923878e+27  5.53145211e+36]
#  [ 3.36173965e+27  6.99271531e+36]
#  [ 4.24982207e+27  8.84000529e+36]
#  [ 5.37251209e+27  1.11753003e+37]
#  [ 6.79178768e+27  1.41275181e+37]
#  [ 8.58599736e+27  1.78596334e+37]
#  [ 1.08541898e+28  2.25776756e+37]
#  [ 1.37215787e+28  2.85421000e+37]
#  [ 1.73464564e+28  3.60821649e+37]
#  [ 2.19289294e+28  4.56141143e+37]
#  [ 2.77219744e+28  5.76641560e+37]
#  [ 3.50453834e+28  7.28975006e+37]
#  [ 4.43034464e+28  9.21550894e+37]
#  [ 5.60072399e+28  1.16500021e+38]
#  [ 7.08028721e+28  1.47276232e+38]
#  [ 8.95071177e+28  1.86182709e+38]
#  [ 1.13152515e+29  2.35367258e+38]
#  [ 1.43044412e+29  2.97545037e+38]
#  [ 1.80832970e+29  3.76148555e+38]
#  [ 2.28604231e+29  4.75517001e+38]
#  [ 2.88995391e+29  6.01135997e+38]
#  [ 3.65340348e+29  7.59940199e+38]
#  [ 4.61853561e+29  9.60696199e+38]
#  [ 5.83862965e+29  1.21448662e+39]
#  [ 7.38104055e+29  1.53532173e+39]
#  [ 9.33091610e+29  1.94091308e+39]
#  [ 1.17958980e+30  2.45365091e+39]
#  [ 1.49120599e+30  3.10184030e+39]
#  [ 1.88514299e+30  3.92126416e+39]
#  [ 2.38314784e+30  4.95715804e+39]
#  [ 3.01271211e+30  6.26670795e+39]
#  [ 3.80859097e+30  7.92220576e+39]
#  [ 4.81471963e+30  1.00150425e+40]
#  [ 6.08664097e+30  1.26607509e+40]
#  [ 7.69456928e+30  1.60053856e+40]
#  [ 9.72727104e+30  2.02335840e+40]
#  [ 1.22969578e+31  2.55787603e+40]
#  [ 1.55454881e+31  3.23359901e+40]
#  [ 1.96521935e+31  4.08783031e+40]
#  [ 2.48437805e+31  5.16772662e+40]
#  [ 3.14068535e+31  6.53290316e+40]
#  [ 3.97037126e+31  8.25872298e+40]
#  [ 5.01923788e+31  1.04404586e+41]
#  [ 6.34518700e+31  1.31985510e+41]
#  [ 8.02141795e+31  1.66852582e+41]
#  [ 1.01404635e+32  2.10930611e+41]
#  [ 1.28193053e+32  2.66652889e+41]
#  [ 1.62058262e+32  3.37095501e+41]
#  [ 2.04869736e+32  4.26147208e+41]
#  [ 2.58990896e+32  5.38723988e+41]
#  [ 3.27409423e+32  6.81040583e+41]
#  [ 4.13902282e+32  8.60953438e+41]
#  [ 5.23244342e+32  1.08839448e+42]
#  [ 6.61471587e+32  1.37591940e+42]
#  [ 8.36214921e+32  1.73940090e+42]
#  [ 1.05712071e+33  2.19890446e+42]
#  [ 1.33638390e+33  2.77979655e+42]
#  [ 1.68942109e+33  3.51414513e+42]
#  [ 2.13572144e+33  4.44248901e+42]
#  [ 2.69992218e+33  5.61607654e+42]
#  [ 3.41316939e+33  7.09969500e+42]
#  [ 4.31483882e+33  8.97524644e+42]
#  [ 5.45470502e+33  1.13462684e+43]
#  [ 6.89569352e+33  1.43436523e+43]
#  [ 8.71735279e+33  1.81328646e+43]
#  [ 1.10202460e+34  2.29230860e+43]
#  [ 1.39315032e+34  2.89787584e+43]
#  [ 1.76118357e+34  3.66341788e+43]
#  [ 2.22644177e+34  4.63119575e+43]
#  [ 2.81460861e+34  5.85463492e+43]
#  [ 3.55815352e+34  7.40127431e+43]
#  [ 4.49812326e+34  9.35649472e+43]
#  [ 5.68640843e+34  1.18282319e+44]
#  [ 7.18860627e+34  1.49529363e+44]
#  [ 9.08764584e+34  1.89031054e+44]
#  [ 1.14883605e+35  2.38968034e+44]
#  [ 1.45232776e+35  3.02097037e+44]
#  [ 1.83599436e+35  3.81903072e+44]
#  [ 2.32101521e+35  4.82791750e+44]
#  [ 2.93416609e+35  6.10332507e+44]
#  [ 3.70929482e+35  7.71566164e+44]
#  [ 4.68919198e+35  9.75393507e+44]
#  [ 5.92795314e+35  1.23306657e+45]
#  [ 7.49396019e+35  1.55881004e+45]
#  [ 9.47366708e+35  1.97060644e+45]
#  [ 1.19763579e+36  2.49118840e+45]
#  [ 1.51401953e+36  3.14929427e+45]
#  [ 1.91398312e+36  3.98125441e+45]
#  [ 2.41960679e+36  5.03299632e+45]
#  [ 3.05880299e+36  6.36258043e+45]
#  [ 3.86685742e+36  8.04340492e+45]
#  [ 4.88837872e+36  1.01682591e+46]
#  [ 6.17975791e+36  1.28544436e+46]
#  [ 7.81228626e+36  1.62502469e+46]
#  [ 9.87608525e+36  2.05431314e+46]
#  [ 1.24850852e+37  2.59700832e+46]
#  [ 1.57833134e+37  3.28306918e+46]
#  [ 1.99528485e+37  4.15036913e+46]
#  [ 2.52238625e+37  5.24678669e+46]
#  [ 3.18873394e+37  6.63284887e+46]
#  [ 4.03111249e+37  8.38507181e+46]
#  [ 5.09602606e+37  1.06001854e+47]
#  [ 6.44226102e+37  1.34004729e+47]
#  [ 8.14413541e+37  1.69405229e+47]
#  [ 1.02956004e+38  2.14157595e+47]
#  [ 1.30154254e+38             inf]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]
#  [            nan             nan]]

# %%
plt.plot(data['Rx'][data['trajectory'] == 17].values, '--', color = colors[1], lw = 2, label='True')
plt.plot(denorm_y(traj_pred)[:,1], '-', color = colors[0], lw = 2, label='Predicted')

# %%
I_interp = interp1d(t_, X_run[], axis=0, fill_value="extrapolate")
u_interp = interp1d(t_, u_, axis=0, fill_value="extrapolate")

def x_of_t(t):
    return np.concatenate([I_interp(t), u_interp(t)])



def n_ode(y, t, model, x_of_t):
    # y: numpy array, shape (d_y,)
    # x_of_t(t): returns numpy array, shape (d_x,)

    y_torch = torch.tensor(y, dtype=torch.float32).unsqueeze(0)

    x_t = x_of_t(t)
    x_torch = torch.tensor(x_t, dtype=torch.float32).unsqueeze(0)

    with torch.no_grad():
        dy = model(y_torch, x_torch)   # shape (1, d_y)

    return dy.squeeze(0).cpu().numpy()


y = scipy.integrate.odeint(n_ode, x_test[0].numpy(), t_, args=(model,))
# Out:
#   Cell In[159], line 1
#     I_interp = interp1d(t_, X_run[], axis=0, fill_value="extrapolate")
#                             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
